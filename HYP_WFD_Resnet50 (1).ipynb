# %% [markdown]
# # Downloading data

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import tensorflow as tf
from tensorflow.keras import layers, models, regularizers
from tensorflow.keras.applications.efficientnet import preprocess_input

# ==== Paths ====
train_dir = '/content/drive/MyDrive/VGG/train'
val_dir   = '/content/drive/MyDrive/VGG/valid'
test_dir  = '/content/drive/MyDrive/VGG/test'

# ==== Parameters ====
img_size    = (256, 256)
batch_size  = 16
seed        = 123
num_classes = 1   # binary classification

# %%
def prepare_ds(path):
    ds = tf.keras.utils.image_dataset_from_directory(
        path, seed=seed,
        image_size=img_size, batch_size=batch_size,
        label_mode='int'
    )
    ds = ds.map(lambda x, y: (preprocess_input(tf.cast(x, tf.float32)), y))
    return ds.prefetch(tf.data.AUTOTUNE)

train_ds = prepare_ds(train_dir)
val_ds   = prepare_ds(val_dir)
test_ds  = prepare_ds(test_dir)
# Out:
# Found 3200 files belonging to 2 classes.
# Found 398 files belonging to 2 classes.
# Found 402 files belonging to 2 classes.

# %%
def build_model(backbone_class):
    backbone = backbone_class(
        input_shape=img_size + (3,),
        include_top=False,
        weights='imagenet'
    )
    backbone.trainable = False

    inputs = layers.Input(shape=img_size + (3,))
    x = backbone(inputs, training=False)
    x = layers.GlobalAveragePooling2D(name='gap')(x)
    x = layers.Dropout(0.3, name='dropout1')(x)
    x = layers.Dense(
        128, activation='relu',
        kernel_regularizer=regularizers.l2(1e-4),
        name='dense128'
    )(x)
    x = layers.Dropout(0.3, name='dropout2')(x)
    outputs = layers.Dense(1, activation='sigmoid', name='output')(x)

    model = models.Model(inputs, outputs)
    model.compile(
        optimizer=tf.keras.optimizers.AdamW(learning_rate=2.5e-4, weight_decay=1e-4),
        loss='binary_crossentropy',
        metrics=[tf.keras.metrics.AUC(name='auc'), 'accuracy']
    )
    return model

# %%
from tensorflow.keras.applications import InceptionV3
model = build_model(InceptionV3)
model.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/inception_v3/inception_v3_weights_tf_dim_ordering_tf_kernels_notop.h5
# 87910968/87910968 ━━━━━━━━━━━━━━━━━━━━ 5s 0us/step
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_1 (InputLayer)      │ (None, 256, 256, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ inception_v3 (Functional)       │ (None, 6, 6, 2048)     │    21,802,784 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ gap (GlobalAveragePooling2D)    │ (None, 2048)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout1 (Dropout)              │ (None, 2048)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense128 (Dense)                │ (None, 128)            │       262,272 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout2 (Dropout)              │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ output (Dense)                  │ (None, 1)              │           129 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 22,065,185 (84.17 MB)
#  Trainable params: 262,401 (1.00 MB)
#  Non-trainable params: 21,802,784 (83.17 MB)

# %%
from tensorflow.keras.callbacks import (
    ModelCheckpoint, EarlyStopping,
    ReduceLROnPlateau, CSVLogger
)

callbacks = [
    ModelCheckpoint('best_model.h5', monitor='val_auc', save_best_only=True, verbose=1),
    EarlyStopping(monitor='val_auc', patience=10, restore_best_weights=True, verbose=1),
    ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=5, min_lr=1e-6, verbose=1),
    CSVLogger('training_log.csv', append=False)
]

history = model.fit(
    train_ds, validation_data=val_ds,
    epochs=50, callbacks=callbacks
)
# Out:
# Epoch 1/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.5184 - auc: 0.5312 - loss: 6.4191
# Epoch 1: val_auc improved from inf to 0.57648, saving model to best_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 882s 4s/step - accuracy: 0.5185 - auc: 0.5312 - loss: 6.4066 - val_accuracy: 0.5050 - val_auc: 0.5765 - val_loss: 0.7178 - learning_rate: 2.5000e-04
# Epoch 2/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step - accuracy: 0.5492 - auc: 0.5632 - loss: 0.9600
# Epoch 2: val_auc improved from 0.57648 to 0.56557, saving model to best_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 70s 151ms/step - accuracy: 0.5492 - auc: 0.5632 - loss: 0.9595 - val_accuracy: 0.5578 - val_auc: 0.5656 - val_loss: 0.7047 - learning_rate: 2.5000e-04
# Epoch 3/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 127ms/step - accuracy: 0.5412 - auc: 0.5484 - loss: 0.7685
# Epoch 3: val_auc did not improve from 0.56557
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 39s 141ms/step - accuracy: 0.5413 - auc: 0.5485 - loss: 0.7684 - val_accuracy: 0.5829 - val_auc: 0.6859 - val_loss: 0.6920 - learning_rate: 2.5000e-04
# Epoch 4/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step - accuracy: 0.5767 - auc: 0.6144 - loss: 0.7049
# Epoch 4: val_auc did not improve from 0.56557
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 43s 153ms/step - accuracy: 0.5767 - auc: 0.6144 - loss: 0.7049 - val_accuracy: 0.6231 - val_auc: 0.7031 - val_loss: 0.6718 - learning_rate: 2.5000e-04
# Epoch 5/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 128ms/step - accuracy: 0.5540 - auc: 0.5970 - loss: 0.6973
# Epoch 5: val_auc did not improve from 0.56557
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 39s 142ms/step - accuracy: 0.5540 - auc: 0.5970 - loss: 0.6973 - val_accuracy: 0.5452 - val_auc: 0.6364 - val_loss: 0.6980 - learning_rate: 2.5000e-04
# Epoch 6/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 127ms/step - accuracy: 0.5778 - auc: 0.6188 - loss: 0.7075
# Epoch 6: val_auc did not improve from 0.56557
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 28s 142ms/step - accuracy: 0.5778 - auc: 0.6188 - loss: 0.7074 - val_accuracy: 0.5905 - val_auc: 0.7062 - val_loss: 0.6729 - learning_rate: 2.5000e-04
# Epoch 7/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step - accuracy: 0.5768 - auc: 0.6254 - loss: 0.6809
# Epoch 7: val_auc did not improve from 0.56557
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 40s 140ms/step - accuracy: 0.5768 - auc: 0.6254 - loss: 0.6809 - val_accuracy: 0.5854 - val_auc: 0.7046 - val_loss: 0.6612 - learning_rate: 2.5000e-04
# Epoch 8/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 125ms/step - accuracy: 0.5768 - auc: 0.6290 - loss: 0.6734
# Epoch 8: val_auc did not improve from 0.56557
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 43s 152ms/step - accuracy: 0.5768 - auc: 0.6290 - loss: 0.6734 - val_accuracy: 0.6030 - val_auc: 0.7073 - val_loss: 0.6592 - learning_rate: 2.5000e-04
# Epoch 9/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step - accuracy: 0.5762 - auc: 0.6371 - loss: 0.6701
# Epoch 9: val_auc did not improve from 0.56557
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 39s 142ms/step - accuracy: 0.5762 - auc: 0.6371 - loss: 0.6701 - val_accuracy: 0.5704 - val_auc: 0.6725 - val_loss: 0.6611 - learning_rate: 2.5000e-04
# Epoch 10/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step - accuracy: 0.5780 - auc: 0.6298 - loss: 0.6677
# Epoch 10: val_auc did not improve from 0.56557
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 42s 147ms/step - accuracy: 0.5781 - auc: 0.6299 - loss: 0.6677 - val_accuracy: 0.5829 - val_auc: 0.6798 - val_loss: 0.6467 - learning_rate: 2.5000e-04
# Epoch 11/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 131ms/step - accuracy: 0.6022 - auc: 0.6626 - loss: 0.6542
# Epoch 11: val_auc did not improve from 0.56557
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 40s 145ms/step - accuracy: 0.6022 - auc: 0.6626 - loss: 0.6542 - val_accuracy: 0.6307 - val_auc: 0.7064 - val_loss: 0.6448 - learning_rate: 2.5000e-04
# Epoch 12/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 131ms/step - accuracy: 0.5853 - auc: 0.6515 - loss: 0.6561
# Epoch 12: val_auc did not improve from 0.56557
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 43s 157ms/step - accuracy: 0.5854 - auc: 0.6515 - loss: 0.6561 - val_accuracy: 0.6005 - val_auc: 0.7111 - val_loss: 0.6399 - learning_rate: 2.5000e-04
# Epoch 13/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 130ms/step - accuracy: 0.6075 - auc: 0.6672 - loss: 0.6559
# Epoch 13: val_auc did not improve from 0.56557
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 41s 157ms/step - accuracy: 0.6074 - auc: 0.6671 - loss: 0.6559 - val_accuracy: 0.6482 - val_auc: 0.7116 - val_loss: 0.6462 - learning_rate: 2.5000e-04
# Epoch 14/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 129ms/step - accuracy: 0.6137 - auc: 0.6881 - loss: 0.6387
# Epoch 14: val_auc did not improve from 0.56557
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 38s 143ms/step - accuracy: 0.6137 - auc: 0.6880 - loss: 0.6387 - val_accuracy: 0.6382 - val_auc: 0.7097 - val_loss: 0.6497 - learning_rate: 2.5000e-04
# Epoch 15/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step - accuracy: 0.6179 - auc: 0.6846 - loss: 0.6394
# Epoch 15: val_auc did not improve from 0.56557
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 41s 142ms/step - accuracy: 0.6179 - auc: 0.6846 - loss: 0.6394 - val_accuracy: 0.6583 - val_auc: 0.7295 - val_loss: 0.6191 - learning_rate: 2.5000e-04
# Epoch 16/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step - accuracy: 0.6247 - auc: 0.6960 - loss: 0.6354
# Epoch 16: val_auc did not improve from 0.56557
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 42s 148ms/step - accuracy: 0.6246 - auc: 0.6959 - loss: 0.6354 - val_accuracy: 0.6307 - val_auc: 0.7215 - val_loss: 0.6382 - learning_rate: 2.5000e-04
# Epoch 17/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step - accuracy: 0.6217 - auc: 0.6844 - loss: 0.6431
# Epoch 17: val_auc did not improve from 0.56557
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 39s 140ms/step - accuracy: 0.6217 - auc: 0.6844 - loss: 0.6431 - val_accuracy: 0.6382 - val_auc: 0.7119 - val_loss: 0.6350 - learning_rate: 2.5000e-04
# Epoch 18/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 125ms/step - accuracy: 0.6190 - auc: 0.6906 - loss: 0.6417
# Epoch 18: val_auc did not improve from 0.56557
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 43s 151ms/step - accuracy: 0.6191 - auc: 0.6906 - loss: 0.6417 - val_accuracy: 0.6231 - val_auc: 0.7215 - val_loss: 0.6355 - learning_rate: 2.5000e-04
# Epoch 19/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 125ms/step - accuracy: 0.6340 - auc: 0.6971 - loss: 0.6368
# Epoch 19: val_auc did not improve from 0.56557
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 41s 151ms/step - accuracy: 0.6339 - auc: 0.6970 - loss: 0.6368 - val_accuracy: 0.6281 - val_auc: 0.7220 - val_loss: 0.6299 - learning_rate: 2.5000e-04
# Epoch 20/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step - accuracy: 0.6044 - auc: 0.6832 - loss: 0.6346
# Epoch 20: val_auc did not improve from 0.56557
#
# Epoch 20: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 31s 152ms/step - accuracy: 0.6044 - auc: 0.6831 - loss: 0.6347 - val_accuracy: 0.6884 - val_auc: 0.7459 - val_loss: 0.6360 - learning_rate: 2.5000e-04
# Epoch 21/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step - accuracy: 0.6223 - auc: 0.6888 - loss: 0.6363
# Epoch 21: val_auc did not improve from 0.56557
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 41s 152ms/step - accuracy: 0.6223 - auc: 0.6888 - loss: 0.6363 - val_accuracy: 0.6633 - val_auc: 0.7428 - val_loss: 0.6175 - learning_rate: 1.2500e-04
# Epoch 22/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step - accuracy: 0.6430 - auc: 0.7120 - loss: 0.6194
# Epoch 22: val_auc did not improve from 0.56557
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 41s 149ms/step - accuracy: 0.6430 - auc: 0.7120 - loss: 0.6195 - val_accuracy: 0.6633 - val_auc: 0.7509 - val_loss: 0.6122 - learning_rate: 1.2500e-04
# Epoch 23/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step - accuracy: 0.6422 - auc: 0.7202 - loss: 0.6174
# Epoch 23: val_auc did not improve from 0.56557
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 39s 139ms/step - accuracy: 0.6422 - auc: 0.7201 - loss: 0.6175 - val_accuracy: 0.6407 - val_auc: 0.7452 - val_loss: 0.6174 - learning_rate: 1.2500e-04
# Epoch 24/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 125ms/step - accuracy: 0.6287 - auc: 0.7045 - loss: 0.6226
# Epoch 24: val_auc did not improve from 0.56557
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 43s 151ms/step - accuracy: 0.6288 - auc: 0.7045 - loss: 0.6226 - val_accuracy: 0.6709 - val_auc: 0.7465 - val_loss: 0.6200 - learning_rate: 1.2500e-04
# Epoch 25/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 125ms/step - accuracy: 0.6398 - auc: 0.7136 - loss: 0.6213
# Epoch 25: val_auc did not improve from 0.56557
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 41s 152ms/step - accuracy: 0.6397 - auc: 0.7135 - loss: 0.6213 - val_accuracy: 0.6633 - val_auc: 0.7514 - val_loss: 0.6225 - learning_rate: 1.2500e-04
# Epoch 26/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 125ms/step - accuracy: 0.6257 - auc: 0.7122 - loss: 0.6179
# Epoch 26: val_auc did not improve from 0.56557
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 39s 140ms/step - accuracy: 0.6258 - auc: 0.7122 - loss: 0.6179 - val_accuracy: 0.6884 - val_auc: 0.7548 - val_loss: 0.6106 - learning_rate: 1.2500e-04
# Epoch 27/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step - accuracy: 0.6354 - auc: 0.7123 - loss: 0.6170
# Epoch 27: val_auc did not improve from 0.56557
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 41s 140ms/step - accuracy: 0.6353 - auc: 0.7123 - loss: 0.6170 - val_accuracy: 0.6633 - val_auc: 0.7616 - val_loss: 0.6065 - learning_rate: 1.2500e-04
# Epoch 28/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step - accuracy: 0.6389 - auc: 0.7082 - loss: 0.6185
# Epoch 28: val_auc did not improve from 0.56557
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 43s 150ms/step - accuracy: 0.6389 - auc: 0.7082 - loss: 0.6185 - val_accuracy: 0.6658 - val_auc: 0.7581 - val_loss: 0.6067 - learning_rate: 1.2500e-04
# Epoch 29/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step - accuracy: 0.6290 - auc: 0.7122 - loss: 0.6160
# Epoch 29: val_auc did not improve from 0.56557
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 40s 145ms/step - accuracy: 0.6290 - auc: 0.7121 - loss: 0.6160 - val_accuracy: 0.6482 - val_auc: 0.7511 - val_loss: 0.6062 - learning_rate: 1.2500e-04
# Epoch 30/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step - accuracy: 0.6363 - auc: 0.7113 - loss: 0.6252
# Epoch 30: val_auc did not improve from 0.56557
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 28s 140ms/step - accuracy: 0.6362 - auc: 0.7113 - loss: 0.6252 - val_accuracy: 0.6910 - val_auc: 0.7631 - val_loss: 0.6062 - learning_rate: 1.2500e-04
# Epoch 31/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 128ms/step - accuracy: 0.6370 - auc: 0.7130 - loss: 0.6130
# Epoch 31: val_auc did not improve from 0.56557
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 41s 142ms/step - accuracy: 0.6370 - auc: 0.7130 - loss: 0.6130 - val_accuracy: 0.6784 - val_auc: 0.7577 - val_loss: 0.6050 - learning_rate: 1.2500e-04
# Epoch 32/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step - accuracy: 0.6358 - auc: 0.7177 - loss: 0.6113
# Epoch 32: val_auc did not improve from 0.56557
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 40s 139ms/step - accuracy: 0.6358 - auc: 0.7176 - loss: 0.6113 - val_accuracy: 0.7060 - val_auc: 0.7620 - val_loss: 0.6062 - learning_rate: 1.2500e-04
# Epoch 33/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step - accuracy: 0.6427 - auc: 0.7104 - loss: 0.6183
# Epoch 33: val_auc did not improve from 0.56557
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 28s 140ms/step - accuracy: 0.6427 - auc: 0.7104 - loss: 0.6183 - val_accuracy: 0.6910 - val_auc: 0.7727 - val_loss: 0.6007 - learning_rate: 1.2500e-04
# Epoch 34/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 128ms/step - accuracy: 0.6397 - auc: 0.7135 - loss: 0.6118
# Epoch 34: val_auc did not improve from 0.56557
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 44s 154ms/step - accuracy: 0.6397 - auc: 0.7134 - loss: 0.6118 - val_accuracy: 0.6985 - val_auc: 0.7589 - val_loss: 0.6056 - learning_rate: 1.2500e-04
# Epoch 35/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 130ms/step - accuracy: 0.6438 - auc: 0.7240 - loss: 0.6022
# Epoch 35: val_auc did not improve from 0.56557
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 39s 146ms/step - accuracy: 0.6437 - auc: 0.7239 - loss: 0.6022 - val_accuracy: 0.6834 - val_auc: 0.7617 - val_loss: 0.6067 - learning_rate: 1.2500e-04
# Epoch 36/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 125ms/step - accuracy: 0.6469 - auc: 0.7242 - loss: 0.6054
# Epoch 36: val_auc did not improve from 0.56557
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 42s 151ms/step - accuracy: 0.6469 - auc: 0.7243 - loss: 0.6054 - val_accuracy: 0.6960 - val_auc: 0.7539 - val_loss: 0.5991 - learning_rate: 1.2500e-04
# Epoch 37/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step - accuracy: 0.6360 - auc: 0.7153 - loss: 0.6109
# Epoch 37: val_auc did not improve from 0.56557
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 30s 148ms/step - accuracy: 0.6360 - auc: 0.7153 - loss: 0.6109 - val_accuracy: 0.7111 - val_auc: 0.7759 - val_loss: 0.6012 - learning_rate: 1.2500e-04
# Epoch 38/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 130ms/step - accuracy: 0.6429 - auc: 0.7175 - loss: 0.6046
# Epoch 38: val_auc did not improve from 0.56557
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 40s 145ms/step - accuracy: 0.6429 - auc: 0.7175 - loss: 0.6046 - val_accuracy: 0.6985 - val_auc: 0.7651 - val_loss: 0.5988 - learning_rate: 1.2500e-04
# Epoch 39/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step - accuracy: 0.6498 - auc: 0.7243 - loss: 0.6042
# Epoch 39: val_auc did not improve from 0.56557
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 29s 146ms/step - accuracy: 0.6498 - auc: 0.7242 - loss: 0.6042 - val_accuracy: 0.6608 - val_auc: 0.7477 - val_loss: 0.6131 - learning_rate: 1.2500e-04
# Epoch 40/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 130ms/step - accuracy: 0.6326 - auc: 0.7133 - loss: 0.6130
# Epoch 40: val_auc did not improve from 0.56557
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 41s 144ms/step - accuracy: 0.6327 - auc: 0.7133 - loss: 0.6130 - val_accuracy: 0.7010 - val_auc: 0.7593 - val_loss: 0.5902 - learning_rate: 1.2500e-04
# Epoch 41/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 130ms/step - accuracy: 0.6606 - auc: 0.7434 - loss: 0.5918
# Epoch 41: val_auc did not improve from 0.56557
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 29s 144ms/step - accuracy: 0.6607 - auc: 0.7434 - loss: 0.5919 - val_accuracy: 0.6985 - val_auc: 0.7717 - val_loss: 0.5922 - learning_rate: 1.2500e-04
# Epoch 42/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 129ms/step - accuracy: 0.6414 - auc: 0.7242 - loss: 0.6013
# Epoch 42: val_auc did not improve from 0.56557
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 43s 156ms/step - accuracy: 0.6414 - auc: 0.7242 - loss: 0.6013 - val_accuracy: 0.7236 - val_auc: 0.7803 - val_loss: 0.5944 - learning_rate: 1.2500e-04
# Epoch 43/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step - accuracy: 0.6533 - auc: 0.7301 - loss: 0.6045
# Epoch 43: val_auc did not improve from 0.56557
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 30s 148ms/step - accuracy: 0.6532 - auc: 0.7300 - loss: 0.6045 - val_accuracy: 0.7010 - val_auc: 0.7801 - val_loss: 0.5946 - learning_rate: 1.2500e-04
# Epoch 44/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step - accuracy: 0.6662 - auc: 0.7408 - loss: 0.5939
# Epoch 44: val_auc did not improve from 0.56557
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 39s 140ms/step - accuracy: 0.6661 - auc: 0.7408 - loss: 0.5940 - val_accuracy: 0.7136 - val_auc: 0.7705 - val_loss: 0.5966 - learning_rate: 1.2500e-04
# Epoch 45/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step - accuracy: 0.6560 - auc: 0.7251 - loss: 0.6036
# Epoch 45: val_auc did not improve from 0.56557
#
# Epoch 45: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 28s 140ms/step - accuracy: 0.6560 - auc: 0.7251 - loss: 0.6036 - val_accuracy: 0.7161 - val_auc: 0.7822 - val_loss: 0.5931 - learning_rate: 1.2500e-04
# Epoch 46/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step - accuracy: 0.6596 - auc: 0.7350 - loss: 0.5919
# Epoch 46: val_auc did not improve from 0.56557
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 43s 153ms/step - accuracy: 0.6596 - auc: 0.7349 - loss: 0.5919 - val_accuracy: 0.7236 - val_auc: 0.7941 - val_loss: 0.5877 - learning_rate: 6.2500e-05
# Epoch 47/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step - accuracy: 0.6675 - auc: 0.7500 - loss: 0.5908
# Epoch 47: val_auc did not improve from 0.56557
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 28s 140ms/step - accuracy: 0.6674 - auc: 0.7499 - loss: 0.5908 - val_accuracy: 0.7186 - val_auc: 0.7854 - val_loss: 0.5800 - learning_rate: 6.2500e-05
# Epoch 48/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step - accuracy: 0.6665 - auc: 0.7413 - loss: 0.5908
# Epoch 48: val_auc did not improve from 0.56557
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 43s 149ms/step - accuracy: 0.6664 - auc: 0.7413 - loss: 0.5908 - val_accuracy: 0.7161 - val_auc: 0.7930 - val_loss: 0.5797 - learning_rate: 6.2500e-05
# Epoch 49/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step - accuracy: 0.6631 - auc: 0.7388 - loss: 0.5889
# Epoch 49: val_auc did not improve from 0.56557
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 40s 144ms/step - accuracy: 0.6630 - auc: 0.7387 - loss: 0.5890 - val_accuracy: 0.7060 - val_auc: 0.7797 - val_loss: 0.5826 - learning_rate: 6.2500e-05
# Epoch 50/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step - accuracy: 0.6563 - auc: 0.7317 - loss: 0.5902
# Epoch 50: val_auc did not improve from 0.56557
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 40s 140ms/step - accuracy: 0.6563 - auc: 0.7317 - loss: 0.5902 - val_accuracy: 0.7136 - val_auc: 0.7836 - val_loss: 0.5792 - learning_rate: 6.2500e-05
# Restoring model weights from the end of the best epoch: 46.

# %%
import numpy as np
from sklearn.metrics import roc_curve, accuracy_score, roc_auc_score, f1_score
import tensorflow as tf
# Evaluate on test set using the best saved model
model.load_weights('best_model.h5')

# 1) Predict probabilities
y_true, y_prob = [], []
for x_batch, y_batch in test_ds:
    y_true.extend(y_batch.numpy())
    y_prob.extend(model.predict(x_batch).flatten())
y_true = np.array(y_true)
y_prob = np.array(y_prob)

# 2) Compute ROC curve and Youden’s J threshold
fpr, tpr, thresholds = roc_curve(y_true, y_prob)
j_idx = np.argmax(tpr - fpr)
best_threshold = thresholds[j_idx]
print(f'Optimal threshold (Youden J): {best_threshold:.3f}')

# 3) Compute binary predictions and metrics
y_pred = (y_prob >= best_threshold).astype(int)
test_acc = accuracy_score(y_true, y_pred)
test_auc = roc_auc_score(y_true, y_prob)
test_f1  = f1_score(y_true, y_pred)

print(f'Test AUC : {test_auc:.4f}')
print(f'Test Acc : {test_acc:.4f}')
print(f'Test F1  : {test_f1:.4f}')
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 6s 6s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 247ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 7s 7s/step
# Optimal threshold (Youden J): 0.473
# Test AUC : 0.5432
# Test Acc : 0.5448
# Test F1  : 0.6817
