# %%
# Step 1: Importing Necessary Libraries
import os
import shutil
import hashlib
import matplotlib.pyplot as plt
import cv2

# Step 2: Creating Function for generating Hash value of each Image
def generate_image_hash(image_path):
    """Generate SHA-256 hash for the given image file."""
    with open(image_path, 'rb') as f:
        image_bytes = f.read()
    return hashlib.sha256(image_bytes).hexdigest()

# # Step 3: Getting Current Directory (Optional: just to show where you are)
# current_dir = os.getcwd()
# print("Current Working Directory:", current_dir)

# Step 4: Change directory to where your multiple images are located
folder_path =r'C:\Users\Global\Fabric project\WFDD\grey cloth\normal'
os.chdir(folder_path)
print("Changed working directory to:", os.getcwd())

# Step 5: Finding length (number) of the images in that folder
all_files = os.listdir(folder_path)
# Filter for common image formats if needed. Adjust extensions accordingly.
image_extensions = ('.jpg', '.jpeg', '.png', '.bmp', '.tif', '.tiff')
images = [f for f in all_files if f.lower().endswith(image_extensions)]
print("Total images in folder:", len(images))

# Step 6: Method for generating Hash values of each image & finding duplicates
hash_dict = {}  # This dictionary will map a hash -> list of file names having that hash

for image_file in images:
    image_hash = generate_image_hash(os.path.join(folder_path, image_file))
    if image_hash in hash_dict:
        hash_dict[image_hash].append(image_file)
    else:
        hash_dict[image_hash] = [image_file]

# Identify duplicate groups (those with more than one file name)
duplicates = {h: files for h, files in hash_dict.items() if len(files) > 1}

if duplicates:
    print("\nFound duplicate images:")
    for h, files in duplicates.items():
        print(f"Hash: {h}\nFiles: {files}\n")
else:
    print("\nNo duplicate images found.")

# Step 7: Visualizing (display one sample duplicate image from each duplicate group)
if duplicates:
    print("Displaying one sample image from each duplicate group:")
    plt.figure(figsize=(12, len(duplicates) * 4))
    for idx, (h, files) in enumerate(duplicates.items()):
        # Read the first image in the duplicate list with cv2 and convert to RGB for display
        sample_image_path = os.path.join(folder_path, files[0])
        img = cv2.imread(sample_image_path)
        img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
        plt.subplot(len(duplicates), 1, idx + 1)
        plt.imshow(img_rgb)
        plt.title(f"Duplicate Group (Hash: {h}) with {len(files)} images")
        plt.axis('off')
    plt.tight_layout()
    plt.show()

# Step 8: Remove duplicates by copying only one image per unique hash into a new folder.
# Creating a new folder 'normal1' within the same parent directory.
parent_dir = os.path.dirname(folder_path)  # One level above your current folder
destination = os.path.join(parent_dir, 'normal1')
os.makedirs(destination, exist_ok=True)
print("New folder for filtered images created at:", destination)

# Copy one image per hash into destination (this removes duplicates)
for h, file_list in hash_dict.items():
    # Pick the first file of this hash group
    src_file = os.path.join(folder_path, file_list[0])
    dst_file = os.path.join(destination, file_list[0])
    shutil.copy(src_file, dst_file)

print("Filtered images have been copied to the new folder.")

# Step 9: Verify new folder image count
new_images = [f for f in os.listdir(destination) if f.lower().endswith(image_extensions)]
print("Total unique images in new folder (normal1):", len(new_images))
# Out:
# Changed working directory to: C:\Users\Global\Fabric project\WFDD\grey cloth\normal
# Total images in folder: 309
#
# No duplicate images found.
# New folder for filtered images created at: C:\Users\Global\Fabric project\WFDD\grey cloth\normal1
# Filtered images have been copied to the new folder.
# Total unique images in new folder (normal1): 309

# %%
import os
import shutil
import hashlib
import matplotlib.pyplot as plt
import cv2

# --- Helper Function: Generate Hash for an Image ---
def generate_image_hash(image_path):
    """Generate SHA-256 hash for the given image file."""
    with open(image_path, 'rb') as f:
        image_bytes = f.read()
    return hashlib.sha256(image_bytes).hexdigest()

# --- Settings ---
# Folder containing defect subfolders
defect_folder =r'C:\Users\Global\Fabric project\WFDD\grey cloth\defect'
# Valid image extensions (adjust as needed)
image_extensions = ('.jpg', '.jpeg', '.png', '.bmp', '.tif', '.tiff')

# New parent folder for filtered defect images (one subfolder per defect type)
parent_dir = os.path.dirname(defect_folder)
destination_parent = os.path.join(parent_dir, 'defect1')
os.makedirs(destination_parent, exist_ok=True)
print("New parent folder for filtered defect images created at:", destination_parent)

# --- Process Each Defect Subfolder ---
defect_types = [d for d in os.listdir(defect_folder) if os.path.isdir(os.path.join(defect_folder, d))]
if not defect_types:
    raise ValueError("No defect subfolders found in the defect folder.")

for defect_type in defect_types:
    print(f"\nProcessing defect type: {defect_type}")
    subfolder_path = os.path.join(defect_folder, defect_type)
    
    # List all valid image files in the defect subfolder
    all_files = os.listdir(subfolder_path)
    images = [f for f in all_files if f.lower().endswith(image_extensions)]
    print(f"Total images in '{defect_type}' folder: {len(images)}")
    
    # Dictionary to map hash -> list of file names
    hash_dict = {}
    for image_file in images:
        image_path = os.path.join(subfolder_path, image_file)
        image_hash = generate_image_hash(image_path)
        hash_dict.setdefault(image_hash, []).append(image_file)
    
    # Identify duplicate groups (hash groups with more than one image)
    duplicates = {h: files for h, files in hash_dict.items() if len(files) > 1}
    if duplicates:
        print("Found duplicate images:")
        for h, files in duplicates.items():
            print(f"Hash: {h}\nFiles: {files}\n")
    else:
        print("No duplicate images found.")

    # --- Visualization: Display one sample image from each duplicate group (if any) ---
    if duplicates:
        print("Displaying one sample image from each duplicate group:")
        plt.figure(figsize=(12, len(duplicates) * 4))
        for idx, (h, files) in enumerate(duplicates.items()):
            sample_image_path = os.path.join(subfolder_path, files[0])
            img = cv2.imread(sample_image_path)
            if img is None:
                continue
            img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
            plt.subplot(len(duplicates), 1, idx + 1)
            plt.imshow(img_rgb)
            plt.title(f"Duplicate Group (Hash: {h}) with {len(files)} images")
            plt.axis('off')
        plt.tight_layout()
        plt.show()
    
    # --- Copy Unique Images: One image per unique hash ---
    # Create corresponding subfolder in destination
    destination = os.path.join(destination_parent, defect_type)
    os.makedirs(destination, exist_ok=True)
    for h, file_list in hash_dict.items():
        # Pick the first file from each group (which removes duplicates)
        src_file = os.path.join(subfolder_path, file_list[0])
        dst_file = os.path.join(destination, file_list[0])
        shutil.copy(src_file, dst_file)
    
    # Verify the new folder count for the defect type
    new_images = [f for f in os.listdir(destination) if f.lower().endswith(image_extensions)]
    print(f"Total unique images in new folder '{defect_type}':", len(new_images))
# Out:
# New parent folder for filtered defect images created at: C:\Users\Global\Fabric project\WFDD\grey cloth\defect1
#
# Processing defect type: contaminated
# Total images in 'contaminated' folder: 20
# No duplicate images found.
# Total unique images in new folder 'contaminated': 20
#
# Processing defect type: flecked
# Total images in 'flecked' folder: 14
# No duplicate images found.
# Total unique images in new folder 'flecked': 14
#
# Processing defect type: line
# Total images in 'line' folder: 9
# No duplicate images found.
# Total unique images in new folder 'line': 9
#
# Processing defect type: string
# Total images in 'string' folder: 16
# No duplicate images found.
# Total unique images in new folder 'string': 16

# %%
import os
import cv2

# Specify the folder containing images
folder_path = r'C:\Users\Global\Fabric project\WFDD\grey cloth\normal' # Change as necessary

# Define valid image extensions
image_extensions = ('.jpg', '.jpeg', '.png', '.bmp', '.tif', '.tiff')

# Iterate over all files in the folder
print("Image Sizes in the Folder:")
for filename in os.listdir(folder_path):
    if filename.lower().endswith(image_extensions):
        image_path = os.path.join(folder_path, filename)
        image = cv2.imread(image_path)
        if image is not None:
            # cv2 image shape returns (height, width, channels)
            height, width = image.shape[:2]
            print(f"{filename}: Width = {width} px, Height = {height} px")
        else:
            print(f"Could not read {filename}")
# Out:
# Image Sizes in the Folder:
# img1.png: Width = 512 px, Height = 512 px
# img10.png: Width = 512 px, Height = 512 px
# img100.png: Width = 512 px, Height = 512 px
# img101.png: Width = 512 px, Height = 512 px
# img102.png: Width = 512 px, Height = 512 px
# img103.png: Width = 512 px, Height = 512 px
# img104.png: Width = 512 px, Height = 512 px
# img105.png: Width = 512 px, Height = 512 px
# img106.png: Width = 512 px, Height = 512 px
# img107.png: Width = 512 px, Height = 512 px
# img108.png: Width = 512 px, Height = 512 px
# img109.png: Width = 512 px, Height = 512 px
# img11.png: Width = 512 px, Height = 512 px
# img110.png: Width = 512 px, Height = 512 px
# img111.png: Width = 512 px, Height = 512 px
# img112.png: Width = 512 px, Height = 512 px
# img113.png: Width = 512 px, Height = 512 px
# img114.png: Width = 512 px, Height = 512 px
# img115.png: Width = 512 px, Height = 512 px
# img116.png: Width = 512 px, Height = 512 px
# img117.png: Width = 512 px, Height = 512 px
# img118.png: Width = 512 px, Height = 512 px
# img119.png: Width = 512 px, Height = 512 px
# img12.png: Width = 512 px, Height = 512 px
# img120.png: Width = 512 px, Height = 512 px
# img121.png: Width = 512 px, Height = 512 px
# img122.png: Width = 512 px, Height = 512 px
# img123.png: Width = 512 px, Height = 512 px
# img124.png: Width = 512 px, Height = 512 px
# img125.png: Width = 512 px, Height = 512 px
# img126.png: Width = 512 px, Height = 512 px
# img127.png: Width = 512 px, Height = 512 px
# img128.png: Width = 512 px, Height = 512 px
# img129.png: Width = 512 px, Height = 512 px
# img13.png: Width = 512 px, Height = 512 px
# img130.png: Width = 512 px, Height = 512 px
# img131.png: Width = 512 px, Height = 512 px
# img132.png: Width = 512 px, Height = 512 px
# img133.png: Width = 512 px, Height = 512 px
# img134.png: Width = 512 px, Height = 512 px
# img135.png: Width = 512 px, Height = 512 px
# img136.png: Width = 512 px, Height = 512 px
# img137.png: Width = 512 px, Height = 512 px
# img138.png: Width = 512 px, Height = 512 px
# img139.png: Width = 512 px, Height = 512 px
# img14.png: Width = 512 px, Height = 512 px
# img140.png: Width = 512 px, Height = 512 px
# img141.png: Width = 512 px, Height = 512 px
# img142.png: Width = 512 px, Height = 512 px
# img143.png: Width = 512 px, Height = 512 px
# img144.png: Width = 512 px, Height = 512 px
# img145.png: Width = 512 px, Height = 512 px
# img146.png: Width = 512 px, Height = 512 px
# img147.png: Width = 512 px, Height = 512 px
# img148.png: Width = 512 px, Height = 512 px
# img149.png: Width = 512 px, Height = 512 px
# img15.png: Width = 512 px, Height = 512 px
# img150.png: Width = 512 px, Height = 512 px
# img151.png: Width = 512 px, Height = 512 px
# img152.png: Width = 512 px, Height = 512 px
# img153.png: Width = 512 px, Height = 512 px
# img154.png: Width = 512 px, Height = 512 px
# img155.png: Width = 512 px, Height = 512 px
# img156.png: Width = 512 px, Height = 512 px
# img157.png: Width = 512 px, Height = 512 px
# img158.png: Width = 512 px, Height = 512 px
# img159.png: Width = 512 px, Height = 512 px
# img16.png: Width = 512 px, Height = 512 px
# img160.png: Width = 512 px, Height = 512 px
# img161.png: Width = 512 px, Height = 512 px
# img162.png: Width = 512 px, Height = 512 px
# img163.png: Width = 512 px, Height = 512 px
# img164.png: Width = 512 px, Height = 512 px
# img165.png: Width = 512 px, Height = 512 px
# img166.png: Width = 512 px, Height = 512 px
# img167.png: Width = 512 px, Height = 512 px
# img168.png: Width = 512 px, Height = 512 px
# img169.png: Width = 512 px, Height = 512 px
# img17.png: Width = 512 px, Height = 512 px
# img170.png: Width = 512 px, Height = 512 px
# img171.png: Width = 512 px, Height = 512 px
# img172.png: Width = 512 px, Height = 512 px
# img173.png: Width = 512 px, Height = 512 px
# img174.png: Width = 512 px, Height = 512 px
# img175.png: Width = 512 px, Height = 512 px
# img176.png: Width = 512 px, Height = 512 px
# img177.png: Width = 512 px, Height = 512 px
# img178.png: Width = 512 px, Height = 512 px
# img179.png: Width = 512 px, Height = 512 px
# img18.png: Width = 512 px, Height = 512 px
# img180.png: Width = 512 px, Height = 512 px
# img181.png: Width = 512 px, Height = 512 px
# img182.png: Width = 512 px, Height = 512 px
# img183.png: Width = 512 px, Height = 512 px
# img184.png: Width = 512 px, Height = 512 px
# img185.png: Width = 512 px, Height = 512 px
# img186.png: Width = 512 px, Height = 512 px
# img187.png: Width = 512 px, Height = 512 px
# img188.png: Width = 512 px, Height = 512 px
# img189.png: Width = 512 px, Height = 512 px
# img19.png: Width = 512 px, Height = 512 px
# img190.png: Width = 512 px, Height = 512 px
# img191.png: Width = 512 px, Height = 512 px
# img192.png: Width = 512 px, Height = 512 px
# img193.png: Width = 512 px, Height = 512 px
# img194.png: Width = 512 px, Height = 512 px
# img195.png: Width = 512 px, Height = 512 px
# img196.png: Width = 512 px, Height = 512 px
# img197.png: Width = 512 px, Height = 512 px
# img198.png: Width = 512 px, Height = 512 px
# img199.png: Width = 512 px, Height = 512 px
# img2.png: Width = 512 px, Height = 512 px
# img20.png: Width = 512 px, Height = 512 px
# img200.png: Width = 512 px, Height = 512 px
# img201.png: Width = 512 px, Height = 512 px
# img202.png: Width = 512 px, Height = 512 px
# img203.png: Width = 512 px, Height = 512 px
# img204.png: Width = 512 px, Height = 512 px
# img205.png: Width = 512 px, Height = 512 px
# img206.png: Width = 512 px, Height = 512 px
# img207.png: Width = 512 px, Height = 512 px
# img208.png: Width = 512 px, Height = 512 px
# img209.png: Width = 512 px, Height = 512 px
# img21.png: Width = 512 px, Height = 512 px
# img210.png: Width = 512 px, Height = 512 px
# img211.png: Width = 512 px, Height = 512 px
# img212.png: Width = 512 px, Height = 512 px
# img213.png: Width = 512 px, Height = 512 px
# img214.png: Width = 512 px, Height = 512 px
# img215.png: Width = 512 px, Height = 512 px
# img216.png: Width = 512 px, Height = 512 px
# img217.png: Width = 512 px, Height = 512 px
# img218.png: Width = 512 px, Height = 512 px
# img219.png: Width = 512 px, Height = 512 px
# img22.png: Width = 512 px, Height = 512 px
# img220.png: Width = 512 px, Height = 512 px
# img221.png: Width = 512 px, Height = 512 px
# img222.png: Width = 512 px, Height = 512 px
# img223.png: Width = 512 px, Height = 512 px
# img224.png: Width = 512 px, Height = 512 px
# img225.png: Width = 512 px, Height = 512 px
# img226.png: Width = 512 px, Height = 512 px
# img227.png: Width = 512 px, Height = 512 px
# img228.png: Width = 512 px, Height = 512 px
# img229.png: Width = 512 px, Height = 512 px
# img23.png: Width = 512 px, Height = 512 px
# img230.png: Width = 512 px, Height = 512 px
# img231.png: Width = 512 px, Height = 512 px
# img232.png: Width = 512 px, Height = 512 px
# img233.png: Width = 512 px, Height = 512 px
# img234.png: Width = 512 px, Height = 512 px
# img235.png: Width = 512 px, Height = 512 px
# img236.png: Width = 512 px, Height = 512 px
# img237.png: Width = 512 px, Height = 512 px
# img238.png: Width = 512 px, Height = 512 px
# img239.png: Width = 512 px, Height = 512 px
# img24.png: Width = 512 px, Height = 512 px
# img240.png: Width = 512 px, Height = 512 px
# img241.png: Width = 512 px, Height = 512 px
# img242.png: Width = 512 px, Height = 512 px
# img243.png: Width = 512 px, Height = 512 px
# img244.png: Width = 512 px, Height = 512 px
# img245.png: Width = 512 px, Height = 512 px
# img246.png: Width = 512 px, Height = 512 px
# img247.png: Width = 512 px, Height = 512 px
# img248.png: Width = 512 px, Height = 512 px
# img249.png: Width = 512 px, Height = 512 px
# img25.png: Width = 512 px, Height = 512 px
# img250.png: Width = 512 px, Height = 512 px
# img251.png: Width = 512 px, Height = 512 px
# img252.png: Width = 512 px, Height = 512 px
# img253.png: Width = 512 px, Height = 512 px
# img254.png: Width = 512 px, Height = 512 px
# img255.png: Width = 512 px, Height = 512 px
# img256.png: Width = 512 px, Height = 512 px
# img257.png: Width = 512 px, Height = 512 px
# img258.png: Width = 512 px, Height = 512 px
# img259.png: Width = 512 px, Height = 512 px
# img26.png: Width = 512 px, Height = 512 px
# img260.png: Width = 512 px, Height = 512 px
# img261.png: Width = 512 px, Height = 512 px
# img262.png: Width = 512 px, Height = 512 px
# img263.png: Width = 512 px, Height = 512 px
# img264.png: Width = 512 px, Height = 512 px
# img265.png: Width = 512 px, Height = 512 px
# img266.png: Width = 512 px, Height = 512 px
# img267.png: Width = 512 px, Height = 512 px
# img268.png: Width = 512 px, Height = 512 px
# img269.png: Width = 512 px, Height = 512 px
# img27.png: Width = 512 px, Height = 512 px
# img270.png: Width = 512 px, Height = 512 px
# img271.png: Width = 512 px, Height = 512 px
# img272.png: Width = 512 px, Height = 512 px
# img273.png: Width = 512 px, Height = 512 px
# img274.png: Width = 512 px, Height = 512 px
# img275.png: Width = 512 px, Height = 512 px
# img276.png: Width = 512 px, Height = 512 px
# img277.png: Width = 512 px, Height = 512 px
# img278.png: Width = 512 px, Height = 512 px
# img279.png: Width = 512 px, Height = 512 px
# img28.png: Width = 512 px, Height = 512 px
# img280.png: Width = 512 px, Height = 512 px
# img281.png: Width = 512 px, Height = 512 px
# img282.png: Width = 512 px, Height = 512 px
# img283.png: Width = 512 px, Height = 512 px
# img284.png: Width = 512 px, Height = 512 px
# img285.png: Width = 512 px, Height = 512 px
# img286.png: Width = 512 px, Height = 512 px
# img287.png: Width = 512 px, Height = 512 px
# img288.png: Width = 512 px, Height = 512 px
# img289.png: Width = 512 px, Height = 512 px
# img29.png: Width = 512 px, Height = 512 px
# img290.png: Width = 512 px, Height = 512 px
# img291.png: Width = 512 px, Height = 512 px
# img292.png: Width = 512 px, Height = 512 px
# img293.png: Width = 512 px, Height = 512 px
# img294.png: Width = 512 px, Height = 512 px
# img295.png: Width = 512 px, Height = 512 px
# img296.png: Width = 512 px, Height = 512 px
# img297.png: Width = 512 px, Height = 512 px
# img298.png: Width = 512 px, Height = 512 px
# img299.png: Width = 512 px, Height = 512 px
# img3.png: Width = 512 px, Height = 512 px
# img30.png: Width = 512 px, Height = 512 px
# img300.png: Width = 512 px, Height = 512 px
# img301.png: Width = 512 px, Height = 512 px
# img302.png: Width = 512 px, Height = 512 px
# img303.png: Width = 512 px, Height = 512 px
# img304.png: Width = 512 px, Height = 512 px
# img305.png: Width = 512 px, Height = 512 px
# img306.png: Width = 512 px, Height = 512 px
# img307.png: Width = 512 px, Height = 512 px
# img308.png: Width = 512 px, Height = 512 px
# img309.png: Width = 512 px, Height = 512 px
# img31.png: Width = 512 px, Height = 512 px
# img32.png: Width = 512 px, Height = 512 px
# img33.png: Width = 512 px, Height = 512 px
# img34.png: Width = 512 px, Height = 512 px
# img35.png: Width = 512 px, Height = 512 px
# img36.png: Width = 512 px, Height = 512 px
# img37.png: Width = 512 px, Height = 512 px
# img38.png: Width = 512 px, Height = 512 px
# img39.png: Width = 512 px, Height = 512 px
# img4.png: Width = 512 px, Height = 512 px
# img40.png: Width = 512 px, Height = 512 px
# img41.png: Width = 512 px, Height = 512 px
# img42.png: Width = 512 px, Height = 512 px
# img43.png: Width = 512 px, Height = 512 px
# img44.png: Width = 512 px, Height = 512 px
# img45.png: Width = 512 px, Height = 512 px
# img46.png: Width = 512 px, Height = 512 px
# img47.png: Width = 512 px, Height = 512 px
# img48.png: Width = 512 px, Height = 512 px
# img49.png: Width = 512 px, Height = 512 px
# img5.png: Width = 512 px, Height = 512 px
# img50.png: Width = 512 px, Height = 512 px
# img51.png: Width = 512 px, Height = 512 px
# img52.png: Width = 512 px, Height = 512 px
# img53.png: Width = 512 px, Height = 512 px
# img54.png: Width = 512 px, Height = 512 px
# img55.png: Width = 512 px, Height = 512 px
# img56.png: Width = 512 px, Height = 512 px
# img57.png: Width = 512 px, Height = 512 px
# img58.png: Width = 512 px, Height = 512 px
# img59.png: Width = 512 px, Height = 512 px
# img6.png: Width = 512 px, Height = 512 px
# img60.png: Width = 512 px, Height = 512 px
# img61.png: Width = 512 px, Height = 512 px
# img62.png: Width = 512 px, Height = 512 px
# img63.png: Width = 512 px, Height = 512 px
# img64.png: Width = 512 px, Height = 512 px
# img65.png: Width = 512 px, Height = 512 px
# img66.png: Width = 512 px, Height = 512 px
# img67.png: Width = 512 px, Height = 512 px
# img68.png: Width = 512 px, Height = 512 px
# img69.png: Width = 512 px, Height = 512 px
# img7.png: Width = 512 px, Height = 512 px
# img70.png: Width = 512 px, Height = 512 px
# img71.png: Width = 512 px, Height = 512 px
# img72.png: Width = 512 px, Height = 512 px
# img73.png: Width = 512 px, Height = 512 px
# img74.png: Width = 512 px, Height = 512 px
# img75.png: Width = 512 px, Height = 512 px
# img76.png: Width = 512 px, Height = 512 px
# img77.png: Width = 512 px, Height = 512 px
# img78.png: Width = 512 px, Height = 512 px
# img79.png: Width = 512 px, Height = 512 px
# img8.png: Width = 512 px, Height = 512 px
# img80.png: Width = 512 px, Height = 512 px
# img81.png: Width = 512 px, Height = 512 px
# img82.png: Width = 512 px, Height = 512 px
# img83.png: Width = 512 px, Height = 512 px
# img84.png: Width = 512 px, Height = 512 px
# img85.png: Width = 512 px, Height = 512 px
# img86.png: Width = 512 px, Height = 512 px
# img87.png: Width = 512 px, Height = 512 px
# img88.png: Width = 512 px, Height = 512 px
# img89.png: Width = 512 px, Height = 512 px
# img9.png: Width = 512 px, Height = 512 px
# img90.png: Width = 512 px, Height = 512 px
# img91.png: Width = 512 px, Height = 512 px
# img92.png: Width = 512 px, Height = 512 px
# img93.png: Width = 512 px, Height = 512 px
# img94.png: Width = 512 px, Height = 512 px
# img95.png: Width = 512 px, Height = 512 px
# img96.png: Width = 512 px, Height = 512 px
# img97.png: Width = 512 px, Height = 512 px
# img98.png: Width = 512 px, Height = 512 px
# img99.png: Width = 512 px, Height = 512 px

# %%
import os
import cv2

# Specify the parent folder containing subfolders with images (defect1)
folder_parent = r'C:\Users\Global\Fabric project\WFDD\grey cloth\defect'  # Change as necessary

# Define valid image extensions
image_extensions = ('.jpg', '.jpeg', '.png', '.bmp', '.tif', '.tiff')

print("Image Sizes in the Folder:")

# Iterate over each subfolder in folder_parent
for subfolder in os.listdir(folder_parent):
    subfolder_path = os.path.join(folder_parent, subfolder)
    if os.path.isdir(subfolder_path):
        print(f"\nDefect Type: {subfolder}")
        # Iterate over all files in the subfolder
        for filename in os.listdir(subfolder_path):
            if filename.lower().endswith(image_extensions):
                image_path = os.path.join(subfolder_path, filename)
                image = cv2.imread(image_path)
                if image is not None:
                    # cv2 image shape returns (height, width, channels)
                    height, width = image.shape[:2]
                    print(f"{filename}: Width = {width} px, Height = {height} px")
                else:
                    print(f"Could not read {filename}")
# Out:
# Image Sizes in the Folder:
#
# Defect Type: contaminated
# 001.png: Width = 512 px, Height = 512 px
# 002.png: Width = 512 px, Height = 512 px
# 003.png: Width = 512 px, Height = 512 px
# 004.png: Width = 512 px, Height = 512 px
# 005.png: Width = 512 px, Height = 512 px
# 006.png: Width = 512 px, Height = 512 px
# 007.png: Width = 512 px, Height = 512 px
# 008.png: Width = 512 px, Height = 512 px
# 009.png: Width = 512 px, Height = 512 px
# 010.png: Width = 512 px, Height = 512 px
# 011.png: Width = 512 px, Height = 512 px
# 012.png: Width = 512 px, Height = 512 px
# 013.png: Width = 512 px, Height = 512 px
# 014.png: Width = 512 px, Height = 512 px
# 015.png: Width = 512 px, Height = 512 px
# 016.png: Width = 512 px, Height = 512 px
# 017.png: Width = 512 px, Height = 512 px
# 018.png: Width = 512 px, Height = 512 px
# 019.png: Width = 512 px, Height = 512 px
# 020.png: Width = 512 px, Height = 512 px
#
# Defect Type: flecked
# 001.png: Width = 512 px, Height = 512 px
# 002.png: Width = 512 px, Height = 512 px
# 003.png: Width = 512 px, Height = 512 px
# 004.png: Width = 512 px, Height = 512 px
# 005.png: Width = 512 px, Height = 512 px
# 006.png: Width = 512 px, Height = 512 px
# 007.png: Width = 512 px, Height = 512 px
# 008.png: Width = 512 px, Height = 512 px
# 009.png: Width = 512 px, Height = 512 px
# 010.png: Width = 512 px, Height = 512 px
# 011.png: Width = 512 px, Height = 512 px
# 012.png: Width = 512 px, Height = 512 px
# 013.png: Width = 512 px, Height = 512 px
# 014.png: Width = 512 px, Height = 512 px
#
# Defect Type: line
# 001.png: Width = 512 px, Height = 512 px
# 002.png: Width = 512 px, Height = 512 px
# 003.png: Width = 512 px, Height = 512 px
# 004.png: Width = 512 px, Height = 512 px
# 005.png: Width = 512 px, Height = 512 px
# 006.png: Width = 512 px, Height = 512 px
# 007.png: Width = 512 px, Height = 512 px
# 008.png: Width = 512 px, Height = 512 px
# 009.png: Width = 512 px, Height = 512 px
#
# Defect Type: string
# 001.png: Width = 512 px, Height = 512 px
# 002.png: Width = 512 px, Height = 512 px
# 003.png: Width = 512 px, Height = 512 px
# 004.png: Width = 512 px, Height = 512 px
# 005.png: Width = 512 px, Height = 512 px
# 006.png: Width = 512 px, Height = 512 px
# 007.png: Width = 512 px, Height = 512 px
# 008.png: Width = 512 px, Height = 512 px
# 009.png: Width = 512 px, Height = 512 px
# 010.png: Width = 512 px, Height = 512 px
# 011.png: Width = 512 px, Height = 512 px
# 012.png: Width = 512 px, Height = 512 px
# 013.png: Width = 512 px, Height = 512 px
# 014.png: Width = 512 px, Height = 512 px
# 015.png: Width = 512 px, Height = 512 px
# 016.png: Width = 512 px, Height = 512 px
