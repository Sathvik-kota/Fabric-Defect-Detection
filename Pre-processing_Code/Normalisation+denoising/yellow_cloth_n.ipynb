# %%
import os
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt

# Set paths
normal_folder =r'C:\Users\Global\Fabric project\WFDD\Yellow cloth\normal1'
defect_folder = r'C:\Users\Global\Fabric project\WFDD\Yellow cloth\defect1'

# Output folders for grayscale images
normal_gray_folder =r'C:\Users\Global\Fabric project\WFDD\Yellow cloth\normal_gray'
defect_gray_folder = r'C:\Users\Global\Fabric project\WFDD\Yellow cloth\defect_gray'

# Create grayscale folders if they don't exist
os.makedirs(normal_gray_folder, exist_ok=True)
os.makedirs(defect_gray_folder, exist_ok=True)

# Function to convert all images in a folder to grayscale
def convert_to_grayscale(input_folder, output_folder):
    for file in os.listdir(input_folder):
        img_path = os.path.join(input_folder, file)
        if file.lower().endswith(('.png', '.jpg', '.jpeg')):
            img = Image.open(img_path).convert('L')  # 'L' = grayscale
            img.save(os.path.join(output_folder, file))

# Convert all images
convert_to_grayscale(normal_folder, normal_gray_folder)
convert_to_grayscale(defect_folder, defect_gray_folder)

# Display first grayscale image from each folder
def display_and_print_details(folder_path, title):
    first_image_path = os.path.join(folder_path, os.listdir(folder_path)[0])
    img = Image.open(first_image_path)
    img_array = np.array(img)

    # Display image
    plt.imshow(img_array, cmap='gray')
    plt.title(f"{title} (Grayscale)")
    plt.axis('off')
    plt.show()

    # Print 3x3 pixel values and number of channels
    print(f"{title} - 3x3 Top-left Window Values:\n", img_array[:3, :3])
    print(f"{title} - Image shape: {img_array.shape}")
    print(f"{title} - Number of channels: {1 if len(img_array.shape)==2 else img_array.shape[2]}")
    print("-----\n")

# Apply display and info function
display_and_print_details(normal_gray_folder, "Normal Image")
display_and_print_details(defect_gray_folder, "Defect Image")
# Out:
# Normal Image - 3x3 Top-left Window Values:
#  [[223 228 225]
#  [207 214 219]
#  [199 205 213]]
# Normal Image - Image shape: (512, 512)
# Normal Image - Number of channels: 1
# -----
# Defect Image - 3x3 Top-left Window Values:
#  [[194 225 214]
#  [165 202 204]
#  [174 206 220]]
# Defect Image - Image shape: (512, 512)
# Defect Image - Number of channels: 1
# -----

# %%
import os
import numpy as np
from PIL import Image
import matplotlib.pyplot as plt

# Set paths to final grayscale image folders
normal_gray_folder =r'C:\Users\Global\Fabric project\WFDD\Yellow cloth\normal_gray'
defect_gray_folder = r'C:\Users\Global\Fabric project\WFDD\Yellow cloth\defect_gray'
# Output folders for normalized images
normal_normalized_folder =r'C:\Users\Global\Fabric project\WFDD\Yellow cloth\normal_normalized'
defect_normalized_folder =r'C:\Users\Global\Fabric project\WFDD\Yellow cloth\defect_normalized'

# Create normalized folders if they don't exist
os.makedirs(normal_normalized_folder, exist_ok=True)
os.makedirs(defect_normalized_folder, exist_ok=True)

# Function to normalize grayscale image
def normalize_image(image_array):
    return image_array / 255.0

# Function to process all images in a folder
def process_and_save_all_images(input_folder, output_folder, title):
    image_files = [f for f in os.listdir(input_folder) if f.lower().endswith(('.png', '.jpg', '.jpeg', '.bmp', '.tif'))]
    
    if not image_files:
        print(f"No image files found in {input_folder}")
        return
    
    for i, file_name in enumerate(image_files):
        file_path = os.path.join(input_folder, file_name)
        img = Image.open(file_path).convert('L')  # Ensure it's grayscale
        img_array = np.array(img)

        # Normalize
        normalized_array = normalize_image(img_array)

        # Save normalized image (convert back to 8-bit before saving)
        normalized_img = Image.fromarray((normalized_array * 255).astype(np.uint8))
        normalized_img.save(os.path.join(output_folder, file_name))

        # Display and print info for the first image only
        if i == 0:
            plt.imshow(normalized_array, cmap='gray')
            plt.title(f"{title} - First Image (Normalized)")
            plt.axis('off')
            plt.show()
            
            print(f"{title} - 3x3 Top-left Window (Normalized) Values:\n", normalized_array[:3, :3])
            print(f"{title} - Image shape: {normalized_array.shape}")
            print(f"{title} - Number of channels: {1 if len(normalized_array.shape)==2 else normalized_array.shape[2]}")
            print("-----\n")

    print(f"{title} - Total images processed and saved: {len(image_files)}\n")

# Process both normal and defect folders
process_and_save_all_images(normal_gray_folder, normal_normalized_folder, "Normal Image")
process_and_save_all_images(defect_gray_folder, defect_normalized_folder, "Defect Image")
# Out:
# Normal Image - 3x3 Top-left Window (Normalized) Values:
#  [[0.8745098  0.89411765 0.88235294]
#  [0.81176471 0.83921569 0.85882353]
#  [0.78039216 0.80392157 0.83529412]]
# Normal Image - Image shape: (512, 512)
# Normal Image - Number of channels: 1
# -----
#
# Normal Image - Total images processed and saved: 940
# Defect Image - 3x3 Top-left Window (Normalized) Values:
#  [[0.76078431 0.88235294 0.83921569]
#  [0.64705882 0.79215686 0.8       ]
#  [0.68235294 0.80784314 0.8627451 ]]
# Defect Image - Image shape: (512, 512)
# Defect Image - Number of channels: 1
# -----
#
# Defect Image - Total images processed and saved: 95

# %%
import os
import cv2
import numpy as np
from skimage import restoration, img_as_float, img_as_ubyte
from skimage.metrics import peak_signal_noise_ratio as psnr, structural_similarity as ssim

# ===============================
# Step 1: Define Folder Paths
# ===============================
normal_input_folder = r'C:\Users\Global\Fabric project\WFDD\Yellow cloth\normal_normalized'
defect_input_folder = r'C:\Users\Global\Fabric project\WFDD\Yellow cloth\defect_normalized'

normal_output_folder = r'C:\Users\Global\Fabric project\WFDD\Yellow cloth\denoised_normal'
defect_output_folder = r'C:\Users\Global\Fabric project\WFDD\Yellow cloth\denoised_defect'

# Create output folders if they don't exist
os.makedirs(normal_output_folder, exist_ok=True)
os.makedirs(defect_output_folder, exist_ok=True)

# ===============================
# Step 2: Define a Function to Process a Folder
# ===============================
def process_folder(input_folder, output_folder):
    """
    Process each image in the input folder (already normalized grayscale images):
    - Apply wavelet denoising using BayesShrink.
    - Compute PSNR and SSIM metrics.
    - Save the denoised image to the output folder.
    """
    # Define valid image extensions
    image_extensions = ('.png', '.jpg', '.jpeg', '.bmp', '.tif', '.tiff')
    files = [f for f in os.listdir(input_folder) if f.lower().endswith(image_extensions)]

    print(f"Found {len(files)} images in {input_folder}...\n")
    
    # Check if any image files are found
    if len(files) == 0:
        print(f"No image files found in folder: {input_folder}")
        return
    
    for file in files:
        input_path = os.path.join(input_folder, file)
        output_path = os.path.join(output_folder, file)
        
        # Load the normalized grayscale image.
        img = cv2.imread(input_path, cv2.IMREAD_GRAYSCALE)
        
        if img is None:
            print(f"Error reading image: {file}. Skipping...")
            continue
        
        img_float = img_as_float(img)  # Now pixel values are in the range [0, 1]
        
        # Apply Wavelet Denoising using BayesShrink
        denoised = restoration.denoise_wavelet(
            img_float, 
            method='BayesShrink', 
            mode='soft', 
            rescale_sigma=True
        )
        
        # Compute PSNR and SSIM
        psnr_value = psnr(img_float, denoised, data_range=1.0)
        ssim_value = ssim(img_float, denoised, data_range=1.0)
        
        # Print PSNR and SSIM values
        print(f"Processing '{file}'")
        print(f"PSNR: {psnr_value:.2f} dB, SSIM: {ssim_value:.4f}\n")
        
        # Clip and save the denoised image
        denoised_clipped = np.clip(denoised, 0, 1)
        denoised_uint8 = img_as_ubyte(denoised_clipped)
        
        # Saving the denoised image
        try:
            success = cv2.imwrite(output_path, denoised_uint8)
            if success:
                print(f"Successfully saved: {file}")
            else:
                print(f"Failed to save: {file}")
        except Exception as e:
            print(f"Error saving image {file}: {e}")

# ===============================
# Step 6: Process Both Folders
# ===============================
print("Processing Normal Images...\n")
process_folder(normal_input_folder, normal_output_folder)
print("Processing Defective Images...\n")
process_folder(defect_input_folder, defect_output_folder)
# Out:
# Processing Normal Images...
#
# Found 940 images in C:\Users\Global\Fabric project\WFDD\Yellow cloth\normal_normalized...
#
# Processing 'img1.png'
# PSNR: 43.92 dB, SSIM: 0.9859
#
# Successfully saved: img1.png
# Processing 'img10.png'
# PSNR: 41.66 dB, SSIM: 0.9823
#
# Successfully saved: img10.png
# Processing 'img100.png'
# PSNR: 42.47 dB, SSIM: 0.9871
#
# Successfully saved: img100.png
# Processing 'img1000.png'
# PSNR: 34.40 dB, SSIM: 0.9632
#
# Successfully saved: img1000.png
# Processing 'img1001.png'
# PSNR: 41.23 dB, SSIM: 0.9755
#
# Successfully saved: img1001.png
# Processing 'img1002.png'
# PSNR: 39.52 dB, SSIM: 0.9644
#
# Successfully saved: img1002.png
# Processing 'img1003.png'
# PSNR: 39.16 dB, SSIM: 0.9613
#
# Successfully saved: img1003.png
# Processing 'img1004.png'
# PSNR: 39.07 dB, SSIM: 0.9613
#
# Successfully saved: img1004.png
# Processing 'img1005.png'
# PSNR: 39.79 dB, SSIM: 0.9667
#
# Successfully saved: img1005.png
# Processing 'img1006.png'
# PSNR: 36.45 dB, SSIM: 0.9661
#
# Successfully saved: img1006.png
# Processing 'img1007.png'
# PSNR: 38.01 dB, SSIM: 0.9539
#
# Successfully saved: img1007.png
# Processing 'img1008.png'
# PSNR: 33.34 dB, SSIM: 0.9441
#
# Successfully saved: img1008.png
# Processing 'img1009.png'
# PSNR: 32.37 dB, SSIM: 0.9328
#
# Successfully saved: img1009.png
# Processing 'img101.png'
# PSNR: 37.47 dB, SSIM: 0.9668
#
# Successfully saved: img101.png
# Processing 'img1010.png'
# PSNR: 31.77 dB, SSIM: 0.9300
#
# Successfully saved: img1010.png
# Processing 'img1011.png'
# PSNR: 39.70 dB, SSIM: 0.9645
#
# Successfully saved: img1011.png
# Processing 'img1012.png'
# PSNR: 39.40 dB, SSIM: 0.9645
#
# Successfully saved: img1012.png
# Processing 'img1013.png'
# PSNR: 37.88 dB, SSIM: 0.9481
#
# Successfully saved: img1013.png
# Processing 'img1014.png'
# PSNR: 37.82 dB, SSIM: 0.9478
#
# Successfully saved: img1014.png
# Processing 'img1015.png'
# PSNR: 39.93 dB, SSIM: 0.9685
#
# Successfully saved: img1015.png
# Processing 'img1016.png'
# PSNR: 39.71 dB, SSIM: 0.9683
#
# Successfully saved: img1016.png
# Processing 'img1017.png'
# PSNR: 36.51 dB, SSIM: 0.9746
#
# Successfully saved: img1017.png
# Processing 'img1018.png'
# PSNR: 38.22 dB, SSIM: 0.9571
#
# Successfully saved: img1018.png
# Processing 'img1019.png'
# PSNR: 38.23 dB, SSIM: 0.9608
#
# Successfully saved: img1019.png
# Processing 'img102.png'
# PSNR: 40.75 dB, SSIM: 0.9839
#
# Successfully saved: img102.png
# Processing 'img1020.png'
# PSNR: 33.65 dB, SSIM: 0.9507
#
# Successfully saved: img1020.png
# Processing 'img1021.png'
# PSNR: 39.96 dB, SSIM: 0.9671
#
# Successfully saved: img1021.png
# Processing 'img1022.png'
# PSNR: 39.68 dB, SSIM: 0.9667
#
# Successfully saved: img1022.png
# Processing 'img1023.png'
# PSNR: 39.47 dB, SSIM: 0.9656
#
# Successfully saved: img1023.png
# Processing 'img1024.png'
# PSNR: 38.07 dB, SSIM: 0.9528
#
# Successfully saved: img1024.png
# Processing 'img1025.png'
# PSNR: 39.69 dB, SSIM: 0.9692
#
# Successfully saved: img1025.png
# Processing 'img1026.png'
# PSNR: 33.63 dB, SSIM: 0.9511
#
# Successfully saved: img1026.png
# Processing 'img1027.png'
# PSNR: 39.76 dB, SSIM: 0.9664
#
# Successfully saved: img1027.png
# Processing 'img1028.png'
# PSNR: 40.12 dB, SSIM: 0.9737
#
# Successfully saved: img1028.png
# Processing 'img1029.png'
# PSNR: 38.18 dB, SSIM: 0.9541
#
# Successfully saved: img1029.png
# Processing 'img103.png'
# PSNR: 39.40 dB, SSIM: 0.9807
#
# Successfully saved: img103.png
# Processing 'img1030.png'
# PSNR: 39.90 dB, SSIM: 0.9668
#
# Successfully saved: img1030.png
# Processing 'img1031.png'
# PSNR: 39.66 dB, SSIM: 0.9682
#
# Successfully saved: img1031.png
# Processing 'img1032.png'
# PSNR: 39.79 dB, SSIM: 0.9681
#
# Successfully saved: img1032.png
# Processing 'img1033.png'
# PSNR: 41.92 dB, SSIM: 0.9842
#
# Successfully saved: img1033.png
# Processing 'img1034.png'
# PSNR: 36.35 dB, SSIM: 0.9628
#
# Successfully saved: img1034.png
# Processing 'img1035.png'
# PSNR: 40.84 dB, SSIM: 0.9815
#
# Successfully saved: img1035.png
# Processing 'img1036.png'
# PSNR: 36.49 dB, SSIM: 0.9676
#
# Successfully saved: img1036.png
# Processing 'img1037.png'
# PSNR: 36.45 dB, SSIM: 0.9668
#
# Successfully saved: img1037.png
# Processing 'img1038.png'
# PSNR: 36.51 dB, SSIM: 0.9709
#
# Successfully saved: img1038.png
# Processing 'img1039.png'
# PSNR: 38.64 dB, SSIM: 0.9671
#
# Successfully saved: img1039.png
# Processing 'img104.png'
# PSNR: 34.64 dB, SSIM: 0.9632
#
# Successfully saved: img104.png
# Processing 'img1040.png'
# PSNR: 35.72 dB, SSIM: 0.9672
#
# Successfully saved: img1040.png
# Processing 'img1041.png'
# PSNR: 40.35 dB, SSIM: 0.9757
#
# Successfully saved: img1041.png
# Processing 'img1042.png'
# PSNR: 42.30 dB, SSIM: 0.9865
#
# Successfully saved: img1042.png
# Processing 'img1043.png'
# PSNR: 41.56 dB, SSIM: 0.9794
#
# Successfully saved: img1043.png
# Processing 'img1044.png'
# PSNR: 40.60 dB, SSIM: 0.9831
#
# Successfully saved: img1044.png
# Processing 'img105.png'
# PSNR: 35.87 dB, SSIM: 0.9703
#
# Successfully saved: img105.png
# Processing 'img106.png'
# PSNR: 36.85 dB, SSIM: 0.9733
#
# Successfully saved: img106.png
# Processing 'img107.png'
# PSNR: 42.43 dB, SSIM: 0.9874
#
# Successfully saved: img107.png
# Processing 'img108.png'
# PSNR: 40.85 dB, SSIM: 0.9841
#
# Successfully saved: img108.png
# Processing 'img109.png'
# PSNR: 34.63 dB, SSIM: 0.9598
#
# Successfully saved: img109.png
# Processing 'img11.png'
# PSNR: 39.95 dB, SSIM: 0.9778
#
# Successfully saved: img11.png
# Processing 'img110.png'
# PSNR: 37.94 dB, SSIM: 0.9756
#
# Successfully saved: img110.png
# Processing 'img111.png'
# PSNR: 34.58 dB, SSIM: 0.9594
#
# Successfully saved: img111.png
# Processing 'img112.png'
# PSNR: 41.90 dB, SSIM: 0.9784
#
# Successfully saved: img112.png
# Processing 'img113.png'
# PSNR: 42.34 dB, SSIM: 0.9859
#
# Successfully saved: img113.png
# Processing 'img114.png'
# PSNR: 32.86 dB, SSIM: 0.9491
#
# Successfully saved: img114.png
# Processing 'img115.png'
# PSNR: 41.77 dB, SSIM: 0.9827
#
# Successfully saved: img115.png
# Processing 'img116.png'
# PSNR: 37.75 dB, SSIM: 0.9773
#
# Successfully saved: img116.png
# Processing 'img117.png'
# PSNR: 40.82 dB, SSIM: 0.9814
#
# Successfully saved: img117.png
# Processing 'img118.png'
# PSNR: 39.35 dB, SSIM: 0.9773
#
# Successfully saved: img118.png
# Processing 'img119.png'
# PSNR: 38.15 dB, SSIM: 0.9737
#
# Successfully saved: img119.png
# Processing 'img12.png'
# PSNR: 38.48 dB, SSIM: 0.9729
#
# Successfully saved: img12.png
# Processing 'img120.png'
# PSNR: 36.94 dB, SSIM: 0.9696
#
# Successfully saved: img120.png
# Processing 'img121.png'
# PSNR: 33.67 dB, SSIM: 0.9551
#
# Successfully saved: img121.png
# Processing 'img122.png'
# PSNR: 41.81 dB, SSIM: 0.9802
#
# Successfully saved: img122.png
# Processing 'img123.png'
# PSNR: 40.11 dB, SSIM: 0.9752
#
# Successfully saved: img123.png
# Processing 'img124.png'
# PSNR: 34.93 dB, SSIM: 0.9652
#
# Successfully saved: img124.png
# Processing 'img125.png'
# PSNR: 38.63 dB, SSIM: 0.9717
#
# Successfully saved: img125.png
# Processing 'img126.png'
# PSNR: 33.51 dB, SSIM: 0.9510
#
# Successfully saved: img126.png
# Processing 'img127.png'
# PSNR: 32.71 dB, SSIM: 0.9443
#
# Successfully saved: img127.png
# Processing 'img13.png'
# PSNR: 40.22 dB, SSIM: 0.9766
#
# Successfully saved: img13.png
# Processing 'img131.png'
# PSNR: 37.53 dB, SSIM: 0.9710
#
# Successfully saved: img131.png
# Processing 'img132.png'
# PSNR: 44.05 dB, SSIM: 0.9889
#
# Successfully saved: img132.png
# Processing 'img133.png'
# PSNR: 40.74 dB, SSIM: 0.9805
#
# Successfully saved: img133.png
# Processing 'img134.png'
# PSNR: 39.25 dB, SSIM: 0.9765
#
# Successfully saved: img134.png
# Processing 'img135.png'
# PSNR: 35.84 dB, SSIM: 0.9658
#
# Successfully saved: img135.png
# Processing 'img136.png'
# PSNR: 38.02 dB, SSIM: 0.9726
#
# Successfully saved: img136.png
# Processing 'img137.png'
# PSNR: 36.85 dB, SSIM: 0.9688
#
# Successfully saved: img137.png
# Processing 'img14.png'
# PSNR: 37.14 dB, SSIM: 0.9674
#
# Successfully saved: img14.png
# Processing 'img140.png'
# PSNR: 32.52 dB, SSIM: 0.9333
#
# Successfully saved: img140.png
# Processing 'img141.png'
# PSNR: 32.44 dB, SSIM: 0.9341
#
# Successfully saved: img141.png
# Processing 'img142.png'
# PSNR: 31.70 dB, SSIM: 0.9269
#
# Successfully saved: img142.png
# Processing 'img143.png'
# PSNR: 31.86 dB, SSIM: 0.9354
#
# Successfully saved: img143.png
# Processing 'img144.png'
# PSNR: 37.89 dB, SSIM: 0.9714
#
# Successfully saved: img144.png
# Processing 'img145.png'
# PSNR: 36.74 dB, SSIM: 0.9683
#
# Successfully saved: img145.png
# Processing 'img146.png'
# PSNR: 34.73 dB, SSIM: 0.9608
#
# Successfully saved: img146.png
# Processing 'img147.png'
# PSNR: 32.70 dB, SSIM: 0.9444
#
# Successfully saved: img147.png
# Processing 'img148.png'
# PSNR: 32.82 dB, SSIM: 0.9504
#
# Successfully saved: img148.png
# Processing 'img149.png'
# PSNR: 37.43 dB, SSIM: 0.9680
#
# Successfully saved: img149.png
# Processing 'img15.png'
# PSNR: 46.04 dB, SSIM: 0.9919
#
# Successfully saved: img15.png
# Processing 'img150.png'
# PSNR: 32.37 dB, SSIM: 0.9432
#
# Successfully saved: img150.png
# Processing 'img151.png'
# PSNR: 40.67 dB, SSIM: 0.9798
#
# Successfully saved: img151.png
# Processing 'img152.png'
# PSNR: 43.78 dB, SSIM: 0.9888
#
# Successfully saved: img152.png
# Processing 'img153.png'
# PSNR: 41.63 dB, SSIM: 0.9849
#
# Successfully saved: img153.png
# Processing 'img154.png'
# PSNR: 40.43 dB, SSIM: 0.9787
#
# Successfully saved: img154.png
# Processing 'img155.png'
# PSNR: 31.72 dB, SSIM: 0.9278
#
# Successfully saved: img155.png
# Processing 'img156.png'
# PSNR: 34.80 dB, SSIM: 0.9700
#
# Successfully saved: img156.png
# Processing 'img157.png'
# PSNR: 41.59 dB, SSIM: 0.9781
#
# Successfully saved: img157.png
# Processing 'img158.png'
# PSNR: 44.48 dB, SSIM: 0.9898
#
# Successfully saved: img158.png
# Processing 'img159.png'
# PSNR: 33.94 dB, SSIM: 0.9635
#
# Successfully saved: img159.png
# Processing 'img16.png'
# PSNR: 43.84 dB, SSIM: 0.9870
#
# Successfully saved: img16.png
# Processing 'img160.png'
# PSNR: 40.28 dB, SSIM: 0.9748
#
# Successfully saved: img160.png
# Processing 'img161.png'
# PSNR: 38.72 dB, SSIM: 0.9715
#
# Successfully saved: img161.png
# Processing 'img162.png'
# PSNR: 37.90 dB, SSIM: 0.9782
#
# Successfully saved: img162.png
# Processing 'img163.png'
# PSNR: 33.77 dB, SSIM: 0.9598
#
# Successfully saved: img163.png
# Processing 'img164.png'
# PSNR: 38.20 dB, SSIM: 0.9625
#
# Successfully saved: img164.png
# Processing 'img165.png'
# PSNR: 38.08 dB, SSIM: 0.9748
#
# Successfully saved: img165.png
# Processing 'img166.png'
# PSNR: 37.00 dB, SSIM: 0.9721
#
# Successfully saved: img166.png
# Processing 'img167.png'
# PSNR: 35.92 dB, SSIM: 0.9730
#
# Successfully saved: img167.png
# Processing 'img168.png'
# PSNR: 40.61 dB, SSIM: 0.9795
#
# Successfully saved: img168.png
# Processing 'img169.png'
# PSNR: 33.95 dB, SSIM: 0.9585
#
# Successfully saved: img169.png
# Processing 'img17.png'
# PSNR: 37.38 dB, SSIM: 0.9669
#
# Successfully saved: img17.png
# Processing 'img170.png'
# PSNR: 34.76 dB, SSIM: 0.9605
#
# Successfully saved: img170.png
# Processing 'img171.png'
# PSNR: 40.55 dB, SSIM: 0.9815
#
# Successfully saved: img171.png
# Processing 'img172.png'
# PSNR: 31.99 dB, SSIM: 0.9427
#
# Successfully saved: img172.png
# Processing 'img173.png'
# PSNR: 39.77 dB, SSIM: 0.9700
#
# Successfully saved: img173.png
# Processing 'img174.png'
# PSNR: 34.63 dB, SSIM: 0.9602
#
# Successfully saved: img174.png
# Processing 'img175.png'
# PSNR: 36.71 dB, SSIM: 0.9660
#
# Successfully saved: img175.png
# Processing 'img176.png'
# PSNR: 40.46 dB, SSIM: 0.9809
#
# Successfully saved: img176.png
# Processing 'img177.png'
# PSNR: 42.17 dB, SSIM: 0.9817
#
# Successfully saved: img177.png
# Processing 'img178.png'
# PSNR: 40.20 dB, SSIM: 0.9745
#
# Successfully saved: img178.png
# Processing 'img179.png'
# PSNR: 42.50 dB, SSIM: 0.9872
#
# Successfully saved: img179.png
# Processing 'img18.png'
# PSNR: 37.13 dB, SSIM: 0.9659
#
# Successfully saved: img18.png
# Processing 'img180.png'
# PSNR: 38.53 dB, SSIM: 0.9673
#
# Successfully saved: img180.png
# Processing 'img181.png'
# PSNR: 37.37 dB, SSIM: 0.9677
#
# Successfully saved: img181.png
# Processing 'img182.png'
# PSNR: 37.94 dB, SSIM: 0.9749
#
# Successfully saved: img182.png
# Processing 'img183.png'
# PSNR: 40.82 dB, SSIM: 0.9824
#
# Successfully saved: img183.png
# Processing 'img184.png'
# PSNR: 32.73 dB, SSIM: 0.9461
#
# Successfully saved: img184.png
# Processing 'img185.png'
# PSNR: 40.54 dB, SSIM: 0.9815
#
# Successfully saved: img185.png
# Processing 'img186.png'
# PSNR: 31.85 dB, SSIM: 0.9359
#
# Successfully saved: img186.png
# Processing 'img187.png'
# PSNR: 32.00 dB, SSIM: 0.9433
#
# Successfully saved: img187.png
# Processing 'img188.png'
# PSNR: 35.84 dB, SSIM: 0.9688
#
# Successfully saved: img188.png
# Processing 'img189.png'
# PSNR: 34.77 dB, SSIM: 0.9651
#
# Successfully saved: img189.png
# Processing 'img19.png'
# PSNR: 37.03 dB, SSIM: 0.9667
#
# Successfully saved: img19.png
# Processing 'img190.png'
# PSNR: 44.85 dB, SSIM: 0.9895
#
# Successfully saved: img190.png
# Processing 'img191.png'
# PSNR: 32.99 dB, SSIM: 0.9476
#
# Successfully saved: img191.png
# Processing 'img192.png'
# PSNR: 31.91 dB, SSIM: 0.9371
#
# Successfully saved: img192.png
# Processing 'img193.png'
# PSNR: 32.02 dB, SSIM: 0.9441
#
# Successfully saved: img193.png
# Processing 'img194.png'
# PSNR: 46.57 dB, SSIM: 0.9927
#
# Successfully saved: img194.png
# Processing 'img195.png'
# PSNR: 44.44 dB, SSIM: 0.9885
#
# Successfully saved: img195.png
# Processing 'img196.png'
# PSNR: 40.13 dB, SSIM: 0.9723
#
# Successfully saved: img196.png
# Processing 'img197.png'
# PSNR: 38.50 dB, SSIM: 0.9662
#
# Successfully saved: img197.png
# Processing 'img198.png'
# PSNR: 40.65 dB, SSIM: 0.9825
#
# Successfully saved: img198.png
# Processing 'img199.png'
# PSNR: 44.42 dB, SSIM: 0.9902
#
# Successfully saved: img199.png
# Processing 'img2.png'
# PSNR: 38.01 dB, SSIM: 0.9750
#
# Successfully saved: img2.png
# Processing 'img20.png'
# PSNR: 42.58 dB, SSIM: 0.9866
#
# Successfully saved: img20.png
# Processing 'img200.png'
# PSNR: 32.75 dB, SSIM: 0.9474
#
# Successfully saved: img200.png
# Processing 'img201.png'
# PSNR: 36.38 dB, SSIM: 0.9622
#
# Successfully saved: img201.png
# Processing 'img202.png'
# PSNR: 32.89 dB, SSIM: 0.9525
#
# Successfully saved: img202.png
# Processing 'img203.png'
# PSNR: 32.21 dB, SSIM: 0.9476
#
# Successfully saved: img203.png
# Processing 'img204.png'
# PSNR: 44.40 dB, SSIM: 0.9888
#
# Successfully saved: img204.png
# Processing 'img205.png'
# PSNR: 41.85 dB, SSIM: 0.9823
#
# Successfully saved: img205.png
# Processing 'img206.png'
# PSNR: 38.81 dB, SSIM: 0.9682
#
# Successfully saved: img206.png
# Processing 'img207.png'
# PSNR: 32.67 dB, SSIM: 0.9459
#
# Successfully saved: img207.png
# Processing 'img208.png'
# PSNR: 32.12 dB, SSIM: 0.9456
#
# Successfully saved: img208.png
# Processing 'img209.png'
# PSNR: 46.30 dB, SSIM: 0.9914
#
# Successfully saved: img209.png
# Processing 'img21.png'
# PSNR: 34.20 dB, SSIM: 0.9560
#
# Successfully saved: img21.png
# Processing 'img210.png'
# PSNR: 43.96 dB, SSIM: 0.9869
#
# Successfully saved: img210.png
# Processing 'img211.png'
# PSNR: 41.42 dB, SSIM: 0.9778
#
# Successfully saved: img211.png
# Processing 'img212.png'
# PSNR: 36.35 dB, SSIM: 0.9657
#
# Successfully saved: img212.png
# Processing 'img213.png'
# PSNR: 37.84 dB, SSIM: 0.9505
#
# Successfully saved: img213.png
# Processing 'img214.png'
# PSNR: 36.21 dB, SSIM: 0.9318
#
# Successfully saved: img214.png
# Processing 'img215.png'
# PSNR: 31.60 dB, SSIM: 0.9242
#
# Successfully saved: img215.png
# Processing 'img216.png'
# PSNR: 30.98 dB, SSIM: 0.9260
#
# Successfully saved: img216.png
# Processing 'img217.png'
# PSNR: 33.76 dB, SSIM: 0.9613
#
# Successfully saved: img217.png
# Processing 'img218.png'
# PSNR: 33.12 dB, SSIM: 0.9587
#
# Successfully saved: img218.png
# Processing 'img219.png'
# PSNR: 49.68 dB, SSIM: 0.9961
#
# Successfully saved: img219.png
# Processing 'img22.png'
# PSNR: 33.43 dB, SSIM: 0.9531
#
# Successfully saved: img22.png
# Processing 'img220.png'
# PSNR: 47.10 dB, SSIM: 0.9938
#
# Successfully saved: img220.png
# Processing 'img221.png'
# PSNR: 44.31 dB, SSIM: 0.9890
#
# Successfully saved: img221.png
# Processing 'img222.png'
# PSNR: 40.51 dB, SSIM: 0.9775
#
# Successfully saved: img222.png
# Processing 'img223.png'
# PSNR: 41.29 dB, SSIM: 0.9770
#
# Successfully saved: img223.png
# Processing 'img224.png'
# PSNR: 44.17 dB, SSIM: 0.9868
#
# Successfully saved: img224.png
# Processing 'img225.png'
# PSNR: 31.76 dB, SSIM: 0.9317
#
# Successfully saved: img225.png
# Processing 'img226.png'
# PSNR: 32.09 dB, SSIM: 0.9456
#
# Successfully saved: img226.png
# Processing 'img227.png'
# PSNR: 43.66 dB, SSIM: 0.9868
#
# Successfully saved: img227.png
# Processing 'img228.png'
# PSNR: 40.06 dB, SSIM: 0.9727
#
# Successfully saved: img228.png
# Processing 'img229.png'
# PSNR: 31.25 dB, SSIM: 0.9332
#
# Successfully saved: img229.png
# Processing 'img23.png'
# PSNR: 40.42 dB, SSIM: 0.9774
#
# Successfully saved: img23.png
# Processing 'img230.png'
# PSNR: 49.81 dB, SSIM: 0.9965
#
# Successfully saved: img230.png
# Processing 'img231.png'
# PSNR: 40.21 dB, SSIM: 0.9776
#
# Successfully saved: img231.png
# Processing 'img232.png'
# PSNR: 32.68 dB, SSIM: 0.9464
#
# Successfully saved: img232.png
# Processing 'img233.png'
# PSNR: 31.95 dB, SSIM: 0.9392
#
# Successfully saved: img233.png
# Processing 'img234.png'
# PSNR: 32.13 dB, SSIM: 0.9470
#
# Successfully saved: img234.png
# Processing 'img235.png'
# PSNR: 41.93 dB, SSIM: 0.9788
#
# Successfully saved: img235.png
# Processing 'img236.png'
# PSNR: 49.74 dB, SSIM: 0.9964
#
# Successfully saved: img236.png
# Processing 'img237.png'
# PSNR: 46.15 dB, SSIM: 0.9921
#
# Successfully saved: img237.png
# Processing 'img238.png'
# PSNR: 43.71 dB, SSIM: 0.9870
#
# Successfully saved: img238.png
# Processing 'img239.png'
# PSNR: 31.93 dB, SSIM: 0.9406
#
# Successfully saved: img239.png
# Processing 'img240.png'
# PSNR: 31.31 dB, SSIM: 0.9356
#
# Successfully saved: img240.png
# Processing 'img241.png'
# PSNR: 47.15 dB, SSIM: 0.9935
#
# Successfully saved: img241.png
# Processing 'img242.png'
# PSNR: 44.19 dB, SSIM: 0.9874
#
# Successfully saved: img242.png
# Processing 'img243.png'
# PSNR: 42.10 dB, SSIM: 0.9812
#
# Successfully saved: img243.png
# Processing 'img244.png'
# PSNR: 38.08 dB, SSIM: 0.9719
#
# Successfully saved: img244.png
# Processing 'img245.png'
# PSNR: 36.94 dB, SSIM: 0.9693
#
# Successfully saved: img245.png
# Processing 'img246.png'
# PSNR: 40.05 dB, SSIM: 0.9710
#
# Successfully saved: img246.png
# Processing 'img247.png'
# PSNR: 35.81 dB, SSIM: 0.9634
#
# Successfully saved: img247.png
# Processing 'img248.png'
# PSNR: 32.80 dB, SSIM: 0.9463
#
# Successfully saved: img248.png
# Processing 'img249.png'
# PSNR: 31.95 dB, SSIM: 0.9383
#
# Successfully saved: img249.png
# Processing 'img25.png'
# PSNR: 41.91 dB, SSIM: 0.9788
#
# Successfully saved: img25.png
# Processing 'img250.png'
# PSNR: 32.00 dB, SSIM: 0.9414
#
# Successfully saved: img250.png
# Processing 'img251.png'
# PSNR: 32.16 dB, SSIM: 0.9484
#
# Successfully saved: img251.png
# Processing 'img252.png'
# PSNR: 39.12 dB, SSIM: 0.9752
#
# Successfully saved: img252.png
# Processing 'img253.png'
# PSNR: 32.74 dB, SSIM: 0.9486
#
# Successfully saved: img253.png
# Processing 'img254.png'
# PSNR: 32.01 dB, SSIM: 0.9419
#
# Successfully saved: img254.png
# Processing 'img255.png'
# PSNR: 32.15 dB, SSIM: 0.9486
#
# Successfully saved: img255.png
# Processing 'img256.png'
# PSNR: 32.76 dB, SSIM: 0.9445
#
# Successfully saved: img256.png
# Processing 'img257.png'
# PSNR: 38.38 dB, SSIM: 0.9604
#
# Successfully saved: img257.png
# Processing 'img258.png'
# PSNR: 32.71 dB, SSIM: 0.9477
#
# Successfully saved: img258.png
# Processing 'img259.png'
# PSNR: 35.67 dB, SSIM: 0.9714
#
# Successfully saved: img259.png
# Processing 'img26.png'
# PSNR: 44.10 dB, SSIM: 0.9907
#
# Successfully saved: img26.png
# Processing 'img260.png'
# PSNR: 34.91 dB, SSIM: 0.9678
#
# Successfully saved: img260.png
# Processing 'img261.png'
# PSNR: 35.66 dB, SSIM: 0.9711
#
# Successfully saved: img261.png
# Processing 'img262.png'
# PSNR: 33.74 dB, SSIM: 0.9555
#
# Successfully saved: img262.png
# Processing 'img263.png'
# PSNR: 33.79 dB, SSIM: 0.9592
#
# Successfully saved: img263.png
# Processing 'img264.png'
# PSNR: 33.10 dB, SSIM: 0.9554
#
# Successfully saved: img264.png
# Processing 'img265.png'
# PSNR: 36.81 dB, SSIM: 0.9744
#
# Successfully saved: img265.png
# Processing 'img266.png'
# PSNR: 34.01 dB, SSIM: 0.9632
#
# Successfully saved: img266.png
# Processing 'img267.png'
# PSNR: 38.05 dB, SSIM: 0.9794
#
# Successfully saved: img267.png
# Processing 'img268.png'
# PSNR: 42.20 dB, SSIM: 0.9864
#
# Successfully saved: img268.png
# Processing 'img269.png'
# PSNR: 42.09 dB, SSIM: 0.9867
#
# Successfully saved: img269.png
# Processing 'img27.png'
# PSNR: 44.26 dB, SSIM: 0.9892
#
# Successfully saved: img27.png
# Processing 'img270.png'
# PSNR: 38.11 dB, SSIM: 0.9760
#
# Successfully saved: img270.png
# Processing 'img271.png'
# PSNR: 36.83 dB, SSIM: 0.9705
#
# Successfully saved: img271.png
# Processing 'img272.png'
# PSNR: 36.55 dB, SSIM: 0.9694
#
# Successfully saved: img272.png
# Processing 'img273.png'
# PSNR: 35.58 dB, SSIM: 0.9656
#
# Successfully saved: img273.png
# Processing 'img274.png'
# PSNR: 42.78 dB, SSIM: 0.9886
#
# Successfully saved: img274.png
# Processing 'img275.png'
# PSNR: 43.85 dB, SSIM: 0.9895
#
# Successfully saved: img275.png
# Processing 'img276.png'
# PSNR: 37.02 dB, SSIM: 0.9766
#
# Successfully saved: img276.png
# Processing 'img277.png'
# PSNR: 42.65 dB, SSIM: 0.9882
#
# Successfully saved: img277.png
# Processing 'img278.png'
# PSNR: 38.99 dB, SSIM: 0.9774
#
# Successfully saved: img278.png
# Processing 'img279.png'
# PSNR: 35.26 dB, SSIM: 0.9585
#
# Successfully saved: img279.png
# Processing 'img28.png'
# PSNR: 42.46 dB, SSIM: 0.9854
#
# Successfully saved: img28.png
# Processing 'img280.png'
# PSNR: 36.35 dB, SSIM: 0.9686
#
# Successfully saved: img280.png
# Processing 'img281.png'
# PSNR: 46.23 dB, SSIM: 0.9923
#
# Successfully saved: img281.png
# Processing 'img282.png'
# PSNR: 42.17 dB, SSIM: 0.9856
#
# Successfully saved: img282.png
# Processing 'img283.png'
# PSNR: 40.49 dB, SSIM: 0.9820
#
# Successfully saved: img283.png
# Processing 'img284.png'
# PSNR: 38.98 dB, SSIM: 0.9781
#
# Successfully saved: img284.png
# Processing 'img285.png'
# PSNR: 36.21 dB, SSIM: 0.9672
#
# Successfully saved: img285.png
# Processing 'img286.png'
# PSNR: 39.54 dB, SSIM: 0.9808
#
# Successfully saved: img286.png
# Processing 'img287.png'
# PSNR: 42.67 dB, SSIM: 0.9876
#
# Successfully saved: img287.png
# Processing 'img288.png'
# PSNR: 46.46 dB, SSIM: 0.9933
#
# Successfully saved: img288.png
# Processing 'img289.png'
# PSNR: 44.08 dB, SSIM: 0.9890
#
# Successfully saved: img289.png
# Processing 'img29.png'
# PSNR: 41.82 dB, SSIM: 0.9853
#
# Successfully saved: img29.png
# Processing 'img290.png'
# PSNR: 46.50 dB, SSIM: 0.9929
#
# Successfully saved: img290.png
# Processing 'img291.png'
# PSNR: 42.36 dB, SSIM: 0.9847
#
# Successfully saved: img291.png
# Processing 'img292.png'
# PSNR: 40.59 dB, SSIM: 0.9803
#
# Successfully saved: img292.png
# Processing 'img293.png'
# PSNR: 39.08 dB, SSIM: 0.9761
#
# Successfully saved: img293.png
# Processing 'img294.png'
# PSNR: 37.37 dB, SSIM: 0.9686
#
# Successfully saved: img294.png
# Processing 'img295.png'
# PSNR: 37.29 dB, SSIM: 0.9668
#
# Successfully saved: img295.png
# Processing 'img296.png'
# PSNR: 37.25 dB, SSIM: 0.9699
#
# Successfully saved: img296.png
# Processing 'img297.png'
# PSNR: 36.30 dB, SSIM: 0.9663
#
# Successfully saved: img297.png
# Processing 'img298.png'
# PSNR: 43.89 dB, SSIM: 0.9906
#
# Successfully saved: img298.png
# Processing 'img299.png'
# PSNR: 42.91 dB, SSIM: 0.9886
#
# Successfully saved: img299.png
# Processing 'img3.png'
# PSNR: 42.14 dB, SSIM: 0.9830
#
# Successfully saved: img3.png
# Processing 'img30.png'
# PSNR: 40.26 dB, SSIM: 0.9816
#
# Successfully saved: img30.png
# Processing 'img300.png'
# PSNR: 44.87 dB, SSIM: 0.9908
#
# Successfully saved: img300.png
# Processing 'img301.png'
# PSNR: 44.34 dB, SSIM: 0.9884
#
# Successfully saved: img301.png
# Processing 'img302.png'
# PSNR: 44.19 dB, SSIM: 0.9897
#
# Successfully saved: img302.png
# Processing 'img303.png'
# PSNR: 42.46 dB, SSIM: 0.9856
#
# Successfully saved: img303.png
# Processing 'img304.png'
# PSNR: 39.15 dB, SSIM: 0.9769
#
# Successfully saved: img304.png
# Processing 'img305.png'
# PSNR: 37.72 dB, SSIM: 0.9716
#
# Successfully saved: img305.png
# Processing 'img306.png'
# PSNR: 37.02 dB, SSIM: 0.9756
#
# Successfully saved: img306.png
# Processing 'img307.png'
# PSNR: 37.15 dB, SSIM: 0.9748
#
# Successfully saved: img307.png
# Processing 'img308.png'
# PSNR: 42.66 dB, SSIM: 0.9878
#
# Successfully saved: img308.png
# Processing 'img309.png'
# PSNR: 43.91 dB, SSIM: 0.9890
#
# Successfully saved: img309.png
# Processing 'img31.png'
# PSNR: 38.87 dB, SSIM: 0.9779
#
# Successfully saved: img31.png
# Processing 'img310.png'
# PSNR: 42.16 dB, SSIM: 0.9843
#
# Successfully saved: img310.png
# Processing 'img311.png'
# PSNR: 38.84 dB, SSIM: 0.9741
#
# Successfully saved: img311.png
# Processing 'img312.png'
# PSNR: 42.06 dB, SSIM: 0.9815
#
# Successfully saved: img312.png
# Processing 'img313.png'
# PSNR: 36.10 dB, SSIM: 0.9574
#
# Successfully saved: img313.png
# Processing 'img314.png'
# PSNR: 35.07 dB, SSIM: 0.9478
#
# Successfully saved: img314.png
# Processing 'img315.png'
# PSNR: 37.27 dB, SSIM: 0.9769
#
# Successfully saved: img315.png
# Processing 'img316.png'
# PSNR: 43.00 dB, SSIM: 0.9887
#
# Successfully saved: img316.png
# Processing 'img317.png'
# PSNR: 44.24 dB, SSIM: 0.9906
#
# Successfully saved: img317.png
# Processing 'img318.png'
# PSNR: 42.63 dB, SSIM: 0.9867
#
# Successfully saved: img318.png
# Processing 'img319.png'
# PSNR: 39.31 dB, SSIM: 0.9783
#
# Successfully saved: img319.png
# Processing 'img32.png'
# PSNR: 38.47 dB, SSIM: 0.9770
#
# Successfully saved: img32.png
# Processing 'img320.png'
# PSNR: 38.01 dB, SSIM: 0.9729
#
# Successfully saved: img320.png
# Processing 'img321.png'
# PSNR: 37.72 dB, SSIM: 0.9731
#
# Successfully saved: img321.png
# Processing 'img322.png'
# PSNR: 37.62 dB, SSIM: 0.9717
#
# Successfully saved: img322.png
# Processing 'img323.png'
# PSNR: 40.07 dB, SSIM: 0.9734
#
# Successfully saved: img323.png
# Processing 'img324.png'
# PSNR: 37.58 dB, SSIM: 0.9738
#
# Successfully saved: img324.png
# Processing 'img325.png'
# PSNR: 36.61 dB, SSIM: 0.9712
#
# Successfully saved: img325.png
# Processing 'img326.png'
# PSNR: 46.32 dB, SSIM: 0.9930
#
# Successfully saved: img326.png
# Processing 'img327.png'
# PSNR: 44.28 dB, SSIM: 0.9882
#
# Successfully saved: img327.png
# Processing 'img328.png'
# PSNR: 46.47 dB, SSIM: 0.9934
#
# Successfully saved: img328.png
# Processing 'img329.png'
# PSNR: 44.53 dB, SSIM: 0.9903
#
# Successfully saved: img329.png
# Processing 'img33.png'
# PSNR: 37.48 dB, SSIM: 0.9717
#
# Successfully saved: img33.png
# Processing 'img330.png'
# PSNR: 39.43 dB, SSIM: 0.9788
#
# Successfully saved: img330.png
# Processing 'img331.png'
# PSNR: 38.96 dB, SSIM: 0.9789
#
# Successfully saved: img331.png
# Processing 'img332.png'
# PSNR: 37.65 dB, SSIM: 0.9724
#
# Successfully saved: img332.png
# Processing 'img333.png'
# PSNR: 36.65 dB, SSIM: 0.9677
#
# Successfully saved: img333.png
# Processing 'img334.png'
# PSNR: 37.79 dB, SSIM: 0.9781
#
# Successfully saved: img334.png
# Processing 'img335.png'
# PSNR: 35.26 dB, SSIM: 0.9551
#
# Successfully saved: img335.png
# Processing 'img336.png'
# PSNR: 36.68 dB, SSIM: 0.9733
#
# Successfully saved: img336.png
# Processing 'img337.png'
# PSNR: 37.10 dB, SSIM: 0.9760
#
# Successfully saved: img337.png
# Processing 'img338.png'
# PSNR: 42.76 dB, SSIM: 0.9879
#
# Successfully saved: img338.png
# Processing 'img339.png'
# PSNR: 44.72 dB, SSIM: 0.9905
#
# Successfully saved: img339.png
# Processing 'img34.png'
# PSNR: 37.29 dB, SSIM: 0.9755
#
# Successfully saved: img34.png
# Processing 'img340.png'
# PSNR: 43.87 dB, SSIM: 0.9895
#
# Successfully saved: img340.png
# Processing 'img341.png'
# PSNR: 42.22 dB, SSIM: 0.9855
#
# Successfully saved: img341.png
# Processing 'img342.png'
# PSNR: 40.54 dB, SSIM: 0.9812
#
# Successfully saved: img342.png
# Processing 'img343.png'
# PSNR: 39.11 dB, SSIM: 0.9778
#
# Successfully saved: img343.png
# Processing 'img344.png'
# PSNR: 37.74 dB, SSIM: 0.9709
#
# Successfully saved: img344.png
# Processing 'img345.png'
# PSNR: 37.49 dB, SSIM: 0.9697
#
# Successfully saved: img345.png
# Processing 'img346.png'
# PSNR: 34.41 dB, SSIM: 0.9503
#
# Successfully saved: img346.png
# Processing 'img347.png'
# PSNR: 37.32 dB, SSIM: 0.9673
#
# Successfully saved: img347.png
# Processing 'img348.png'
# PSNR: 40.51 dB, SSIM: 0.9789
#
# Successfully saved: img348.png
# Processing 'img349.png'
# PSNR: 37.23 dB, SSIM: 0.9670
#
# Successfully saved: img349.png
# Processing 'img35.png'
# PSNR: 41.61 dB, SSIM: 0.9792
#
# Successfully saved: img35.png
# Processing 'img350.png'
# PSNR: 44.64 dB, SSIM: 0.9893
#
# Successfully saved: img350.png
# Processing 'img351.png'
# PSNR: 43.76 dB, SSIM: 0.9881
#
# Successfully saved: img351.png
# Processing 'img352.png'
# PSNR: 42.15 dB, SSIM: 0.9842
#
# Successfully saved: img352.png
# Processing 'img353.png'
# PSNR: 40.53 dB, SSIM: 0.9795
#
# Successfully saved: img353.png
# Processing 'img354.png'
# PSNR: 37.60 dB, SSIM: 0.9669
#
# Successfully saved: img354.png
# Processing 'img355.png'
# PSNR: 37.28 dB, SSIM: 0.9654
#
# Successfully saved: img355.png
# Processing 'img356.png'
# PSNR: 37.14 dB, SSIM: 0.9670
#
# Successfully saved: img356.png
# Processing 'img357.png'
# PSNR: 42.45 dB, SSIM: 0.9866
#
# Successfully saved: img357.png
# Processing 'img358.png'
# PSNR: 36.22 dB, SSIM: 0.9647
#
# Successfully saved: img358.png
# Processing 'img359.png'
# PSNR: 40.73 dB, SSIM: 0.9803
#
# Successfully saved: img359.png
# Processing 'img36.png'
# PSNR: 36.35 dB, SSIM: 0.9743
#
# Successfully saved: img36.png
# Processing 'img360.png'
# PSNR: 39.21 dB, SSIM: 0.9755
#
# Successfully saved: img360.png
# Processing 'img361.png'
# PSNR: 38.89 dB, SSIM: 0.9754
#
# Successfully saved: img361.png
# Processing 'img362.png'
# PSNR: 37.62 dB, SSIM: 0.9674
#
# Successfully saved: img362.png
# Processing 'img363.png'
# PSNR: 37.49 dB, SSIM: 0.9695
#
# Successfully saved: img363.png
# Processing 'img364.png'
# PSNR: 44.56 dB, SSIM: 0.9895
#
# Successfully saved: img364.png
# Processing 'img365.png'
# PSNR: 43.80 dB, SSIM: 0.9871
#
# Successfully saved: img365.png
# Processing 'img366.png'
# PSNR: 37.23 dB, SSIM: 0.9770
#
# Successfully saved: img366.png
# Processing 'img367.png'
# PSNR: 42.93 dB, SSIM: 0.9886
#
# Successfully saved: img367.png
# Processing 'img368.png'
# PSNR: 44.68 dB, SSIM: 0.9883
#
# Successfully saved: img368.png
# Processing 'img369.png'
# PSNR: 44.35 dB, SSIM: 0.9889
#
# Successfully saved: img369.png
# Processing 'img37.png'
# PSNR: 41.36 dB, SSIM: 0.9819
#
# Successfully saved: img37.png
# Processing 'img370.png'
# PSNR: 42.45 dB, SSIM: 0.9845
#
# Successfully saved: img370.png
# Processing 'img371.png'
# PSNR: 37.74 dB, SSIM: 0.9682
#
# Successfully saved: img371.png
# Processing 'img372.png'
# PSNR: 39.39 dB, SSIM: 0.9803
#
# Successfully saved: img372.png
# Processing 'img373.png'
# PSNR: 42.65 dB, SSIM: 0.9875
#
# Successfully saved: img373.png
# Processing 'img374.png'
# PSNR: 46.40 dB, SSIM: 0.9932
#
# Successfully saved: img374.png
# Processing 'img375.png'
# PSNR: 41.25 dB, SSIM: 0.9764
#
# Successfully saved: img375.png
# Processing 'img376.png'
# PSNR: 37.03 dB, SSIM: 0.9753
#
# Successfully saved: img376.png
# Processing 'img377.png'
# PSNR: 42.63 dB, SSIM: 0.9876
#
# Successfully saved: img377.png
# Processing 'img378.png'
# PSNR: 43.95 dB, SSIM: 0.9884
#
# Successfully saved: img378.png
# Processing 'img379.png'
# PSNR: 43.79 dB, SSIM: 0.9860
#
# Successfully saved: img379.png
# Processing 'img38.png'
# PSNR: 43.30 dB, SSIM: 0.9848
#
# Successfully saved: img38.png
# Processing 'img380.png'
# PSNR: 42.12 dB, SSIM: 0.9845
#
# Successfully saved: img380.png
# Processing 'img381.png'
# PSNR: 40.46 dB, SSIM: 0.9796
#
# Successfully saved: img381.png
# Processing 'img382.png'
# PSNR: 37.52 dB, SSIM: 0.9685
#
# Successfully saved: img382.png
# Processing 'img383.png'
# PSNR: 37.35 dB, SSIM: 0.9671
#
# Successfully saved: img383.png
# Processing 'img384.png'
# PSNR: 36.33 dB, SSIM: 0.9660
#
# Successfully saved: img384.png
# Processing 'img385.png'
# PSNR: 44.35 dB, SSIM: 0.9892
#
# Successfully saved: img385.png
# Processing 'img386.png'
# PSNR: 43.65 dB, SSIM: 0.9869
#
# Successfully saved: img386.png
# Processing 'img387.png'
# PSNR: 41.44 dB, SSIM: 0.9772
#
# Successfully saved: img387.png
# Processing 'img388.png'
# PSNR: 39.63 dB, SSIM: 0.9812
#
# Successfully saved: img388.png
# Processing 'img389.png'
# PSNR: 42.83 dB, SSIM: 0.9879
#
# Successfully saved: img389.png
# Processing 'img39.png'
# PSNR: 42.53 dB, SSIM: 0.9863
#
# Successfully saved: img39.png
# Processing 'img390.png'
# PSNR: 41.71 dB, SSIM: 0.9780
#
# Successfully saved: img390.png
# Processing 'img391.png'
# PSNR: 46.28 dB, SSIM: 0.9924
#
# Successfully saved: img391.png
# Processing 'img392.png'
# PSNR: 44.20 dB, SSIM: 0.9890
#
# Successfully saved: img392.png
# Processing 'img393.png'
# PSNR: 42.28 dB, SSIM: 0.9843
#
# Successfully saved: img393.png
# Processing 'img394.png'
# PSNR: 40.52 dB, SSIM: 0.9799
#
# Successfully saved: img394.png
# Processing 'img395.png'
# PSNR: 39.03 dB, SSIM: 0.9757
#
# Successfully saved: img395.png
# Processing 'img396.png'
# PSNR: 37.64 dB, SSIM: 0.9684
#
# Successfully saved: img396.png
# Processing 'img397.png'
# PSNR: 37.37 dB, SSIM: 0.9666
#
# Successfully saved: img397.png
# Processing 'img398.png'
# PSNR: 37.30 dB, SSIM: 0.9689
#
# Successfully saved: img398.png
# Processing 'img399.png'
# PSNR: 36.32 dB, SSIM: 0.9653
#
# Successfully saved: img399.png
# Processing 'img4.png'
# PSNR: 40.34 dB, SSIM: 0.9781
#
# Successfully saved: img4.png
# Processing 'img40.png'
# PSNR: 40.98 dB, SSIM: 0.9742
#
# Successfully saved: img40.png
# Processing 'img400.png'
# PSNR: 41.52 dB, SSIM: 0.9783
#
# Successfully saved: img400.png
# Processing 'img401.png'
# PSNR: 42.06 dB, SSIM: 0.9851
#
# Successfully saved: img401.png
# Processing 'img402.png'
# PSNR: 41.38 dB, SSIM: 0.9764
#
# Successfully saved: img402.png
# Processing 'img403.png'
# PSNR: 37.33 dB, SSIM: 0.9775
#
# Successfully saved: img403.png
# Processing 'img404.png'
# PSNR: 42.96 dB, SSIM: 0.9886
#
# Successfully saved: img404.png
# Processing 'img405.png'
# PSNR: 44.43 dB, SSIM: 0.9893
#
# Successfully saved: img405.png
# Processing 'img406.png'
# PSNR: 42.54 dB, SSIM: 0.9852
#
# Successfully saved: img406.png
# Processing 'img407.png'
# PSNR: 41.85 dB, SSIM: 0.9855
#
# Successfully saved: img407.png
# Processing 'img408.png'
# PSNR: 39.31 dB, SSIM: 0.9776
#
# Successfully saved: img408.png
# Processing 'img409.png'
# PSNR: 38.99 dB, SSIM: 0.9780
#
# Successfully saved: img409.png
# Processing 'img41.png'
# PSNR: 41.87 dB, SSIM: 0.9839
#
# Successfully saved: img41.png
# Processing 'img410.png'
# PSNR: 37.77 dB, SSIM: 0.9704
#
# Successfully saved: img410.png
# Processing 'img411.png'
# PSNR: 37.67 dB, SSIM: 0.9726
#
# Successfully saved: img411.png
# Processing 'img412.png'
# PSNR: 44.48 dB, SSIM: 0.9877
#
# Successfully saved: img412.png
# Processing 'img413.png'
# PSNR: 36.62 dB, SSIM: 0.9698
#
# Successfully saved: img413.png
# Processing 'img414.png'
# PSNR: 44.25 dB, SSIM: 0.9890
#
# Successfully saved: img414.png
# Processing 'img415.png'
# PSNR: 41.15 dB, SSIM: 0.9741
#
# Successfully saved: img415.png
# Processing 'img416.png'
# PSNR: 37.12 dB, SSIM: 0.9748
#
# Successfully saved: img416.png
# Processing 'img417.png'
# PSNR: 39.55 dB, SSIM: 0.9809
#
# Successfully saved: img417.png
# Processing 'img418.png'
# PSNR: 42.76 dB, SSIM: 0.9878
#
# Successfully saved: img418.png
# Processing 'img419.png'
# PSNR: 46.39 dB, SSIM: 0.9925
#
# Successfully saved: img419.png
# Processing 'img42.png'
# PSNR: 39.44 dB, SSIM: 0.9640
#
# Successfully saved: img42.png
# Processing 'img420.png'
# PSNR: 44.16 dB, SSIM: 0.9886
#
# Successfully saved: img420.png
# Processing 'img421.png'
# PSNR: 42.24 dB, SSIM: 0.9844
#
# Successfully saved: img421.png
# Processing 'img422.png'
# PSNR: 39.05 dB, SSIM: 0.9757
#
# Successfully saved: img422.png
# Processing 'img423.png'
# PSNR: 43.66 dB, SSIM: 0.9858
#
# Successfully saved: img423.png
# Processing 'img424.png'
# PSNR: 37.72 dB, SSIM: 0.9683
#
# Successfully saved: img424.png
# Processing 'img425.png'
# PSNR: 37.52 dB, SSIM: 0.9666
#
# Successfully saved: img425.png
# Processing 'img426.png'
# PSNR: 37.43 dB, SSIM: 0.9655
#
# Successfully saved: img426.png
# Processing 'img427.png'
# PSNR: 37.36 dB, SSIM: 0.9673
#
# Successfully saved: img427.png
# Processing 'img428.png'
# PSNR: 36.31 dB, SSIM: 0.9634
#
# Successfully saved: img428.png
# Processing 'img429.png'
# PSNR: 41.29 dB, SSIM: 0.9759
#
# Successfully saved: img429.png
# Processing 'img43.png'
# PSNR: 41.47 dB, SSIM: 0.9781
#
# Successfully saved: img43.png
# Processing 'img430.png'
# PSNR: 41.13 dB, SSIM: 0.9738
#
# Successfully saved: img430.png
# Processing 'img431.png'
# PSNR: 37.07 dB, SSIM: 0.9744
#
# Successfully saved: img431.png
# Processing 'img432.png'
# PSNR: 39.45 dB, SSIM: 0.9803
#
# Successfully saved: img432.png
# Processing 'img433.png'
# PSNR: 42.70 dB, SSIM: 0.9876
#
# Successfully saved: img433.png
# Processing 'img434.png'
# PSNR: 39.09 dB, SSIM: 0.9779
#
# Successfully saved: img434.png
# Processing 'img435.png'
# PSNR: 44.03 dB, SSIM: 0.9882
#
# Successfully saved: img435.png
# Processing 'img436.png'
# PSNR: 42.17 dB, SSIM: 0.9840
#
# Successfully saved: img436.png
# Processing 'img437.png'
# PSNR: 40.41 dB, SSIM: 0.9791
#
# Successfully saved: img437.png
# Processing 'img438.png'
# PSNR: 38.94 dB, SSIM: 0.9749
#
# Successfully saved: img438.png
# Processing 'img439.png'
# PSNR: 37.61 dB, SSIM: 0.9666
#
# Successfully saved: img439.png
# Processing 'img44.png'
# PSNR: 39.74 dB, SSIM: 0.9680
#
# Successfully saved: img44.png
# Processing 'img440.png'
# PSNR: 37.41 dB, SSIM: 0.9655
#
# Successfully saved: img440.png
# Processing 'img441.png'
# PSNR: 37.33 dB, SSIM: 0.9646
#
# Successfully saved: img441.png
# Processing 'img442.png'
# PSNR: 37.29 dB, SSIM: 0.9669
#
# Successfully saved: img442.png
# Processing 'img443.png'
# PSNR: 36.24 dB, SSIM: 0.9632
#
# Successfully saved: img443.png
# Processing 'img444.png'
# PSNR: 37.10 dB, SSIM: 0.9653
#
# Successfully saved: img444.png
# Processing 'img445.png'
# PSNR: 42.08 dB, SSIM: 0.9865
#
# Successfully saved: img445.png
# Processing 'img446.png'
# PSNR: 37.06 dB, SSIM: 0.9647
#
# Successfully saved: img446.png
# Processing 'img447.png'
# PSNR: 41.02 dB, SSIM: 0.9756
#
# Successfully saved: img447.png
# Processing 'img448.png'
# PSNR: 37.86 dB, SSIM: 0.9801
#
# Successfully saved: img448.png
# Processing 'img449.png'
# PSNR: 37.00 dB, SSIM: 0.9750
#
# Successfully saved: img449.png
# Processing 'img45.png'
# PSNR: 39.58 dB, SSIM: 0.9657
#
# Successfully saved: img45.png
# Processing 'img450.png'
# PSNR: 39.47 dB, SSIM: 0.9806
#
# Successfully saved: img450.png
# Processing 'img451.png'
# PSNR: 42.74 dB, SSIM: 0.9880
#
# Successfully saved: img451.png
# Processing 'img452.png'
# PSNR: 44.00 dB, SSIM: 0.9878
#
# Successfully saved: img452.png
# Processing 'img453.png'
# PSNR: 40.25 dB, SSIM: 0.9792
#
# Successfully saved: img453.png
# Processing 'img454.png'
# PSNR: 37.48 dB, SSIM: 0.9706
#
# Successfully saved: img454.png
# Processing 'img455.png'
# PSNR: 36.35 dB, SSIM: 0.9621
#
# Successfully saved: img455.png
# Processing 'img456.png'
# PSNR: 36.32 dB, SSIM: 0.9606
#
# Successfully saved: img456.png
# Processing 'img457.png'
# PSNR: 36.92 dB, SSIM: 0.9637
#
# Successfully saved: img457.png
# Processing 'img458.png'
# PSNR: 36.29 dB, SSIM: 0.9637
#
# Successfully saved: img458.png
# Processing 'img459.png'
# PSNR: 44.83 dB, SSIM: 0.9906
#
# Successfully saved: img459.png
# Processing 'img46.png'
# PSNR: 36.33 dB, SSIM: 0.9647
#
# Successfully saved: img46.png
# Processing 'img460.png'
# PSNR: 39.70 dB, SSIM: 0.9648
#
# Successfully saved: img460.png
# Processing 'img461.png'
# PSNR: 37.08 dB, SSIM: 0.9758
#
# Successfully saved: img461.png
# Processing 'img462.png'
# PSNR: 39.49 dB, SSIM: 0.9808
#
# Successfully saved: img462.png
# Processing 'img463.png'
# PSNR: 43.95 dB, SSIM: 0.9884
#
# Successfully saved: img463.png
# Processing 'img464.png'
# PSNR: 42.16 dB, SSIM: 0.9847
#
# Successfully saved: img464.png
# Processing 'img465.png'
# PSNR: 40.33 dB, SSIM: 0.9797
#
# Successfully saved: img465.png
# Processing 'img466.png'
# PSNR: 37.81 dB, SSIM: 0.9685
#
# Successfully saved: img466.png
# Processing 'img467.png'
# PSNR: 37.55 dB, SSIM: 0.9699
#
# Successfully saved: img467.png
# Processing 'img468.png'
# PSNR: 35.20 dB, SSIM: 0.9613
#
# Successfully saved: img468.png
# Processing 'img469.png'
# PSNR: 36.39 dB, SSIM: 0.9592
#
# Successfully saved: img469.png
# Processing 'img470.png'
# PSNR: 37.37 dB, SSIM: 0.9667
#
# Successfully saved: img470.png
# Processing 'img471.png'
# PSNR: 36.42 dB, SSIM: 0.9609
#
# Successfully saved: img471.png
# Processing 'img472.png'
# PSNR: 43.70 dB, SSIM: 0.9886
#
# Successfully saved: img472.png
# Processing 'img473.png'
# PSNR: 39.77 dB, SSIM: 0.9662
#
# Successfully saved: img473.png
# Processing 'img474.png'
# PSNR: 36.89 dB, SSIM: 0.9745
#
# Successfully saved: img474.png
# Processing 'img475.png'
# PSNR: 44.80 dB, SSIM: 0.9907
#
# Successfully saved: img475.png
# Processing 'img476.png'
# PSNR: 37.05 dB, SSIM: 0.9756
#
# Successfully saved: img476.png
# Processing 'img477.png'
# PSNR: 39.40 dB, SSIM: 0.9800
#
# Successfully saved: img477.png
# Processing 'img478.png'
# PSNR: 42.71 dB, SSIM: 0.9879
#
# Successfully saved: img478.png
# Processing 'img479.png'
# PSNR: 38.30 dB, SSIM: 0.9727
#
# Successfully saved: img479.png
# Processing 'img480.png'
# PSNR: 46.22 dB, SSIM: 0.9923
#
# Successfully saved: img480.png
# Processing 'img481.png'
# PSNR: 44.09 dB, SSIM: 0.9886
#
# Successfully saved: img481.png
# Processing 'img482.png'
# PSNR: 36.41 dB, SSIM: 0.9603
#
# Successfully saved: img482.png
# Processing 'img483.png'
# PSNR: 37.37 dB, SSIM: 0.9671
#
# Successfully saved: img483.png
# Processing 'img484.png'
# PSNR: 36.39 dB, SSIM: 0.9601
#
# Successfully saved: img484.png
# Processing 'img485.png'
# PSNR: 36.41 dB, SSIM: 0.9652
#
# Successfully saved: img485.png
# Processing 'img486.png'
# PSNR: 42.12 dB, SSIM: 0.9821
#
# Successfully saved: img486.png
# Processing 'img487.png'
# PSNR: 41.68 dB, SSIM: 0.9791
#
# Successfully saved: img487.png
# Processing 'img488.png'
# PSNR: 39.84 dB, SSIM: 0.9659
#
# Successfully saved: img488.png
# Processing 'img489.png'
# PSNR: 39.48 dB, SSIM: 0.9806
#
# Successfully saved: img489.png
# Processing 'img490.png'
# PSNR: 37.01 dB, SSIM: 0.9648
#
# Successfully saved: img490.png
# Processing 'img491.png'
# PSNR: 42.85 dB, SSIM: 0.9884
#
# Successfully saved: img491.png
# Processing 'img492.png'
# PSNR: 46.59 dB, SSIM: 0.9925
#
# Successfully saved: img492.png
# Processing 'img493.png'
# PSNR: 44.28 dB, SSIM: 0.9886
#
# Successfully saved: img493.png
# Processing 'img494.png'
# PSNR: 36.57 dB, SSIM: 0.9623
#
# Successfully saved: img494.png
# Processing 'img495.png'
# PSNR: 36.35 dB, SSIM: 0.9612
#
# Successfully saved: img495.png
# Processing 'img496.png'
# PSNR: 36.31 dB, SSIM: 0.9597
#
# Successfully saved: img496.png
# Processing 'img497.png'
# PSNR: 36.34 dB, SSIM: 0.9626
#
# Successfully saved: img497.png
# Processing 'img498.png'
# PSNR: 39.61 dB, SSIM: 0.9810
#
# Successfully saved: img498.png
# Processing 'img499.png'
# PSNR: 42.83 dB, SSIM: 0.9879
#
# Successfully saved: img499.png
# Processing 'img5.png'
# PSNR: 38.76 dB, SSIM: 0.9733
#
# Successfully saved: img5.png
# Processing 'img50.png'
# PSNR: 34.29 dB, SSIM: 0.9580
#
# Successfully saved: img50.png
# Processing 'img500.png'
# PSNR: 44.03 dB, SSIM: 0.9885
#
# Successfully saved: img500.png
# Processing 'img501.png'
# PSNR: 36.05 dB, SSIM: 0.9640
#
# Successfully saved: img501.png
# Processing 'img502.png'
# PSNR: 42.37 dB, SSIM: 0.9853
#
# Successfully saved: img502.png
# Processing 'img503.png'
# PSNR: 40.56 dB, SSIM: 0.9808
#
# Successfully saved: img503.png
# Processing 'img504.png'
# PSNR: 37.53 dB, SSIM: 0.9725
#
# Successfully saved: img504.png
# Processing 'img505.png'
# PSNR: 37.53 dB, SSIM: 0.9710
#
# Successfully saved: img505.png
# Processing 'img506.png'
# PSNR: 36.53 dB, SSIM: 0.9677
#
# Successfully saved: img506.png
# Processing 'img507.png'
# PSNR: 41.22 dB, SSIM: 0.9767
#
# Successfully saved: img507.png
# Processing 'img508.png'
# PSNR: 42.89 dB, SSIM: 0.9884
#
# Successfully saved: img508.png
# Processing 'img509.png'
# PSNR: 42.72 dB, SSIM: 0.9881
#
# Successfully saved: img509.png
# Processing 'img510.png'
# PSNR: 43.97 dB, SSIM: 0.9876
#
# Successfully saved: img510.png
# Processing 'img511.png'
# PSNR: 42.16 dB, SSIM: 0.9837
#
# Successfully saved: img511.png
# Processing 'img512.png'
# PSNR: 35.16 dB, SSIM: 0.9625
#
# Successfully saved: img512.png
# Processing 'img513.png'
# PSNR: 37.43 dB, SSIM: 0.9722
#
# Successfully saved: img513.png
# Processing 'img514.png'
# PSNR: 36.34 dB, SSIM: 0.9625
#
# Successfully saved: img514.png
# Processing 'img515.png'
# PSNR: 36.34 dB, SSIM: 0.9681
#
# Successfully saved: img515.png
# Processing 'img516.png'
# PSNR: 40.25 dB, SSIM: 0.9726
#
# Successfully saved: img516.png
# Processing 'img517.png'
# PSNR: 39.92 dB, SSIM: 0.9682
#
# Successfully saved: img517.png
# Processing 'img518.png'
# PSNR: 41.19 dB, SSIM: 0.9784
#
# Successfully saved: img518.png
# Processing 'img519.png'
# PSNR: 44.35 dB, SSIM: 0.9890
#
# Successfully saved: img519.png
# Processing 'img520.png'
# PSNR: 42.08 dB, SSIM: 0.9825
#
# Successfully saved: img520.png
# Processing 'img521.png'
# PSNR: 41.53 dB, SSIM: 0.9796
#
# Successfully saved: img521.png
# Processing 'img522.png'
# PSNR: 39.85 dB, SSIM: 0.9672
#
# Successfully saved: img522.png
# Processing 'img523.png'
# PSNR: 41.22 dB, SSIM: 0.9750
#
# Successfully saved: img523.png
# Processing 'img524.png'
# PSNR: 39.58 dB, SSIM: 0.9813
#
# Successfully saved: img524.png
# Processing 'img525.png'
# PSNR: 42.41 dB, SSIM: 0.9842
#
# Successfully saved: img525.png
# Processing 'img526.png'
# PSNR: 40.59 dB, SSIM: 0.9800
#
# Successfully saved: img526.png
# Processing 'img527.png'
# PSNR: 36.43 dB, SSIM: 0.9657
#
# Successfully saved: img527.png
# Processing 'img528.png'
# PSNR: 35.57 dB, SSIM: 0.9627
#
# Successfully saved: img528.png
# Processing 'img529.png'
# PSNR: 44.56 dB, SSIM: 0.9891
#
# Successfully saved: img529.png
# Processing 'img530.png'
# PSNR: 44.42 dB, SSIM: 0.9886
#
# Successfully saved: img530.png
# Processing 'img531.png'
# PSNR: 42.44 dB, SSIM: 0.9839
#
# Successfully saved: img531.png
# Processing 'img532.png'
# PSNR: 40.53 dB, SSIM: 0.9785
#
# Successfully saved: img532.png
# Processing 'img533.png'
# PSNR: 38.93 dB, SSIM: 0.9740
#
# Successfully saved: img533.png
# Processing 'img534.png'
# PSNR: 44.36 dB, SSIM: 0.9874
#
# Successfully saved: img534.png
# Processing 'img535.png'
# PSNR: 37.60 dB, SSIM: 0.9697
#
# Successfully saved: img535.png
# Processing 'img536.png'
# PSNR: 36.38 dB, SSIM: 0.9630
#
# Successfully saved: img536.png
# Processing 'img537.png'
# PSNR: 36.33 dB, SSIM: 0.9627
#
# Successfully saved: img537.png
# Processing 'img538.png'
# PSNR: 42.15 dB, SSIM: 0.9817
#
# Successfully saved: img538.png
# Processing 'img539.png'
# PSNR: 40.51 dB, SSIM: 0.9788
#
# Successfully saved: img539.png
# Processing 'img540.png'
# PSNR: 38.96 dB, SSIM: 0.9740
#
# Successfully saved: img540.png
# Processing 'img541.png'
# PSNR: 37.61 dB, SSIM: 0.9699
#
# Successfully saved: img541.png
# Processing 'img542.png'
# PSNR: 36.37 dB, SSIM: 0.9636
#
# Successfully saved: img542.png
# Processing 'img543.png'
# PSNR: 44.67 dB, SSIM: 0.9888
#
# Successfully saved: img543.png
# Processing 'img544.png'
# PSNR: 42.34 dB, SSIM: 0.9812
#
# Successfully saved: img544.png
# Processing 'img545.png'
# PSNR: 41.24 dB, SSIM: 0.9763
#
# Successfully saved: img545.png
# Processing 'img546.png'
# PSNR: 40.44 dB, SSIM: 0.9786
#
# Successfully saved: img546.png
# Processing 'img547.png'
# PSNR: 38.92 dB, SSIM: 0.9747
#
# Successfully saved: img547.png
# Processing 'img548.png'
# PSNR: 37.52 dB, SSIM: 0.9694
#
# Successfully saved: img548.png
# Processing 'img549.png'
# PSNR: 36.32 dB, SSIM: 0.9627
#
# Successfully saved: img549.png
# Processing 'img550.png'
# PSNR: 35.28 dB, SSIM: 0.9571
#
# Successfully saved: img550.png
# Processing 'img551.png'
# PSNR: 35.30 dB, SSIM: 0.9594
#
# Successfully saved: img551.png
# Processing 'img552.png'
# PSNR: 42.28 dB, SSIM: 0.9821
#
# Successfully saved: img552.png
# Processing 'img553.png'
# PSNR: 44.04 dB, SSIM: 0.9911
#
# Successfully saved: img553.png
# Processing 'img554.png'
# PSNR: 39.81 dB, SSIM: 0.9684
#
# Successfully saved: img554.png
# Processing 'img555.png'
# PSNR: 42.20 dB, SSIM: 0.9831
#
# Successfully saved: img555.png
# Processing 'img556.png'
# PSNR: 38.83 dB, SSIM: 0.9749
#
# Successfully saved: img556.png
# Processing 'img557.png'
# PSNR: 39.54 dB, SSIM: 0.9651
#
# Successfully saved: img557.png
# Processing 'img558.png'
# PSNR: 38.87 dB, SSIM: 0.9739
#
# Successfully saved: img558.png
# Processing 'img559.png'
# PSNR: 37.53 dB, SSIM: 0.9687
#
# Successfully saved: img559.png
# Processing 'img560.png'
# PSNR: 36.28 dB, SSIM: 0.9621
#
# Successfully saved: img560.png
# Processing 'img561.png'
# PSNR: 44.69 dB, SSIM: 0.9888
#
# Successfully saved: img561.png
# Processing 'img562.png'
# PSNR: 43.74 dB, SSIM: 0.9865
#
# Successfully saved: img562.png
# Processing 'img563.png'
# PSNR: 44.19 dB, SSIM: 0.9881
#
# Successfully saved: img563.png
# Processing 'img564.png'
# PSNR: 40.42 dB, SSIM: 0.9791
#
# Successfully saved: img564.png
# Processing 'img565.png'
# PSNR: 35.26 dB, SSIM: 0.9553
#
# Successfully saved: img565.png
# Processing 'img566.png'
# PSNR: 42.17 dB, SSIM: 0.9807
#
# Successfully saved: img566.png
# Processing 'img567.png'
# PSNR: 40.16 dB, SSIM: 0.9713
#
# Successfully saved: img567.png
# Processing 'img568.png'
# PSNR: 43.41 dB, SSIM: 0.9867
#
# Successfully saved: img568.png
# Processing 'img569.png'
# PSNR: 38.31 dB, SSIM: 0.9608
#
# Successfully saved: img569.png
# Processing 'img570.png'
# PSNR: 36.43 dB, SSIM: 0.9612
#
# Successfully saved: img570.png
# Processing 'img571.png'
# PSNR: 35.27 dB, SSIM: 0.9541
#
# Successfully saved: img571.png
# Processing 'img572.png'
# PSNR: 44.41 dB, SSIM: 0.9880
#
# Successfully saved: img572.png
# Processing 'img573.png'
# PSNR: 43.47 dB, SSIM: 0.9855
#
# Successfully saved: img573.png
# Processing 'img574.png'
# PSNR: 41.40 dB, SSIM: 0.9782
#
# Successfully saved: img574.png
# Processing 'img575.png'
# PSNR: 42.60 dB, SSIM: 0.9872
#
# Successfully saved: img575.png
# Processing 'img576.png'
# PSNR: 40.08 dB, SSIM: 0.9768
#
# Successfully saved: img576.png
# Processing 'img577.png'
# PSNR: 44.10 dB, SSIM: 0.9912
#
# Successfully saved: img577.png
# Processing 'img578.png'
# PSNR: 42.38 dB, SSIM: 0.9839
#
# Successfully saved: img578.png
# Processing 'img579.png'
# PSNR: 36.97 dB, SSIM: 0.9650
#
# Successfully saved: img579.png
# Processing 'img580.png'
# PSNR: 40.50 dB, SSIM: 0.9790
#
# Successfully saved: img580.png
# Processing 'img581.png'
# ...
#
# Successfully saved: img856.png
# Processing 'img857.png'
# PSNR: 44.42 dB, SSIM: 0.9894
#
# Successfully saved: img857.png
# Processing 'img858.png'
# PSNR: 43.91 dB, SSIM: 0.9888
#
# Successfully saved: img858.png
# Processing 'img859.png'
# PSNR: 42.02 dB, SSIM: 0.9848
#
# Successfully saved: img859.png
# Processing 'img860.png'
# PSNR: 40.28 dB, SSIM: 0.9807
#
# Successfully saved: img860.png
# Processing 'img861.png'
# PSNR: 38.82 dB, SSIM: 0.9771
#
# Successfully saved: img861.png
# Processing 'img862.png'
# PSNR: 43.67 dB, SSIM: 0.9861
#
# Successfully saved: img862.png
# Processing 'img863.png'
# PSNR: 41.77 dB, SSIM: 0.9776
#
# Successfully saved: img863.png
# Processing 'img864.png'
# PSNR: 42.10 dB, SSIM: 0.9840
#
# Successfully saved: img864.png
# Processing 'img865.png'
# PSNR: 40.47 dB, SSIM: 0.9791
#
# Successfully saved: img865.png
# Processing 'img866.png'
# PSNR: 38.94 dB, SSIM: 0.9746
#
# Successfully saved: img866.png
# Processing 'img867.png'
# PSNR: 35.23 dB, SSIM: 0.9552
#
# Successfully saved: img867.png
# Processing 'img868.png'
# PSNR: 36.57 dB, SSIM: 0.9636
#
# Successfully saved: img868.png
# Processing 'img869.png'
# PSNR: 44.61 dB, SSIM: 0.9883
#
# Successfully saved: img869.png
# Processing 'img870.png'
# PSNR: 43.93 dB, SSIM: 0.9865
#
# Successfully saved: img870.png
# Processing 'img871.png'
# PSNR: 38.52 dB, SSIM: 0.9761
#
# Successfully saved: img871.png
# Processing 'img872.png'
# PSNR: 41.95 dB, SSIM: 0.9796
#
# Successfully saved: img872.png
# Processing 'img873.png'
# PSNR: 41.51 dB, SSIM: 0.9771
#
# Successfully saved: img873.png
# Processing 'img874.png'
# PSNR: 36.89 dB, SSIM: 0.9726
#
# Successfully saved: img874.png
# Processing 'img875.png'
# PSNR: 42.51 dB, SSIM: 0.9869
#
# Successfully saved: img875.png
# Processing 'img876.png'
# PSNR: 42.35 dB, SSIM: 0.9835
#
# Successfully saved: img876.png
# Processing 'img877.png'
# PSNR: 42.05 dB, SSIM: 0.9830
#
# Successfully saved: img877.png
# Processing 'img878.png'
# PSNR: 39.96 dB, SSIM: 0.9675
#
# Successfully saved: img878.png
# Processing 'img879.png'
# PSNR: 40.34 dB, SSIM: 0.9769
#
# Successfully saved: img879.png
# Processing 'img880.png'
# PSNR: 38.75 dB, SSIM: 0.9712
#
# Successfully saved: img880.png
# Processing 'img881.png'
# PSNR: 37.35 dB, SSIM: 0.9662
#
# Successfully saved: img881.png
# Processing 'img882.png'
# PSNR: 43.91 dB, SSIM: 0.9865
#
# Successfully saved: img882.png
# Processing 'img883.png'
# PSNR: 41.95 dB, SSIM: 0.9780
#
# Successfully saved: img883.png
# Processing 'img884.png'
# PSNR: 37.80 dB, SSIM: 0.9719
#
# Successfully saved: img884.png
# Processing 'img885.png'
# PSNR: 35.62 dB, SSIM: 0.9609
#
# Successfully saved: img885.png
# Processing 'img886.png'
# PSNR: 37.97 dB, SSIM: 0.9798
#
# Successfully saved: img886.png
# Processing 'img887.png'
# PSNR: 40.59 dB, SSIM: 0.9783
#
# Successfully saved: img887.png
# Processing 'img888.png'
# PSNR: 36.53 dB, SSIM: 0.9722
#
# Successfully saved: img888.png
# Processing 'img889.png'
# PSNR: 36.03 dB, SSIM: 0.9592
#
# Successfully saved: img889.png
# Processing 'img890.png'
# PSNR: 39.63 dB, SSIM: 0.9671
#
# Successfully saved: img890.png
# Processing 'img891.png'
# PSNR: 44.41 dB, SSIM: 0.9880
#
# Successfully saved: img891.png
# Processing 'img892.png'
# PSNR: 43.66 dB, SSIM: 0.9856
#
# Successfully saved: img892.png
# Processing 'img893.png'
# PSNR: 41.44 dB, SSIM: 0.9753
#
# Successfully saved: img893.png
# Processing 'img894.png'
# PSNR: 41.23 dB, SSIM: 0.9730
#
# Successfully saved: img894.png
# Processing 'img895.png'
# PSNR: 44.54 dB, SSIM: 0.9885
#
# Successfully saved: img895.png
# Processing 'img896.png'
# PSNR: 43.93 dB, SSIM: 0.9863
#
# Successfully saved: img896.png
# Processing 'img897.png'
# PSNR: 41.32 dB, SSIM: 0.9741
#
# Successfully saved: img897.png
# Processing 'img898.png'
# PSNR: 41.31 dB, SSIM: 0.9708
#
# Successfully saved: img898.png
# Processing 'img899.png'
# PSNR: 35.32 dB, SSIM: 0.9585
#
# Successfully saved: img899.png
# Processing 'img9.png'
# PSNR: 33.39 dB, SSIM: 0.9442
#
# Successfully saved: img9.png
# Processing 'img900.png'
# PSNR: 41.36 dB, SSIM: 0.9750
#
# Successfully saved: img900.png
# Processing 'img901.png'
# PSNR: 39.43 dB, SSIM: 0.9658
#
# Successfully saved: img901.png
# Processing 'img902.png'
# PSNR: 41.08 dB, SSIM: 0.9724
#
# Successfully saved: img902.png
# Processing 'img903.png'
# PSNR: 41.07 dB, SSIM: 0.9707
#
# Successfully saved: img903.png
# Processing 'img904.png'
# PSNR: 35.38 dB, SSIM: 0.9573
#
# Successfully saved: img904.png
# Processing 'img905.png'
# PSNR: 35.42 dB, SSIM: 0.9583
#
# Successfully saved: img905.png
# Processing 'img906.png'
# PSNR: 36.93 dB, SSIM: 0.9744
#
# Successfully saved: img906.png
# Processing 'img907.png'
# PSNR: 34.97 dB, SSIM: 0.9519
#
# Successfully saved: img907.png
# Processing 'img908.png'
# PSNR: 43.71 dB, SSIM: 0.9860
#
# Successfully saved: img908.png
# Processing 'img909.png'
# PSNR: 41.43 dB, SSIM: 0.9756
#
# Successfully saved: img909.png
# Processing 'img910.png'
# PSNR: 41.24 dB, SSIM: 0.9731
#
# Successfully saved: img910.png
# Processing 'img911.png'
# PSNR: 41.11 dB, SSIM: 0.9735
#
# Successfully saved: img911.png
# Processing 'img912.png'
# PSNR: 42.19 dB, SSIM: 0.9826
#
# Successfully saved: img912.png
# Processing 'img913.png'
# PSNR: 36.26 dB, SSIM: 0.9629
#
# Successfully saved: img913.png
# Processing 'img914.png'
# PSNR: 36.38 dB, SSIM: 0.9656
#
# Successfully saved: img914.png
# Processing 'img915.png'
# PSNR: 42.00 dB, SSIM: 0.9786
#
# Successfully saved: img915.png
# Processing 'img916.png'
# PSNR: 35.86 dB, SSIM: 0.9582
#
# Successfully saved: img916.png
# Processing 'img917.png'
# PSNR: 34.99 dB, SSIM: 0.9507
#
# Successfully saved: img917.png
# Processing 'img918.png'
# PSNR: 35.95 dB, SSIM: 0.9559
#
# Successfully saved: img918.png
# Processing 'img919.png'
# PSNR: 36.06 dB, SSIM: 0.9606
#
# Successfully saved: img919.png
# Processing 'img920.png'
# PSNR: 44.15 dB, SSIM: 0.9879
#
# Successfully saved: img920.png
# Processing 'img921.png'
# PSNR: 36.95 dB, SSIM: 0.9733
#
# Successfully saved: img921.png
# Processing 'img922.png'
# PSNR: 41.38 dB, SSIM: 0.9765
#
# Successfully saved: img922.png
# Processing 'img923.png'
# PSNR: 40.45 dB, SSIM: 0.9776
#
# Successfully saved: img923.png
# Processing 'img924.png'
# PSNR: 34.99 dB, SSIM: 0.9487
#
# Successfully saved: img924.png
# Processing 'img925.png'
# PSNR: 43.86 dB, SSIM: 0.9881
#
# Successfully saved: img925.png
# Processing 'img926.png'
# PSNR: 42.09 dB, SSIM: 0.9807
#
# Successfully saved: img926.png
# Processing 'img927.png'
# PSNR: 41.72 dB, SSIM: 0.9786
#
# Successfully saved: img927.png
# Processing 'img928.png'
# PSNR: 41.01 dB, SSIM: 0.9747
#
# Successfully saved: img928.png
# Processing 'img929.png'
# PSNR: 36.25 dB, SSIM: 0.9587
#
# Successfully saved: img929.png
# Processing 'img930.png'
# PSNR: 37.24 dB, SSIM: 0.9676
#
# Successfully saved: img930.png
# Processing 'img931.png'
# PSNR: 36.29 dB, SSIM: 0.9630
#
# Successfully saved: img931.png
# Processing 'img932.png'
# PSNR: 43.70 dB, SSIM: 0.9876
#
# Successfully saved: img932.png
# Processing 'img933.png'
# PSNR: 35.50 dB, SSIM: 0.9438
#
# Successfully saved: img933.png
# Processing 'img934.png'
# PSNR: 38.90 dB, SSIM: 0.9734
#
# Successfully saved: img934.png
# Processing 'img935.png'
# PSNR: 34.59 dB, SSIM: 0.9416
#
# Successfully saved: img935.png
# Processing 'img936.png'
# PSNR: 44.63 dB, SSIM: 0.9896
#
# Successfully saved: img936.png
# Processing 'img937.png'
# PSNR: 33.71 dB, SSIM: 0.9556
#
# Successfully saved: img937.png
# Processing 'img938.png'
# PSNR: 33.03 dB, SSIM: 0.9520
#
# Successfully saved: img938.png
# Processing 'img939.png'
# PSNR: 36.84 dB, SSIM: 0.9734
#
# Successfully saved: img939.png
# Processing 'img940.png'
# PSNR: 33.78 dB, SSIM: 0.9562
#
# Successfully saved: img940.png
# Processing 'img941.png'
# PSNR: 33.88 dB, SSIM: 0.9612
#
# Successfully saved: img941.png
# Processing 'img942.png'
# PSNR: 38.11 dB, SSIM: 0.9743
#
# Successfully saved: img942.png
# Processing 'img943.png'
# PSNR: 36.91 dB, SSIM: 0.9715
#
# Successfully saved: img943.png
# Processing 'img944.png'
# PSNR: 33.01 dB, SSIM: 0.9511
#
# Successfully saved: img944.png
# Processing 'img945.png'
# PSNR: 37.62 dB, SSIM: 0.9682
#
# Successfully saved: img945.png
# Processing 'img946.png'
# PSNR: 36.38 dB, SSIM: 0.9627
#
# Successfully saved: img946.png
# Processing 'img947.png'
# PSNR: 35.04 dB, SSIM: 0.9488
#
# Successfully saved: img947.png
# Processing 'img948.png'
# PSNR: 35.11 dB, SSIM: 0.9555
#
# Successfully saved: img948.png
# Processing 'img949.png'
# PSNR: 39.10 dB, SSIM: 0.9784
#
# Successfully saved: img949.png
# Processing 'img96.png'
# PSNR: 37.94 dB, SSIM: 0.9758
#
# Successfully saved: img96.png
# Processing 'img97.png'
# PSNR: 34.63 dB, SSIM: 0.9598
#
# Successfully saved: img97.png
# Processing 'img98.png'
# PSNR: 34.50 dB, SSIM: 0.9601
#
# Successfully saved: img98.png
# Processing 'img99.png'
# PSNR: 35.81 dB, SSIM: 0.9709
#
# Successfully saved: img99.png
# Processing Defective Images...
#
# Found 95 images in C:\Users\Global\Fabric project\WFDD\Yellow cloth\defect_normalized...
#
# Processing '001.png'
# PSNR: 32.49 dB, SSIM: 0.9387
#
# Successfully saved: 001.png
# Processing '002.png'
# PSNR: 41.60 dB, SSIM: 0.9804
#
# Successfully saved: 002.png
# Processing '003.png'
# PSNR: 41.66 dB, SSIM: 0.9804
#
# Successfully saved: 003.png
# Processing '004.png'
# PSNR: 47.44 dB, SSIM: 0.9942
#
# Successfully saved: 004.png
# Processing '005.png'
# PSNR: 41.70 dB, SSIM: 0.9803
#
# Successfully saved: 005.png
# Processing '006.png'
# PSNR: 41.35 dB, SSIM: 0.9792
#
# Successfully saved: 006.png
# Processing '007.png'
# PSNR: 41.42 dB, SSIM: 0.9797
#
# Successfully saved: 007.png
# Processing '008.png'
# PSNR: 41.44 dB, SSIM: 0.9801
#
# Successfully saved: 008.png
# Processing '009.png'
# PSNR: 41.78 dB, SSIM: 0.9808
#
# Successfully saved: 009.png
# Processing '010.png'
# PSNR: 41.81 dB, SSIM: 0.9820
#
# Successfully saved: 010.png
# Processing '011.png'
# PSNR: 41.63 dB, SSIM: 0.9807
#
# Successfully saved: 011.png
# Processing '012.png'
# PSNR: 41.47 dB, SSIM: 0.9808
#
# Successfully saved: 012.png
# Processing '013.png'
# PSNR: 41.59 dB, SSIM: 0.9804
#
# Successfully saved: 013.png
# Processing '014.png'
# PSNR: 41.24 dB, SSIM: 0.9789
#
# Successfully saved: 014.png
# Processing '015.png'
# PSNR: 41.40 dB, SSIM: 0.9796
#
# Successfully saved: 015.png
# Processing '016.png'
# PSNR: 41.19 dB, SSIM: 0.9788
#
# Successfully saved: 016.png
# Processing '017.png'
# PSNR: 41.57 dB, SSIM: 0.9809
#
# Successfully saved: 017.png
# Processing '018.png'
# PSNR: 43.95 dB, SSIM: 0.9880
#
# Successfully saved: 018.png
# Processing '019.png'
# PSNR: 41.55 dB, SSIM: 0.9805
#
# Successfully saved: 019.png
# Processing '020.png'
# PSNR: 41.54 dB, SSIM: 0.9805
#
# Successfully saved: 020.png
# Processing '021.png'
# PSNR: 40.51 dB, SSIM: 0.9783
#
# Successfully saved: 021.png
# Processing '022.png'
# PSNR: 35.32 dB, SSIM: 0.9652
#
# Successfully saved: 022.png
# Processing '023.png'
# PSNR: 35.53 dB, SSIM: 0.9591
#
# Successfully saved: 023.png
# Processing '024.png'
# PSNR: 35.30 dB, SSIM: 0.9559
#
# Successfully saved: 024.png
# Processing '025.png'
# PSNR: 38.14 dB, SSIM: 0.9780
#
# Successfully saved: 025.png
# Processing '026.png'
# PSNR: 43.74 dB, SSIM: 0.9831
#
# Successfully saved: 026.png
# Processing '027.png'
# PSNR: 33.77 dB, SSIM: 0.9339
#
# Successfully saved: 027.png
# Processing '028.png'
# PSNR: 37.17 dB, SSIM: 0.9764
#
# Successfully saved: 028.png
# Processing '029.png'
# PSNR: 43.99 dB, SSIM: 0.9867
#
# Successfully saved: 029.png
# Processing '030.png'
# PSNR: 44.33 dB, SSIM: 0.9906
#
# Successfully saved: 030.png
# Processing '031.png'
# PSNR: 41.74 dB, SSIM: 0.9783
#
# Successfully saved: 031.png
# Processing '032.png'
# PSNR: 41.83 dB, SSIM: 0.9787
#
# Successfully saved: 032.png
# Processing '033.png'
# PSNR: 36.98 dB, SSIM: 0.9694
#
# Successfully saved: 033.png
# Processing '034.png'
# PSNR: 38.82 dB, SSIM: 0.9753
#
# Successfully saved: 034.png
# Processing '035.png'
# PSNR: 40.65 dB, SSIM: 0.9798
#
# Successfully saved: 035.png
# Processing '036.png'
# PSNR: 44.26 dB, SSIM: 0.9889
#
# Successfully saved: 036.png
# Processing '037.png'
# PSNR: 47.11 dB, SSIM: 0.9940
#
# Successfully saved: 037.png
# Processing '038.png'
# PSNR: 44.53 dB, SSIM: 0.9893
#
# Successfully saved: 038.png
# Processing '039.png'
# PSNR: 39.10 dB, SSIM: 0.9844
#
# Successfully saved: 039.png
# Processing '040.png'
# PSNR: 40.28 dB, SSIM: 0.9823
#
# Successfully saved: 040.png
# Processing '041.png'
# PSNR: 37.99 dB, SSIM: 0.9744
#
# Successfully saved: 041.png
# Processing '042.png'
# PSNR: 36.83 dB, SSIM: 0.9708
#
# Successfully saved: 042.png
# Processing '043.png'
# PSNR: 35.66 dB, SSIM: 0.9653
#
# Successfully saved: 043.png
# Processing '044.png'
# PSNR: 35.58 dB, SSIM: 0.9649
#
# Successfully saved: 044.png
# Processing '045.png'
# PSNR: 34.56 dB, SSIM: 0.9523
#
# Successfully saved: 045.png
# Processing '046.png'
# PSNR: 32.50 dB, SSIM: 0.9330
#
# Successfully saved: 046.png
# Processing '047.png'
# PSNR: 39.40 dB, SSIM: 0.9775
#
# Successfully saved: 047.png
# Processing '048.png'
# PSNR: 37.12 dB, SSIM: 0.9722
#
# Successfully saved: 048.png
# Processing '049.png'
# PSNR: 35.66 dB, SSIM: 0.9652
#
# Successfully saved: 049.png
# Processing '050.png'
# PSNR: 39.15 dB, SSIM: 0.9735
#
# Successfully saved: 050.png
# Processing '051.png'
# PSNR: 33.44 dB, SSIM: 0.9434
#
# Successfully saved: 051.png
# Processing '052.png'
# PSNR: 38.11 dB, SSIM: 0.9758
#
# Successfully saved: 052.png
# Processing '053.png'
# PSNR: 34.44 dB, SSIM: 0.9550
#
# Successfully saved: 053.png
# Processing '054.png'
# PSNR: 36.04 dB, SSIM: 0.9507
#
# Successfully saved: 054.png
# Processing '055.png'
# PSNR: 35.47 dB, SSIM: 0.9622
#
# Successfully saved: 055.png
# Processing '056.png'
# PSNR: 39.39 dB, SSIM: 0.9775
#
# Successfully saved: 056.png
# Processing '057.png'
# PSNR: 34.91 dB, SSIM: 0.9642
#
# Successfully saved: 057.png
# Processing '058.png'
# PSNR: 42.08 dB, SSIM: 0.9856
#
# Successfully saved: 058.png
# Processing '059.png'
# PSNR: 43.34 dB, SSIM: 0.9858
#
# Successfully saved: 059.png
# Processing '060.png'
# PSNR: 43.45 dB, SSIM: 0.9863
#
# Successfully saved: 060.png
# Processing '061.png'
# PSNR: 43.59 dB, SSIM: 0.9867
#
# Successfully saved: 061.png
# Processing '062.png'
# PSNR: 43.41 dB, SSIM: 0.9855
#
# Successfully saved: 062.png
# Processing '063.png'
# PSNR: 38.07 dB, SSIM: 0.9560
#
# Successfully saved: 063.png
# Processing '064.png'
# PSNR: 41.83 dB, SSIM: 0.9789
#
# Successfully saved: 064.png
# Processing '065.png'
# PSNR: 39.17 dB, SSIM: 0.9646
#
# Successfully saved: 065.png
# Processing '066.png'
# PSNR: 36.35 dB, SSIM: 0.9715
#
# Successfully saved: 066.png
# Processing '067.png'
# PSNR: 37.99 dB, SSIM: 0.9758
#
# Successfully saved: 067.png
# Processing '068.png'
# PSNR: 40.28 dB, SSIM: 0.9832
#
# Successfully saved: 068.png
# Processing '069.png'
# PSNR: 46.62 dB, SSIM: 0.9929
#
# Successfully saved: 069.png
# Processing '070.png'
# PSNR: 46.45 dB, SSIM: 0.9927
#
# Successfully saved: 070.png
# Processing '071.png'
# PSNR: 46.56 dB, SSIM: 0.9931
#
# Successfully saved: 071.png
# Processing '072.png'
# PSNR: 42.27 dB, SSIM: 0.9863
#
# Successfully saved: 072.png
# Processing '073.png'
# PSNR: 42.29 dB, SSIM: 0.9864
#
# Successfully saved: 073.png
# Processing '074.png'
# PSNR: 38.66 dB, SSIM: 0.9776
#
# Successfully saved: 074.png
# Processing '075.png'
# PSNR: 35.43 dB, SSIM: 0.9634
#
# Successfully saved: 075.png
# Processing '076.png'
# PSNR: 34.42 dB, SSIM: 0.9570
#
# Successfully saved: 076.png
# Processing '077.png'
# PSNR: 39.38 dB, SSIM: 0.9801
#
# Successfully saved: 077.png
# Processing '078.png'
# PSNR: 37.60 dB, SSIM: 0.9735
#
# Successfully saved: 078.png
# Processing '079.png'
# PSNR: 38.16 dB, SSIM: 0.9757
#
# Successfully saved: 079.png
# Processing '080.png'
# PSNR: 37.85 dB, SSIM: 0.9694
#
# Successfully saved: 080.png
# Processing '081.png'
# PSNR: 42.28 dB, SSIM: 0.9876
#
# Successfully saved: 081.png
# Processing '082.png'
# PSNR: 42.32 dB, SSIM: 0.9873
#
# Successfully saved: 082.png
# Processing '083.png'
# PSNR: 42.02 dB, SSIM: 0.9863
#
# Successfully saved: 083.png
# Processing '084.png'
# PSNR: 39.31 dB, SSIM: 0.9787
#
# Successfully saved: 084.png
# Processing '085.png'
# PSNR: 36.99 dB, SSIM: 0.9536
#
# Successfully saved: 085.png
# Processing '086.png'
# PSNR: 37.90 dB, SSIM: 0.9759
#
# Successfully saved: 086.png
# Processing '087.png'
# PSNR: 41.96 dB, SSIM: 0.9813
#
# Successfully saved: 087.png
# Processing '088.png'
# PSNR: 41.74 dB, SSIM: 0.9835
#
# Successfully saved: 088.png
# Processing '089.png'
# PSNR: 41.67 dB, SSIM: 0.9820
#
# Successfully saved: 089.png
# Processing '090.png'
# PSNR: 38.98 dB, SSIM: 0.9734
#
# Successfully saved: 090.png
# Processing '091.png'
# PSNR: 36.73 dB, SSIM: 0.9705
#
# Successfully saved: 091.png
# Processing '092.png'
# PSNR: 35.72 dB, SSIM: 0.9657
#
# Successfully saved: 092.png
# Processing '093.png'
# PSNR: 43.58 dB, SSIM: 0.9851
#
# Successfully saved: 093.png
# Processing '094.png'
# PSNR: 38.16 dB, SSIM: 0.9685
#
# Successfully saved: 094.png
# Processing '095.png'
# PSNR: 36.31 dB, SSIM: 0.9655
#
# Successfully saved: 095.png

# %%
# Step 7: Optional - Visualize a Sample Comparison for Normal Images
# ===============================
# For demonstration, display the first image from the normal folder before and after denoising.
sample_file = os.listdir(normal_input_folder)[0]
sample_input_path = os.path.join(normal_input_folder, sample_file)
sample_output_path = os.path.join(normal_output_folder, sample_file)

orig_sample = cv2.imread(sample_input_path, cv2.IMREAD_GRAYSCALE)
denoised_sample = cv2.imread(sample_output_path, cv2.IMREAD_GRAYSCALE)

# Show before and after denoising images
import matplotlib.pyplot as plt
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
plt.imshow(orig_sample, cmap='gray')
plt.title("Original Normal Image")
plt.axis('off')

plt.subplot(1, 2, 2)
plt.imshow(denoised_sample, cmap='gray')
plt.title("Denoised Normal Image")
plt.axis('off')

plt.suptitle("Comparison: Original vs. Denoised (Normal Fabric)", fontsize=16)
plt.tight_layout()
plt.show()

# %%
# ===============================
# Step 7 (continued): Visualize a Sample Comparison for Defect Images
# ===============================
# For demonstration, display the first image from the defect folder before and after denoising.
sample_defect_file = os.listdir(defect_input_folder)[0]
sample_defect_input_path = os.path.join(defect_input_folder, sample_defect_file)
sample_defect_output_path = os.path.join(defect_output_folder, sample_defect_file)

orig_defect_sample = cv2.imread(sample_defect_input_path, cv2.IMREAD_GRAYSCALE)
denoised_defect_sample = cv2.imread(sample_defect_output_path, cv2.IMREAD_GRAYSCALE)

plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
plt.imshow(orig_defect_sample, cmap='gray')
plt.title("Original Defect Image")
plt.axis('off')

plt.subplot(1, 2, 2)
plt.imshow(denoised_defect_sample, cmap='gray')
plt.title("Denoised Defect Image")
plt.axis('off')

plt.suptitle("Comparison: Original vs. Denoised (Defect Fabric)", fontsize=16)
plt.tight_layout()
plt.show()

# %%
# ===============================
# Step 8: Modified process_folder to return PSNR and SSIM values
# ===============================
def process_folder_with_metrics(input_folder, output_folder):
    image_extensions = ('.png', '.jpg', '.jpeg', '.bmp', '.tif', '.tiff')
    files = [f for f in os.listdir(input_folder) if f.lower().endswith(image_extensions)]

    psnr_values = []
    ssim_values = []

    for file in files:
        input_path = os.path.join(input_folder, file)
        output_path = os.path.join(output_folder, file)

        img = cv2.imread(input_path, cv2.IMREAD_GRAYSCALE)
        img_float = img_as_float(img)

        denoised = restoration.denoise_wavelet(
            img_float,
            method='BayesShrink',
            mode='soft',
            rescale_sigma=True
        )

        psnr_value = psnr(img_float, denoised, data_range=1.0)
        ssim_value = ssim(img_float, denoised, data_range=1.0)

        print(f"Processing '{file}'")
        print(f"PSNR: {psnr_value:.2f} dB, SSIM: {ssim_value:.4f}\n")

        denoised_clipped = np.clip(denoised, 0, 1)
        denoised_uint8 = img_as_ubyte(denoised_clipped)
        cv2.imwrite(output_path, denoised_uint8)

        psnr_values.append(psnr_value)
        ssim_values.append(ssim_value)

    return psnr_values, ssim_values

# ===============================
# Step 9: Call Modified Function for Each Folder
# ===============================
print("=== Processing Normal Folder ===")
normal_psnr, normal_ssim = process_folder_with_metrics(normal_input_folder, normal_output_folder)

print("\n=== Processing Defect Folder ===")
defect_psnr, defect_ssim = process_folder_with_metrics(defect_input_folder, defect_output_folder)

# ===============================
# Step 10: Print Average Metrics
# ===============================
print("\n===== Summary =====")
print(f"Normal Folder - Avg PSNR: {np.mean(normal_psnr):.2f} dB, Avg SSIM: {np.mean(normal_ssim):.4f}")
print(f"Defect Folder - Avg PSNR: {np.mean(defect_psnr):.2f} dB, Avg SSIM: {np.mean(defect_ssim):.4f}")
# Out:
# === Processing Normal Folder ===
# Processing 'img1.png'
# PSNR: 43.92 dB, SSIM: 0.9859
#
# Processing 'img10.png'
# PSNR: 41.66 dB, SSIM: 0.9823
#
# Processing 'img100.png'
# PSNR: 42.47 dB, SSIM: 0.9871
#
# Processing 'img1000.png'
# PSNR: 34.40 dB, SSIM: 0.9632
#
# Processing 'img1001.png'
# PSNR: 41.23 dB, SSIM: 0.9755
#
# Processing 'img1002.png'
# PSNR: 39.52 dB, SSIM: 0.9644
#
# Processing 'img1003.png'
# PSNR: 39.16 dB, SSIM: 0.9613
#
# Processing 'img1004.png'
# PSNR: 39.07 dB, SSIM: 0.9613
#
# Processing 'img1005.png'
# PSNR: 39.79 dB, SSIM: 0.9667
#
# Processing 'img1006.png'
# PSNR: 36.45 dB, SSIM: 0.9661
#
# Processing 'img1007.png'
# PSNR: 38.01 dB, SSIM: 0.9539
#
# Processing 'img1008.png'
# PSNR: 33.34 dB, SSIM: 0.9441
#
# Processing 'img1009.png'
# PSNR: 32.37 dB, SSIM: 0.9328
#
# Processing 'img101.png'
# PSNR: 37.47 dB, SSIM: 0.9668
#
# Processing 'img1010.png'
# PSNR: 31.77 dB, SSIM: 0.9300
#
# Processing 'img1011.png'
# PSNR: 39.70 dB, SSIM: 0.9645
#
# Processing 'img1012.png'
# PSNR: 39.40 dB, SSIM: 0.9645
#
# Processing 'img1013.png'
# PSNR: 37.88 dB, SSIM: 0.9481
#
# Processing 'img1014.png'
# PSNR: 37.82 dB, SSIM: 0.9478
#
# Processing 'img1015.png'
# PSNR: 39.93 dB, SSIM: 0.9685
#
# Processing 'img1016.png'
# PSNR: 39.71 dB, SSIM: 0.9683
#
# Processing 'img1017.png'
# PSNR: 36.51 dB, SSIM: 0.9746
#
# Processing 'img1018.png'
# PSNR: 38.22 dB, SSIM: 0.9571
#
# Processing 'img1019.png'
# PSNR: 38.23 dB, SSIM: 0.9608
#
# Processing 'img102.png'
# PSNR: 40.75 dB, SSIM: 0.9839
#
# Processing 'img1020.png'
# PSNR: 33.65 dB, SSIM: 0.9507
#
# Processing 'img1021.png'
# PSNR: 39.96 dB, SSIM: 0.9671
#
# Processing 'img1022.png'
# PSNR: 39.68 dB, SSIM: 0.9667
#
# Processing 'img1023.png'
# PSNR: 39.47 dB, SSIM: 0.9656
#
# Processing 'img1024.png'
# PSNR: 38.07 dB, SSIM: 0.9528
#
# Processing 'img1025.png'
# PSNR: 39.69 dB, SSIM: 0.9692
#
# Processing 'img1026.png'
# PSNR: 33.63 dB, SSIM: 0.9511
#
# Processing 'img1027.png'
# PSNR: 39.76 dB, SSIM: 0.9664
#
# Processing 'img1028.png'
# PSNR: 40.12 dB, SSIM: 0.9737
#
# Processing 'img1029.png'
# PSNR: 38.18 dB, SSIM: 0.9541
#
# Processing 'img103.png'
# PSNR: 39.40 dB, SSIM: 0.9807
#
# Processing 'img1030.png'
# PSNR: 39.90 dB, SSIM: 0.9668
#
# Processing 'img1031.png'
# PSNR: 39.66 dB, SSIM: 0.9682
#
# Processing 'img1032.png'
# PSNR: 39.79 dB, SSIM: 0.9681
#
# Processing 'img1033.png'
# PSNR: 41.92 dB, SSIM: 0.9842
#
# Processing 'img1034.png'
# PSNR: 36.35 dB, SSIM: 0.9628
#
# Processing 'img1035.png'
# PSNR: 40.84 dB, SSIM: 0.9815
#
# Processing 'img1036.png'
# PSNR: 36.49 dB, SSIM: 0.9676
#
# Processing 'img1037.png'
# PSNR: 36.45 dB, SSIM: 0.9668
#
# Processing 'img1038.png'
# PSNR: 36.51 dB, SSIM: 0.9709
#
# Processing 'img1039.png'
# PSNR: 38.64 dB, SSIM: 0.9671
#
# Processing 'img104.png'
# PSNR: 34.64 dB, SSIM: 0.9632
#
# Processing 'img1040.png'
# PSNR: 35.72 dB, SSIM: 0.9672
#
# Processing 'img1041.png'
# PSNR: 40.35 dB, SSIM: 0.9757
#
# Processing 'img1042.png'
# PSNR: 42.30 dB, SSIM: 0.9865
#
# Processing 'img1043.png'
# PSNR: 41.56 dB, SSIM: 0.9794
#
# Processing 'img1044.png'
# PSNR: 40.60 dB, SSIM: 0.9831
#
# Processing 'img105.png'
# PSNR: 35.87 dB, SSIM: 0.9703
#
# Processing 'img106.png'
# PSNR: 36.85 dB, SSIM: 0.9733
#
# Processing 'img107.png'
# PSNR: 42.43 dB, SSIM: 0.9874
#
# Processing 'img108.png'
# PSNR: 40.85 dB, SSIM: 0.9841
#
# Processing 'img109.png'
# PSNR: 34.63 dB, SSIM: 0.9598
#
# Processing 'img11.png'
# PSNR: 39.95 dB, SSIM: 0.9778
#
# Processing 'img110.png'
# PSNR: 37.94 dB, SSIM: 0.9756
#
# Processing 'img111.png'
# PSNR: 34.58 dB, SSIM: 0.9594
#
# Processing 'img112.png'
# PSNR: 41.90 dB, SSIM: 0.9784
#
# Processing 'img113.png'
# PSNR: 42.34 dB, SSIM: 0.9859
#
# Processing 'img114.png'
# PSNR: 32.86 dB, SSIM: 0.9491
#
# Processing 'img115.png'
# PSNR: 41.77 dB, SSIM: 0.9827
#
# Processing 'img116.png'
# PSNR: 37.75 dB, SSIM: 0.9773
#
# Processing 'img117.png'
# PSNR: 40.82 dB, SSIM: 0.9814
#
# Processing 'img118.png'
# PSNR: 39.35 dB, SSIM: 0.9773
#
# Processing 'img119.png'
# PSNR: 38.15 dB, SSIM: 0.9737
#
# Processing 'img12.png'
# PSNR: 38.48 dB, SSIM: 0.9729
#
# Processing 'img120.png'
# PSNR: 36.94 dB, SSIM: 0.9696
#
# Processing 'img121.png'
# PSNR: 33.67 dB, SSIM: 0.9551
#
# Processing 'img122.png'
# PSNR: 41.81 dB, SSIM: 0.9802
#
# Processing 'img123.png'
# PSNR: 40.11 dB, SSIM: 0.9752
#
# Processing 'img124.png'
# PSNR: 34.93 dB, SSIM: 0.9652
#
# Processing 'img125.png'
# PSNR: 38.63 dB, SSIM: 0.9717
#
# Processing 'img126.png'
# PSNR: 33.51 dB, SSIM: 0.9510
#
# Processing 'img127.png'
# PSNR: 32.71 dB, SSIM: 0.9443
#
# Processing 'img13.png'
# PSNR: 40.22 dB, SSIM: 0.9766
#
# Processing 'img131.png'
# PSNR: 37.53 dB, SSIM: 0.9710
#
# Processing 'img132.png'
# PSNR: 44.05 dB, SSIM: 0.9889
#
# Processing 'img133.png'
# PSNR: 40.74 dB, SSIM: 0.9805
#
# Processing 'img134.png'
# PSNR: 39.25 dB, SSIM: 0.9765
#
# Processing 'img135.png'
# PSNR: 35.84 dB, SSIM: 0.9658
#
# Processing 'img136.png'
# PSNR: 38.02 dB, SSIM: 0.9726
#
# Processing 'img137.png'
# PSNR: 36.85 dB, SSIM: 0.9688
#
# Processing 'img14.png'
# PSNR: 37.14 dB, SSIM: 0.9674
#
# Processing 'img140.png'
# PSNR: 32.52 dB, SSIM: 0.9333
#
# Processing 'img141.png'
# PSNR: 32.44 dB, SSIM: 0.9341
#
# Processing 'img142.png'
# PSNR: 31.70 dB, SSIM: 0.9269
#
# Processing 'img143.png'
# PSNR: 31.86 dB, SSIM: 0.9354
#
# Processing 'img144.png'
# PSNR: 37.89 dB, SSIM: 0.9714
#
# Processing 'img145.png'
# PSNR: 36.74 dB, SSIM: 0.9683
#
# Processing 'img146.png'
# PSNR: 34.73 dB, SSIM: 0.9608
#
# Processing 'img147.png'
# PSNR: 32.70 dB, SSIM: 0.9444
#
# Processing 'img148.png'
# PSNR: 32.82 dB, SSIM: 0.9504
#
# Processing 'img149.png'
# PSNR: 37.43 dB, SSIM: 0.9680
#
# Processing 'img15.png'
# PSNR: 46.04 dB, SSIM: 0.9919
#
# Processing 'img150.png'
# PSNR: 32.37 dB, SSIM: 0.9432
#
# Processing 'img151.png'
# PSNR: 40.67 dB, SSIM: 0.9798
#
# Processing 'img152.png'
# PSNR: 43.78 dB, SSIM: 0.9888
#
# Processing 'img153.png'
# PSNR: 41.63 dB, SSIM: 0.9849
#
# Processing 'img154.png'
# PSNR: 40.43 dB, SSIM: 0.9787
#
# Processing 'img155.png'
# PSNR: 31.72 dB, SSIM: 0.9278
#
# Processing 'img156.png'
# PSNR: 34.80 dB, SSIM: 0.9700
#
# Processing 'img157.png'
# PSNR: 41.59 dB, SSIM: 0.9781
#
# Processing 'img158.png'
# PSNR: 44.48 dB, SSIM: 0.9898
#
# Processing 'img159.png'
# PSNR: 33.94 dB, SSIM: 0.9635
#
# Processing 'img16.png'
# PSNR: 43.84 dB, SSIM: 0.9870
#
# Processing 'img160.png'
# PSNR: 40.28 dB, SSIM: 0.9748
#
# Processing 'img161.png'
# PSNR: 38.72 dB, SSIM: 0.9715
#
# Processing 'img162.png'
# PSNR: 37.90 dB, SSIM: 0.9782
#
# Processing 'img163.png'
# PSNR: 33.77 dB, SSIM: 0.9598
#
# Processing 'img164.png'
# PSNR: 38.20 dB, SSIM: 0.9625
#
# Processing 'img165.png'
# PSNR: 38.08 dB, SSIM: 0.9748
#
# Processing 'img166.png'
# PSNR: 37.00 dB, SSIM: 0.9721
#
# Processing 'img167.png'
# PSNR: 35.92 dB, SSIM: 0.9730
#
# Processing 'img168.png'
# PSNR: 40.61 dB, SSIM: 0.9795
#
# Processing 'img169.png'
# PSNR: 33.95 dB, SSIM: 0.9585
#
# Processing 'img17.png'
# PSNR: 37.38 dB, SSIM: 0.9669
#
# Processing 'img170.png'
# PSNR: 34.76 dB, SSIM: 0.9605
#
# Processing 'img171.png'
# PSNR: 40.55 dB, SSIM: 0.9815
#
# Processing 'img172.png'
# PSNR: 31.99 dB, SSIM: 0.9427
#
# Processing 'img173.png'
# PSNR: 39.77 dB, SSIM: 0.9700
#
# Processing 'img174.png'
# PSNR: 34.63 dB, SSIM: 0.9602
#
# Processing 'img175.png'
# PSNR: 36.71 dB, SSIM: 0.9660
#
# Processing 'img176.png'
# PSNR: 40.46 dB, SSIM: 0.9809
#
# Processing 'img177.png'
# PSNR: 42.17 dB, SSIM: 0.9817
#
# Processing 'img178.png'
# PSNR: 40.20 dB, SSIM: 0.9745
#
# Processing 'img179.png'
# PSNR: 42.50 dB, SSIM: 0.9872
#
# Processing 'img18.png'
# PSNR: 37.13 dB, SSIM: 0.9659
#
# Processing 'img180.png'
# PSNR: 38.53 dB, SSIM: 0.9673
#
# Processing 'img181.png'
# PSNR: 37.37 dB, SSIM: 0.9677
#
# Processing 'img182.png'
# PSNR: 37.94 dB, SSIM: 0.9749
#
# Processing 'img183.png'
# PSNR: 40.82 dB, SSIM: 0.9824
#
# Processing 'img184.png'
# PSNR: 32.73 dB, SSIM: 0.9461
#
# Processing 'img185.png'
# PSNR: 40.54 dB, SSIM: 0.9815
#
# Processing 'img186.png'
# PSNR: 31.85 dB, SSIM: 0.9359
#
# Processing 'img187.png'
# PSNR: 32.00 dB, SSIM: 0.9433
#
# Processing 'img188.png'
# PSNR: 35.84 dB, SSIM: 0.9688
#
# Processing 'img189.png'
# PSNR: 34.77 dB, SSIM: 0.9651
#
# Processing 'img19.png'
# PSNR: 37.03 dB, SSIM: 0.9667
#
# Processing 'img190.png'
# PSNR: 44.85 dB, SSIM: 0.9895
#
# Processing 'img191.png'
# PSNR: 32.99 dB, SSIM: 0.9476
#
# Processing 'img192.png'
# PSNR: 31.91 dB, SSIM: 0.9371
#
# Processing 'img193.png'
# PSNR: 32.02 dB, SSIM: 0.9441
#
# Processing 'img194.png'
# PSNR: 46.57 dB, SSIM: 0.9927
#
# Processing 'img195.png'
# PSNR: 44.44 dB, SSIM: 0.9885
#
# Processing 'img196.png'
# PSNR: 40.13 dB, SSIM: 0.9723
#
# Processing 'img197.png'
# PSNR: 38.50 dB, SSIM: 0.9662
#
# Processing 'img198.png'
# PSNR: 40.65 dB, SSIM: 0.9825
#
# Processing 'img199.png'
# PSNR: 44.42 dB, SSIM: 0.9902
#
# Processing 'img2.png'
# PSNR: 38.01 dB, SSIM: 0.9750
#
# Processing 'img20.png'
# PSNR: 42.58 dB, SSIM: 0.9866
#
# Processing 'img200.png'
# PSNR: 32.75 dB, SSIM: 0.9474
#
# Processing 'img201.png'
# PSNR: 36.38 dB, SSIM: 0.9622
#
# Processing 'img202.png'
# PSNR: 32.89 dB, SSIM: 0.9525
#
# Processing 'img203.png'
# PSNR: 32.21 dB, SSIM: 0.9476
#
# Processing 'img204.png'
# PSNR: 44.40 dB, SSIM: 0.9888
#
# Processing 'img205.png'
# PSNR: 41.85 dB, SSIM: 0.9823
#
# Processing 'img206.png'
# PSNR: 38.81 dB, SSIM: 0.9682
#
# Processing 'img207.png'
# PSNR: 32.67 dB, SSIM: 0.9459
#
# Processing 'img208.png'
# PSNR: 32.12 dB, SSIM: 0.9456
#
# Processing 'img209.png'
# PSNR: 46.30 dB, SSIM: 0.9914
#
# Processing 'img21.png'
# PSNR: 34.20 dB, SSIM: 0.9560
#
# Processing 'img210.png'
# PSNR: 43.96 dB, SSIM: 0.9869
#
# Processing 'img211.png'
# PSNR: 41.42 dB, SSIM: 0.9778
#
# Processing 'img212.png'
# PSNR: 36.35 dB, SSIM: 0.9657
#
# Processing 'img213.png'
# PSNR: 37.84 dB, SSIM: 0.9505
#
# Processing 'img214.png'
# PSNR: 36.21 dB, SSIM: 0.9318
#
# Processing 'img215.png'
# PSNR: 31.60 dB, SSIM: 0.9242
#
# Processing 'img216.png'
# PSNR: 30.98 dB, SSIM: 0.9260
#
# Processing 'img217.png'
# PSNR: 33.76 dB, SSIM: 0.9613
#
# Processing 'img218.png'
# PSNR: 33.12 dB, SSIM: 0.9587
#
# Processing 'img219.png'
# PSNR: 49.68 dB, SSIM: 0.9961
#
# Processing 'img22.png'
# PSNR: 33.43 dB, SSIM: 0.9531
#
# Processing 'img220.png'
# PSNR: 47.10 dB, SSIM: 0.9938
#
# Processing 'img221.png'
# PSNR: 44.31 dB, SSIM: 0.9890
#
# Processing 'img222.png'
# PSNR: 40.51 dB, SSIM: 0.9775
#
# Processing 'img223.png'
# PSNR: 41.29 dB, SSIM: 0.9770
#
# Processing 'img224.png'
# PSNR: 44.17 dB, SSIM: 0.9868
#
# Processing 'img225.png'
# PSNR: 31.76 dB, SSIM: 0.9317
#
# Processing 'img226.png'
# PSNR: 32.09 dB, SSIM: 0.9456
#
# Processing 'img227.png'
# PSNR: 43.66 dB, SSIM: 0.9868
#
# Processing 'img228.png'
# PSNR: 40.06 dB, SSIM: 0.9727
#
# Processing 'img229.png'
# PSNR: 31.25 dB, SSIM: 0.9332
#
# Processing 'img23.png'
# PSNR: 40.42 dB, SSIM: 0.9774
#
# Processing 'img230.png'
# PSNR: 49.81 dB, SSIM: 0.9965
#
# Processing 'img231.png'
# PSNR: 40.21 dB, SSIM: 0.9776
#
# Processing 'img232.png'
# PSNR: 32.68 dB, SSIM: 0.9464
#
# Processing 'img233.png'
# PSNR: 31.95 dB, SSIM: 0.9392
#
# Processing 'img234.png'
# PSNR: 32.13 dB, SSIM: 0.9470
#
# Processing 'img235.png'
# PSNR: 41.93 dB, SSIM: 0.9788
#
# Processing 'img236.png'
# PSNR: 49.74 dB, SSIM: 0.9964
#
# Processing 'img237.png'
# PSNR: 46.15 dB, SSIM: 0.9921
#
# Processing 'img238.png'
# PSNR: 43.71 dB, SSIM: 0.9870
#
# Processing 'img239.png'
# PSNR: 31.93 dB, SSIM: 0.9406
#
# Processing 'img240.png'
# PSNR: 31.31 dB, SSIM: 0.9356
#
# Processing 'img241.png'
# PSNR: 47.15 dB, SSIM: 0.9935
#
# Processing 'img242.png'
# PSNR: 44.19 dB, SSIM: 0.9874
#
# Processing 'img243.png'
# PSNR: 42.10 dB, SSIM: 0.9812
#
# Processing 'img244.png'
# PSNR: 38.08 dB, SSIM: 0.9719
#
# Processing 'img245.png'
# PSNR: 36.94 dB, SSIM: 0.9693
#
# Processing 'img246.png'
# PSNR: 40.05 dB, SSIM: 0.9710
#
# Processing 'img247.png'
# PSNR: 35.81 dB, SSIM: 0.9634
#
# Processing 'img248.png'
# PSNR: 32.80 dB, SSIM: 0.9463
#
# Processing 'img249.png'
# PSNR: 31.95 dB, SSIM: 0.9383
#
# Processing 'img25.png'
# PSNR: 41.91 dB, SSIM: 0.9788
#
# Processing 'img250.png'
# PSNR: 32.00 dB, SSIM: 0.9414
#
# Processing 'img251.png'
# PSNR: 32.16 dB, SSIM: 0.9484
#
# Processing 'img252.png'
# PSNR: 39.12 dB, SSIM: 0.9752
#
# Processing 'img253.png'
# PSNR: 32.74 dB, SSIM: 0.9486
#
# Processing 'img254.png'
# PSNR: 32.01 dB, SSIM: 0.9419
#
# Processing 'img255.png'
# PSNR: 32.15 dB, SSIM: 0.9486
#
# Processing 'img256.png'
# PSNR: 32.76 dB, SSIM: 0.9445
#
# Processing 'img257.png'
# PSNR: 38.38 dB, SSIM: 0.9604
#
# Processing 'img258.png'
# PSNR: 32.71 dB, SSIM: 0.9477
#
# Processing 'img259.png'
# PSNR: 35.67 dB, SSIM: 0.9714
#
# Processing 'img26.png'
# PSNR: 44.10 dB, SSIM: 0.9907
#
# Processing 'img260.png'
# PSNR: 34.91 dB, SSIM: 0.9678
#
# Processing 'img261.png'
# PSNR: 35.66 dB, SSIM: 0.9711
#
# Processing 'img262.png'
# PSNR: 33.74 dB, SSIM: 0.9555
#
# Processing 'img263.png'
# PSNR: 33.79 dB, SSIM: 0.9592
#
# Processing 'img264.png'
# PSNR: 33.10 dB, SSIM: 0.9554
#
# Processing 'img265.png'
# PSNR: 36.81 dB, SSIM: 0.9744
#
# Processing 'img266.png'
# PSNR: 34.01 dB, SSIM: 0.9632
#
# Processing 'img267.png'
# PSNR: 38.05 dB, SSIM: 0.9794
#
# Processing 'img268.png'
# PSNR: 42.20 dB, SSIM: 0.9864
#
# Processing 'img269.png'
# PSNR: 42.09 dB, SSIM: 0.9867
#
# Processing 'img27.png'
# PSNR: 44.26 dB, SSIM: 0.9892
#
# Processing 'img270.png'
# PSNR: 38.11 dB, SSIM: 0.9760
#
# Processing 'img271.png'
# PSNR: 36.83 dB, SSIM: 0.9705
#
# Processing 'img272.png'
# PSNR: 36.55 dB, SSIM: 0.9694
#
# Processing 'img273.png'
# PSNR: 35.58 dB, SSIM: 0.9656
#
# Processing 'img274.png'
# PSNR: 42.78 dB, SSIM: 0.9886
#
# Processing 'img275.png'
# PSNR: 43.85 dB, SSIM: 0.9895
#
# Processing 'img276.png'
# PSNR: 37.02 dB, SSIM: 0.9766
#
# Processing 'img277.png'
# PSNR: 42.65 dB, SSIM: 0.9882
#
# Processing 'img278.png'
# PSNR: 38.99 dB, SSIM: 0.9774
#
# Processing 'img279.png'
# PSNR: 35.26 dB, SSIM: 0.9585
#
# Processing 'img28.png'
# PSNR: 42.46 dB, SSIM: 0.9854
#
# Processing 'img280.png'
# PSNR: 36.35 dB, SSIM: 0.9686
#
# Processing 'img281.png'
# PSNR: 46.23 dB, SSIM: 0.9923
#
# Processing 'img282.png'
# PSNR: 42.17 dB, SSIM: 0.9856
#
# Processing 'img283.png'
# PSNR: 40.49 dB, SSIM: 0.9820
#
# Processing 'img284.png'
# PSNR: 38.98 dB, SSIM: 0.9781
#
# Processing 'img285.png'
# PSNR: 36.21 dB, SSIM: 0.9672
#
# Processing 'img286.png'
# PSNR: 39.54 dB, SSIM: 0.9808
#
# Processing 'img287.png'
# PSNR: 42.67 dB, SSIM: 0.9876
#
# Processing 'img288.png'
# PSNR: 46.46 dB, SSIM: 0.9933
#
# Processing 'img289.png'
# PSNR: 44.08 dB, SSIM: 0.9890
#
# Processing 'img29.png'
# PSNR: 41.82 dB, SSIM: 0.9853
#
# Processing 'img290.png'
# PSNR: 46.50 dB, SSIM: 0.9929
#
# Processing 'img291.png'
# PSNR: 42.36 dB, SSIM: 0.9847
#
# Processing 'img292.png'
# PSNR: 40.59 dB, SSIM: 0.9803
#
# Processing 'img293.png'
# PSNR: 39.08 dB, SSIM: 0.9761
#
# Processing 'img294.png'
# PSNR: 37.37 dB, SSIM: 0.9686
#
# Processing 'img295.png'
# PSNR: 37.29 dB, SSIM: 0.9668
#
# Processing 'img296.png'
# PSNR: 37.25 dB, SSIM: 0.9699
#
# Processing 'img297.png'
# PSNR: 36.30 dB, SSIM: 0.9663
#
# Processing 'img298.png'
# PSNR: 43.89 dB, SSIM: 0.9906
#
# Processing 'img299.png'
# PSNR: 42.91 dB, SSIM: 0.9886
#
# Processing 'img3.png'
# PSNR: 42.14 dB, SSIM: 0.9830
#
# Processing 'img30.png'
# PSNR: 40.26 dB, SSIM: 0.9816
#
# Processing 'img300.png'
# PSNR: 44.87 dB, SSIM: 0.9908
#
# Processing 'img301.png'
# PSNR: 44.34 dB, SSIM: 0.9884
#
# Processing 'img302.png'
# PSNR: 44.19 dB, SSIM: 0.9897
#
# Processing 'img303.png'
# PSNR: 42.46 dB, SSIM: 0.9856
#
# Processing 'img304.png'
# PSNR: 39.15 dB, SSIM: 0.9769
#
# Processing 'img305.png'
# PSNR: 37.72 dB, SSIM: 0.9716
#
# Processing 'img306.png'
# PSNR: 37.02 dB, SSIM: 0.9756
#
# Processing 'img307.png'
# PSNR: 37.15 dB, SSIM: 0.9748
#
# Processing 'img308.png'
# PSNR: 42.66 dB, SSIM: 0.9878
#
# Processing 'img309.png'
# PSNR: 43.91 dB, SSIM: 0.9890
#
# Processing 'img31.png'
# PSNR: 38.87 dB, SSIM: 0.9779
#
# Processing 'img310.png'
# PSNR: 42.16 dB, SSIM: 0.9843
#
# Processing 'img311.png'
# PSNR: 38.84 dB, SSIM: 0.9741
#
# Processing 'img312.png'
# PSNR: 42.06 dB, SSIM: 0.9815
#
# Processing 'img313.png'
# PSNR: 36.10 dB, SSIM: 0.9574
#
# Processing 'img314.png'
# PSNR: 35.07 dB, SSIM: 0.9478
#
# Processing 'img315.png'
# PSNR: 37.27 dB, SSIM: 0.9769
#
# Processing 'img316.png'
# PSNR: 43.00 dB, SSIM: 0.9887
#
# Processing 'img317.png'
# PSNR: 44.24 dB, SSIM: 0.9906
#
# Processing 'img318.png'
# PSNR: 42.63 dB, SSIM: 0.9867
#
# Processing 'img319.png'
# PSNR: 39.31 dB, SSIM: 0.9783
#
# Processing 'img32.png'
# PSNR: 38.47 dB, SSIM: 0.9770
#
# Processing 'img320.png'
# PSNR: 38.01 dB, SSIM: 0.9729
#
# Processing 'img321.png'
# PSNR: 37.72 dB, SSIM: 0.9731
#
# Processing 'img322.png'
# PSNR: 37.62 dB, SSIM: 0.9717
#
# Processing 'img323.png'
# PSNR: 40.07 dB, SSIM: 0.9734
#
# Processing 'img324.png'
# PSNR: 37.58 dB, SSIM: 0.9738
#
# Processing 'img325.png'
# PSNR: 36.61 dB, SSIM: 0.9712
#
# Processing 'img326.png'
# PSNR: 46.32 dB, SSIM: 0.9930
#
# Processing 'img327.png'
# PSNR: 44.28 dB, SSIM: 0.9882
#
# Processing 'img328.png'
# PSNR: 46.47 dB, SSIM: 0.9934
#
# Processing 'img329.png'
# PSNR: 44.53 dB, SSIM: 0.9903
#
# Processing 'img33.png'
# PSNR: 37.48 dB, SSIM: 0.9717
#
# Processing 'img330.png'
# PSNR: 39.43 dB, SSIM: 0.9788
#
# Processing 'img331.png'
# PSNR: 38.96 dB, SSIM: 0.9789
#
# Processing 'img332.png'
# PSNR: 37.65 dB, SSIM: 0.9724
#
# Processing 'img333.png'
# PSNR: 36.65 dB, SSIM: 0.9677
#
# Processing 'img334.png'
# PSNR: 37.79 dB, SSIM: 0.9781
#
# Processing 'img335.png'
# PSNR: 35.26 dB, SSIM: 0.9551
#
# Processing 'img336.png'
# PSNR: 36.68 dB, SSIM: 0.9733
#
# Processing 'img337.png'
# PSNR: 37.10 dB, SSIM: 0.9760
#
# Processing 'img338.png'
# PSNR: 42.76 dB, SSIM: 0.9879
#
# Processing 'img339.png'
# PSNR: 44.72 dB, SSIM: 0.9905
#
# Processing 'img34.png'
# PSNR: 37.29 dB, SSIM: 0.9755
#
# Processing 'img340.png'
# PSNR: 43.87 dB, SSIM: 0.9895
#
# Processing 'img341.png'
# PSNR: 42.22 dB, SSIM: 0.9855
#
# Processing 'img342.png'
# PSNR: 40.54 dB, SSIM: 0.9812
#
# Processing 'img343.png'
# PSNR: 39.11 dB, SSIM: 0.9778
#
# Processing 'img344.png'
# PSNR: 37.74 dB, SSIM: 0.9709
#
# Processing 'img345.png'
# PSNR: 37.49 dB, SSIM: 0.9697
#
# Processing 'img346.png'
# PSNR: 34.41 dB, SSIM: 0.9503
#
# Processing 'img347.png'
# PSNR: 37.32 dB, SSIM: 0.9673
#
# Processing 'img348.png'
# PSNR: 40.51 dB, SSIM: 0.9789
#
# Processing 'img349.png'
# PSNR: 37.23 dB, SSIM: 0.9670
#
# Processing 'img35.png'
# PSNR: 41.61 dB, SSIM: 0.9792
#
# Processing 'img350.png'
# PSNR: 44.64 dB, SSIM: 0.9893
#
# Processing 'img351.png'
# PSNR: 43.76 dB, SSIM: 0.9881
#
# Processing 'img352.png'
# PSNR: 42.15 dB, SSIM: 0.9842
#
# Processing 'img353.png'
# PSNR: 40.53 dB, SSIM: 0.9795
#
# Processing 'img354.png'
# PSNR: 37.60 dB, SSIM: 0.9669
#
# Processing 'img355.png'
# PSNR: 37.28 dB, SSIM: 0.9654
#
# Processing 'img356.png'
# PSNR: 37.14 dB, SSIM: 0.9670
#
# Processing 'img357.png'
# PSNR: 42.45 dB, SSIM: 0.9866
#
# Processing 'img358.png'
# PSNR: 36.22 dB, SSIM: 0.9647
#
# Processing 'img359.png'
# PSNR: 40.73 dB, SSIM: 0.9803
#
# Processing 'img36.png'
# PSNR: 36.35 dB, SSIM: 0.9743
#
# Processing 'img360.png'
# PSNR: 39.21 dB, SSIM: 0.9755
#
# Processing 'img361.png'
# PSNR: 38.89 dB, SSIM: 0.9754
#
# Processing 'img362.png'
# PSNR: 37.62 dB, SSIM: 0.9674
#
# Processing 'img363.png'
# PSNR: 37.49 dB, SSIM: 0.9695
#
# Processing 'img364.png'
# PSNR: 44.56 dB, SSIM: 0.9895
#
# Processing 'img365.png'
# PSNR: 43.80 dB, SSIM: 0.9871
#
# Processing 'img366.png'
# PSNR: 37.23 dB, SSIM: 0.9770
#
# Processing 'img367.png'
# PSNR: 42.93 dB, SSIM: 0.9886
#
# Processing 'img368.png'
# PSNR: 44.68 dB, SSIM: 0.9883
#
# Processing 'img369.png'
# PSNR: 44.35 dB, SSIM: 0.9889
#
# Processing 'img37.png'
# PSNR: 41.36 dB, SSIM: 0.9819
#
# Processing 'img370.png'
# PSNR: 42.45 dB, SSIM: 0.9845
#
# Processing 'img371.png'
# PSNR: 37.74 dB, SSIM: 0.9682
#
# Processing 'img372.png'
# PSNR: 39.39 dB, SSIM: 0.9803
#
# Processing 'img373.png'
# PSNR: 42.65 dB, SSIM: 0.9875
#
# Processing 'img374.png'
# PSNR: 46.40 dB, SSIM: 0.9932
#
# Processing 'img375.png'
# PSNR: 41.25 dB, SSIM: 0.9764
#
# Processing 'img376.png'
# PSNR: 37.03 dB, SSIM: 0.9753
#
# Processing 'img377.png'
# PSNR: 42.63 dB, SSIM: 0.9876
#
# Processing 'img378.png'
# PSNR: 43.95 dB, SSIM: 0.9884
#
# Processing 'img379.png'
# PSNR: 43.79 dB, SSIM: 0.9860
#
# Processing 'img38.png'
# PSNR: 43.30 dB, SSIM: 0.9848
#
# Processing 'img380.png'
# PSNR: 42.12 dB, SSIM: 0.9845
#
# Processing 'img381.png'
# PSNR: 40.46 dB, SSIM: 0.9796
#
# Processing 'img382.png'
# PSNR: 37.52 dB, SSIM: 0.9685
#
# Processing 'img383.png'
# PSNR: 37.35 dB, SSIM: 0.9671
#
# Processing 'img384.png'
# PSNR: 36.33 dB, SSIM: 0.9660
#
# Processing 'img385.png'
# PSNR: 44.35 dB, SSIM: 0.9892
#
# Processing 'img386.png'
# PSNR: 43.65 dB, SSIM: 0.9869
#
# Processing 'img387.png'
# PSNR: 41.44 dB, SSIM: 0.9772
#
# Processing 'img388.png'
# PSNR: 39.63 dB, SSIM: 0.9812
#
# Processing 'img389.png'
# PSNR: 42.83 dB, SSIM: 0.9879
#
# Processing 'img39.png'
# PSNR: 42.53 dB, SSIM: 0.9863
#
# Processing 'img390.png'
# PSNR: 41.71 dB, SSIM: 0.9780
#
# Processing 'img391.png'
# PSNR: 46.28 dB, SSIM: 0.9924
#
# Processing 'img392.png'
# PSNR: 44.20 dB, SSIM: 0.9890
#
# Processing 'img393.png'
# PSNR: 42.28 dB, SSIM: 0.9843
#
# Processing 'img394.png'
# PSNR: 40.52 dB, SSIM: 0.9799
#
# Processing 'img395.png'
# PSNR: 39.03 dB, SSIM: 0.9757
#
# Processing 'img396.png'
# PSNR: 37.64 dB, SSIM: 0.9684
#
# Processing 'img397.png'
# PSNR: 37.37 dB, SSIM: 0.9666
#
# Processing 'img398.png'
# PSNR: 37.30 dB, SSIM: 0.9689
#
# Processing 'img399.png'
# PSNR: 36.32 dB, SSIM: 0.9653
#
# Processing 'img4.png'
# PSNR: 40.34 dB, SSIM: 0.9781
#
# Processing 'img40.png'
# PSNR: 40.98 dB, SSIM: 0.9742
#
# Processing 'img400.png'
# PSNR: 41.52 dB, SSIM: 0.9783
#
# Processing 'img401.png'
# PSNR: 42.06 dB, SSIM: 0.9851
#
# Processing 'img402.png'
# PSNR: 41.38 dB, SSIM: 0.9764
#
# Processing 'img403.png'
# PSNR: 37.33 dB, SSIM: 0.9775
#
# Processing 'img404.png'
# PSNR: 42.96 dB, SSIM: 0.9886
#
# Processing 'img405.png'
# PSNR: 44.43 dB, SSIM: 0.9893
#
# Processing 'img406.png'
# PSNR: 42.54 dB, SSIM: 0.9852
#
# Processing 'img407.png'
# PSNR: 41.85 dB, SSIM: 0.9855
#
# Processing 'img408.png'
# PSNR: 39.31 dB, SSIM: 0.9776
#
# Processing 'img409.png'
# PSNR: 38.99 dB, SSIM: 0.9780
#
# Processing 'img41.png'
# PSNR: 41.87 dB, SSIM: 0.9839
#
# Processing 'img410.png'
# PSNR: 37.77 dB, SSIM: 0.9704
#
# Processing 'img411.png'
# PSNR: 37.67 dB, SSIM: 0.9726
#
# Processing 'img412.png'
# PSNR: 44.48 dB, SSIM: 0.9877
#
# Processing 'img413.png'
# PSNR: 36.62 dB, SSIM: 0.9698
#
# Processing 'img414.png'
# PSNR: 44.25 dB, SSIM: 0.9890
#
# Processing 'img415.png'
# PSNR: 41.15 dB, SSIM: 0.9741
#
# Processing 'img416.png'
# PSNR: 37.12 dB, SSIM: 0.9748
#
# Processing 'img417.png'
# PSNR: 39.55 dB, SSIM: 0.9809
#
# Processing 'img418.png'
# PSNR: 42.76 dB, SSIM: 0.9878
#
# Processing 'img419.png'
# PSNR: 46.39 dB, SSIM: 0.9925
#
# Processing 'img42.png'
# PSNR: 39.44 dB, SSIM: 0.9640
#
# Processing 'img420.png'
# PSNR: 44.16 dB, SSIM: 0.9886
#
# Processing 'img421.png'
# PSNR: 42.24 dB, SSIM: 0.9844
#
# Processing 'img422.png'
# PSNR: 39.05 dB, SSIM: 0.9757
#
# Processing 'img423.png'
# PSNR: 43.66 dB, SSIM: 0.9858
#
# Processing 'img424.png'
# PSNR: 37.72 dB, SSIM: 0.9683
#
# Processing 'img425.png'
# PSNR: 37.52 dB, SSIM: 0.9666
#
# Processing 'img426.png'
# PSNR: 37.43 dB, SSIM: 0.9655
#
# Processing 'img427.png'
# PSNR: 37.36 dB, SSIM: 0.9673
#
# Processing 'img428.png'
# PSNR: 36.31 dB, SSIM: 0.9634
#
# Processing 'img429.png'
# PSNR: 41.29 dB, SSIM: 0.9759
#
# Processing 'img43.png'
# PSNR: 41.47 dB, SSIM: 0.9781
#
# Processing 'img430.png'
# PSNR: 41.13 dB, SSIM: 0.9738
#
# Processing 'img431.png'
# PSNR: 37.07 dB, SSIM: 0.9744
#
# Processing 'img432.png'
# PSNR: 39.45 dB, SSIM: 0.9803
#
# Processing 'img433.png'
# PSNR: 42.70 dB, SSIM: 0.9876
#
# Processing 'img434.png'
# PSNR: 39.09 dB, SSIM: 0.9779
#
# Processing 'img435.png'
# PSNR: 44.03 dB, SSIM: 0.9882
#
# Processing 'img436.png'
# PSNR: 42.17 dB, SSIM: 0.9840
#
# Processing 'img437.png'
# PSNR: 40.41 dB, SSIM: 0.9791
#
# Processing 'img438.png'
# PSNR: 38.94 dB, SSIM: 0.9749
#
# Processing 'img439.png'
# PSNR: 37.61 dB, SSIM: 0.9666
#
# Processing 'img44.png'
# PSNR: 39.74 dB, SSIM: 0.9680
#
# Processing 'img440.png'
# PSNR: 37.41 dB, SSIM: 0.9655
#
# Processing 'img441.png'
# PSNR: 37.33 dB, SSIM: 0.9646
#
# Processing 'img442.png'
# PSNR: 37.29 dB, SSIM: 0.9669
#
# Processing 'img443.png'
# PSNR: 36.24 dB, SSIM: 0.9632
#
# Processing 'img444.png'
# PSNR: 37.10 dB, SSIM: 0.9653
#
# Processing 'img445.png'
# PSNR: 42.08 dB, SSIM: 0.9865
#
# Processing 'img446.png'
# PSNR: 37.06 dB, SSIM: 0.9647
#
# Processing 'img447.png'
# PSNR: 41.02 dB, SSIM: 0.9756
#
# Processing 'img448.png'
# PSNR: 37.86 dB, SSIM: 0.9801
#
# Processing 'img449.png'
# PSNR: 37.00 dB, SSIM: 0.9750
#
# Processing 'img45.png'
# PSNR: 39.58 dB, SSIM: 0.9657
#
# Processing 'img450.png'
# PSNR: 39.47 dB, SSIM: 0.9806
#
# Processing 'img451.png'
# PSNR: 42.74 dB, SSIM: 0.9880
#
# Processing 'img452.png'
# PSNR: 44.00 dB, SSIM: 0.9878
#
# Processing 'img453.png'
# PSNR: 40.25 dB, SSIM: 0.9792
#
# Processing 'img454.png'
# PSNR: 37.48 dB, SSIM: 0.9706
#
# Processing 'img455.png'
# PSNR: 36.35 dB, SSIM: 0.9621
#
# Processing 'img456.png'
# PSNR: 36.32 dB, SSIM: 0.9606
#
# Processing 'img457.png'
# PSNR: 36.92 dB, SSIM: 0.9637
#
# Processing 'img458.png'
# PSNR: 36.29 dB, SSIM: 0.9637
#
# Processing 'img459.png'
# PSNR: 44.83 dB, SSIM: 0.9906
#
# Processing 'img46.png'
# PSNR: 36.33 dB, SSIM: 0.9647
#
# Processing 'img460.png'
# PSNR: 39.70 dB, SSIM: 0.9648
#
# Processing 'img461.png'
# PSNR: 37.08 dB, SSIM: 0.9758
#
# Processing 'img462.png'
# PSNR: 39.49 dB, SSIM: 0.9808
#
# Processing 'img463.png'
# PSNR: 43.95 dB, SSIM: 0.9884
#
# Processing 'img464.png'
# PSNR: 42.16 dB, SSIM: 0.9847
#
# Processing 'img465.png'
# PSNR: 40.33 dB, SSIM: 0.9797
#
# Processing 'img466.png'
# PSNR: 37.81 dB, SSIM: 0.9685
#
# Processing 'img467.png'
# PSNR: 37.55 dB, SSIM: 0.9699
#
# Processing 'img468.png'
# PSNR: 35.20 dB, SSIM: 0.9613
#
# Processing 'img469.png'
# PSNR: 36.39 dB, SSIM: 0.9592
#
# Processing 'img470.png'
# PSNR: 37.37 dB, SSIM: 0.9667
#
# Processing 'img471.png'
# PSNR: 36.42 dB, SSIM: 0.9609
#
# Processing 'img472.png'
# PSNR: 43.70 dB, SSIM: 0.9886
#
# Processing 'img473.png'
# PSNR: 39.77 dB, SSIM: 0.9662
#
# Processing 'img474.png'
# PSNR: 36.89 dB, SSIM: 0.9745
#
# Processing 'img475.png'
# PSNR: 44.80 dB, SSIM: 0.9907
#
# Processing 'img476.png'
# PSNR: 37.05 dB, SSIM: 0.9756
#
# Processing 'img477.png'
# PSNR: 39.40 dB, SSIM: 0.9800
#
# Processing 'img478.png'
# PSNR: 42.71 dB, SSIM: 0.9879
#
# Processing 'img479.png'
# PSNR: 38.30 dB, SSIM: 0.9727
#
# Processing 'img480.png'
# PSNR: 46.22 dB, SSIM: 0.9923
#
# Processing 'img481.png'
# PSNR: 44.09 dB, SSIM: 0.9886
#
# Processing 'img482.png'
# PSNR: 36.41 dB, SSIM: 0.9603
#
# Processing 'img483.png'
# PSNR: 37.37 dB, SSIM: 0.9671
#
# Processing 'img484.png'
# PSNR: 36.39 dB, SSIM: 0.9601
#
# Processing 'img485.png'
# PSNR: 36.41 dB, SSIM: 0.9652
#
# Processing 'img486.png'
# PSNR: 42.12 dB, SSIM: 0.9821
#
# Processing 'img487.png'
# PSNR: 41.68 dB, SSIM: 0.9791
#
# Processing 'img488.png'
# PSNR: 39.84 dB, SSIM: 0.9659
#
# Processing 'img489.png'
# PSNR: 39.48 dB, SSIM: 0.9806
#
# Processing 'img490.png'
# PSNR: 37.01 dB, SSIM: 0.9648
#
# Processing 'img491.png'
# PSNR: 42.85 dB, SSIM: 0.9884
#
# Processing 'img492.png'
# PSNR: 46.59 dB, SSIM: 0.9925
#
# Processing 'img493.png'
# PSNR: 44.28 dB, SSIM: 0.9886
#
# Processing 'img494.png'
# PSNR: 36.57 dB, SSIM: 0.9623
#
# Processing 'img495.png'
# PSNR: 36.35 dB, SSIM: 0.9612
#
# Processing 'img496.png'
# PSNR: 36.31 dB, SSIM: 0.9597
#
# Processing 'img497.png'
# PSNR: 36.34 dB, SSIM: 0.9626
#
# Processing 'img498.png'
# PSNR: 39.61 dB, SSIM: 0.9810
#
# Processing 'img499.png'
# PSNR: 42.83 dB, SSIM: 0.9879
#
# Processing 'img5.png'
# PSNR: 38.76 dB, SSIM: 0.9733
#
# Processing 'img50.png'
# PSNR: 34.29 dB, SSIM: 0.9580
#
# Processing 'img500.png'
# PSNR: 44.03 dB, SSIM: 0.9885
#
# Processing 'img501.png'
# PSNR: 36.05 dB, SSIM: 0.9640
#
# Processing 'img502.png'
# PSNR: 42.37 dB, SSIM: 0.9853
#
# Processing 'img503.png'
# PSNR: 40.56 dB, SSIM: 0.9808
#
# Processing 'img504.png'
# PSNR: 37.53 dB, SSIM: 0.9725
#
# Processing 'img505.png'
# PSNR: 37.53 dB, SSIM: 0.9710
#
# Processing 'img506.png'
# PSNR: 36.53 dB, SSIM: 0.9677
#
# Processing 'img507.png'
# PSNR: 41.22 dB, SSIM: 0.9767
#
# Processing 'img508.png'
# PSNR: 42.89 dB, SSIM: 0.9884
#
# Processing 'img509.png'
# PSNR: 42.72 dB, SSIM: 0.9881
#
# Processing 'img510.png'
# PSNR: 43.97 dB, SSIM: 0.9876
#
# Processing 'img511.png'
# PSNR: 42.16 dB, SSIM: 0.9837
#
# Processing 'img512.png'
# PSNR: 35.16 dB, SSIM: 0.9625
#
# Processing 'img513.png'
# PSNR: 37.43 dB, SSIM: 0.9722
#
# Processing 'img514.png'
# PSNR: 36.34 dB, SSIM: 0.9625
#
# Processing 'img515.png'
# PSNR: 36.34 dB, SSIM: 0.9681
#
# Processing 'img516.png'
# PSNR: 40.25 dB, SSIM: 0.9726
#
# Processing 'img517.png'
# PSNR: 39.92 dB, SSIM: 0.9682
#
# Processing 'img518.png'
# PSNR: 41.19 dB, SSIM: 0.9784
#
# Processing 'img519.png'
# PSNR: 44.35 dB, SSIM: 0.9890
#
# Processing 'img520.png'
# PSNR: 42.08 dB, SSIM: 0.9825
#
# Processing 'img521.png'
# PSNR: 41.53 dB, SSIM: 0.9796
#
# Processing 'img522.png'
# PSNR: 39.85 dB, SSIM: 0.9672
#
# Processing 'img523.png'
# PSNR: 41.22 dB, SSIM: 0.9750
#
# Processing 'img524.png'
# PSNR: 39.58 dB, SSIM: 0.9813
#
# Processing 'img525.png'
# PSNR: 42.41 dB, SSIM: 0.9842
#
# Processing 'img526.png'
# PSNR: 40.59 dB, SSIM: 0.9800
#
# Processing 'img527.png'
# PSNR: 36.43 dB, SSIM: 0.9657
#
# Processing 'img528.png'
# PSNR: 35.57 dB, SSIM: 0.9627
#
# Processing 'img529.png'
# PSNR: 44.56 dB, SSIM: 0.9891
#
# Processing 'img530.png'
# PSNR: 44.42 dB, SSIM: 0.9886
#
# Processing 'img531.png'
# PSNR: 42.44 dB, SSIM: 0.9839
#
# Processing 'img532.png'
# PSNR: 40.53 dB, SSIM: 0.9785
#
# Processing 'img533.png'
# PSNR: 38.93 dB, SSIM: 0.9740
#
# Processing 'img534.png'
# PSNR: 44.36 dB, SSIM: 0.9874
#
# Processing 'img535.png'
# PSNR: 37.60 dB, SSIM: 0.9697
#
# Processing 'img536.png'
# PSNR: 36.38 dB, SSIM: 0.9630
#
# Processing 'img537.png'
# PSNR: 36.33 dB, SSIM: 0.9627
#
# Processing 'img538.png'
# PSNR: 42.15 dB, SSIM: 0.9817
#
# Processing 'img539.png'
# PSNR: 40.51 dB, SSIM: 0.9788
#
# Processing 'img540.png'
# PSNR: 38.96 dB, SSIM: 0.9740
#
# Processing 'img541.png'
# PSNR: 37.61 dB, SSIM: 0.9699
#
# Processing 'img542.png'
# PSNR: 36.37 dB, SSIM: 0.9636
#
# Processing 'img543.png'
# PSNR: 44.67 dB, SSIM: 0.9888
#
# Processing 'img544.png'
# PSNR: 42.34 dB, SSIM: 0.9812
#
# Processing 'img545.png'
# PSNR: 41.24 dB, SSIM: 0.9763
#
# Processing 'img546.png'
# PSNR: 40.44 dB, SSIM: 0.9786
#
# Processing 'img547.png'
# PSNR: 38.92 dB, SSIM: 0.9747
#
# Processing 'img548.png'
# PSNR: 37.52 dB, SSIM: 0.9694
#
# Processing 'img549.png'
# PSNR: 36.32 dB, SSIM: 0.9627
#
# Processing 'img550.png'
# PSNR: 35.28 dB, SSIM: 0.9571
#
# Processing 'img551.png'
# PSNR: 35.30 dB, SSIM: 0.9594
#
# Processing 'img552.png'
# PSNR: 42.28 dB, SSIM: 0.9821
#
# Processing 'img553.png'
# PSNR: 44.04 dB, SSIM: 0.9911
#
# Processing 'img554.png'
# PSNR: 39.81 dB, SSIM: 0.9684
#
# Processing 'img555.png'
# PSNR: 42.20 dB, SSIM: 0.9831
#
# Processing 'img556.png'
# PSNR: 38.83 dB, SSIM: 0.9749
#
# Processing 'img557.png'
# PSNR: 39.54 dB, SSIM: 0.9651
#
# Processing 'img558.png'
# PSNR: 38.87 dB, SSIM: 0.9739
#
# Processing 'img559.png'
# PSNR: 37.53 dB, SSIM: 0.9687
#
# Processing 'img560.png'
# PSNR: 36.28 dB, SSIM: 0.9621
#
# Processing 'img561.png'
# PSNR: 44.69 dB, SSIM: 0.9888
#
# Processing 'img562.png'
# PSNR: 43.74 dB, SSIM: 0.9865
#
# Processing 'img563.png'
# PSNR: 44.19 dB, SSIM: 0.9881
#
# Processing 'img564.png'
# PSNR: 40.42 dB, SSIM: 0.9791
#
# Processing 'img565.png'
# PSNR: 35.26 dB, SSIM: 0.9553
#
# Processing 'img566.png'
# PSNR: 42.17 dB, SSIM: 0.9807
#
# Processing 'img567.png'
# PSNR: 40.16 dB, SSIM: 0.9713
#
# Processing 'img568.png'
# PSNR: 43.41 dB, SSIM: 0.9867
#
# Processing 'img569.png'
# PSNR: 38.31 dB, SSIM: 0.9608
#
# Processing 'img570.png'
# PSNR: 36.43 dB, SSIM: 0.9612
#
# Processing 'img571.png'
# PSNR: 35.27 dB, SSIM: 0.9541
#
# Processing 'img572.png'
# PSNR: 44.41 dB, SSIM: 0.9880
#
# Processing 'img573.png'
# PSNR: 43.47 dB, SSIM: 0.9855
#
# Processing 'img574.png'
# PSNR: 41.40 dB, SSIM: 0.9782
#
# Processing 'img575.png'
# PSNR: 42.60 dB, SSIM: 0.9872
#
# Processing 'img576.png'
# PSNR: 40.08 dB, SSIM: 0.9768
#
# Processing 'img577.png'
# PSNR: 44.10 dB, SSIM: 0.9912
#
# Processing 'img578.png'
# PSNR: 42.38 dB, SSIM: 0.9839
#
# Processing 'img579.png'
# PSNR: 36.97 dB, SSIM: 0.9650
#
# Processing 'img580.png'
# PSNR: 40.50 dB, SSIM: 0.9790
#
# Processing 'img581.png'
# PSNR: 37.50 dB, SSIM: 0.9689
#
# Processing 'img582.png'
# PSNR: 44.67 dB, SSIM: 0.9885
#
# Processing 'img583.png'
# PSNR: 43.86 dB, SSIM: 0.9865
#
# Processing 'img584.png'
# PSNR: 41.78 dB, SSIM: 0.9785
#
# Processing 'img585.png'
# PSNR: 44.05 dB, SSIM: 0.9912
#
# Processing 'img586.png'
# PSNR: 42.25 dB, SSIM: 0.9835
#
# Processing 'img587.png'
# PSNR: 40.44 dB, SSIM: 0.9778
#
# Processing 'img588.png'
# PSNR: 36.18 dB, SSIM: 0.9570
#
# Processing 'img589.png'
# PSNR: 46.90 dB, SSIM: 0.9935
#
# Processing 'img590.png'
# PSNR: 35.79 dB, SSIM: 0.9552
#
# Processing 'img591.png'
# PSNR: 44.70 dB, SSIM: 0.9886
#
# Processing 'img592.png'
# PSNR: 43.87 dB, SSIM: 0.9865
#
# Processing 'img593.png'
# PSNR: 41.77 dB, SSIM: 0.9786
#
# Processing 'img594.png'
# PSNR: 44.10 dB, SSIM: 0.9912
#
# Processing 'img595.png'
# PSNR: 44.21 dB, SSIM: 0.9879
#
# Processing 'img596.png'
# PSNR: 42.27 dB, SSIM: 0.9836
#
# Processing 'img597.png'
# PSNR: 40.47 dB, SSIM: 0.9787
#
# Processing 'img598.png'
# PSNR: 37.53 dB, SSIM: 0.9684
#
# Processing 'img599.png'
# PSNR: 46.74 dB, SSIM: 0.9934
#
# Processing 'img6.png'
# PSNR: 37.45 dB, SSIM: 0.9681
#
# Processing 'img600.png'
# PSNR: 43.86 dB, SSIM: 0.9908
#
# Processing 'img601.png'
# PSNR: 35.70 dB, SSIM: 0.9545
#
# Processing 'img602.png'
# PSNR: 46.46 dB, SSIM: 0.9918
#
# Processing 'img603.png'
# PSNR: 44.05 dB, SSIM: 0.9878
#
# Processing 'img604.png'
# PSNR: 42.15 dB, SSIM: 0.9830
#
# Processing 'img605.png'
# PSNR: 40.35 dB, SSIM: 0.9777
#
# Processing 'img606.png'
# PSNR: 38.83 dB, SSIM: 0.9731
#
# Processing 'img607.png'
# PSNR: 37.49 dB, SSIM: 0.9673
#
# Processing 'img608.png'
# PSNR: 36.13 dB, SSIM: 0.9568
#
# Processing 'img609.png'
# PSNR: 41.68 dB, SSIM: 0.9791
#
# Processing 'img610.png'
# PSNR: 44.08 dB, SSIM: 0.9911
#
# Processing 'img611.png'
# PSNR: 46.79 dB, SSIM: 0.9921
#
# Processing 'img612.png'
# PSNR: 46.11 dB, SSIM: 0.9919
#
# Processing 'img613.png'
# PSNR: 44.30 dB, SSIM: 0.9880
#
# Processing 'img614.png'
# PSNR: 43.63 dB, SSIM: 0.9857
#
# Processing 'img615.png'
# PSNR: 41.04 dB, SSIM: 0.9752
#
# Processing 'img616.png'
# PSNR: 46.91 dB, SSIM: 0.9935
#
# Processing 'img617.png'
# PSNR: 44.71 dB, SSIM: 0.9888
#
# Processing 'img618.png'
# PSNR: 43.79 dB, SSIM: 0.9865
#
# Processing 'img619.png'
# PSNR: 41.82 dB, SSIM: 0.9790
#
# Processing 'img620.png'
# PSNR: 39.92 dB, SSIM: 0.9676
#
# Processing 'img621.png'
# PSNR: 40.65 dB, SSIM: 0.9786
#
# Processing 'img622.png'
# PSNR: 39.01 dB, SSIM: 0.9733
#
# Processing 'img623.png'
# PSNR: 41.68 dB, SSIM: 0.9786
#
# Processing 'img624.png'
# PSNR: 37.59 dB, SSIM: 0.9672
#
# Processing 'img625.png'
# PSNR: 37.33 dB, SSIM: 0.9677
#
# Processing 'img626.png'
# PSNR: 36.23 dB, SSIM: 0.9596
#
# Processing 'img627.png'
# PSNR: 35.41 dB, SSIM: 0.9600
#
# Processing 'img628.png'
# PSNR: 46.70 dB, SSIM: 0.9929
#
# Processing 'img629.png'
# PSNR: 36.78 dB, SSIM: 0.9733
#
# Processing 'img630.png'
# PSNR: 37.38 dB, SSIM: 0.9655
#
# Processing 'img631.png'
# PSNR: 37.09 dB, SSIM: 0.9643
#
# Processing 'img632.png'
# PSNR: 37.04 dB, SSIM: 0.9635
#
# Processing 'img633.png'
# PSNR: 36.04 dB, SSIM: 0.9573
#
# Processing 'img634.png'
# PSNR: 39.99 dB, SSIM: 0.9819
#
# Processing 'img635.png'
# PSNR: 35.18 dB, SSIM: 0.9592
#
# Processing 'img636.png'
# PSNR: 41.34 dB, SSIM: 0.9769
#
# Processing 'img637.png'
# PSNR: 43.78 dB, SSIM: 0.9881
#
# Processing 'img638.png'
# PSNR: 41.84 dB, SSIM: 0.9838
#
# Processing 'img639.png'
# PSNR: 40.09 dB, SSIM: 0.9790
#
# Processing 'img640.png'
# PSNR: 38.72 dB, SSIM: 0.9749
#
# Processing 'img641.png'
# PSNR: 37.39 dB, SSIM: 0.9668
#
# Processing 'img642.png'
# PSNR: 46.06 dB, SSIM: 0.9906
#
# Processing 'img643.png'
# PSNR: 43.28 dB, SSIM: 0.9841
#
# Processing 'img644.png'
# PSNR: 47.08 dB, SSIM: 0.9934
#
# Processing 'img645.png'
# PSNR: 41.27 dB, SSIM: 0.9764
#
# Processing 'img646.png'
# PSNR: 44.74 dB, SSIM: 0.9889
#
# Processing 'img647.png'
# PSNR: 43.97 dB, SSIM: 0.9865
#
# Processing 'img648.png'
# PSNR: 44.10 dB, SSIM: 0.9905
#
# Processing 'img649.png'
# PSNR: 38.99 dB, SSIM: 0.9720
#
# Processing 'img650.png'
# PSNR: 37.24 dB, SSIM: 0.9640
#
# Processing 'img651.png'
# PSNR: 36.21 dB, SSIM: 0.9576
#
# Processing 'img652.png'
# PSNR: 36.26 dB, SSIM: 0.9657
#
# Processing 'img653.png'
# PSNR: 46.01 dB, SSIM: 0.9914
#
# Processing 'img654.png'
# PSNR: 43.78 dB, SSIM: 0.9859
#
# Processing 'img655.png'
# PSNR: 41.71 dB, SSIM: 0.9773
#
# Processing 'img656.png'
# PSNR: 39.49 dB, SSIM: 0.9653
#
# Processing 'img657.png'
# PSNR: 40.53 dB, SSIM: 0.9837
#
# Processing 'img658.png'
# PSNR: 43.95 dB, SSIM: 0.9901
#
# Processing 'img659.png'
# PSNR: 46.71 dB, SSIM: 0.9929
#
# Processing 'img660.png'
# PSNR: 46.68 dB, SSIM: 0.9920
#
# Processing 'img661.png'
# PSNR: 44.14 dB, SSIM: 0.9874
#
# Processing 'img662.png'
# PSNR: 39.88 dB, SSIM: 0.9788
#
# Processing 'img663.png'
# PSNR: 36.03 dB, SSIM: 0.9640
#
# Processing 'img664.png'
# PSNR: 43.86 dB, SSIM: 0.9896
#
# Processing 'img665.png'
# PSNR: 46.74 dB, SSIM: 0.9928
#
# Processing 'img666.png'
# PSNR: 37.93 dB, SSIM: 0.9701
#
# Processing 'img667.png'
# PSNR: 37.39 dB, SSIM: 0.9694
#
# Processing 'img668.png'
# PSNR: 39.16 dB, SSIM: 0.9632
#
# Processing 'img669.png'
# PSNR: 36.88 dB, SSIM: 0.9652
#
# Processing 'img670.png'
# PSNR: 35.99 dB, SSIM: 0.9647
#
# Processing 'img671.png'
# PSNR: 47.03 dB, SSIM: 0.9930
#
# Processing 'img672.png'
# PSNR: 46.15 dB, SSIM: 0.9917
#
# Processing 'img673.png'
# PSNR: 43.90 dB, SSIM: 0.9857
#
# Processing 'img674.png'
# PSNR: 43.30 dB, SSIM: 0.9841
#
# Processing 'img675.png'
# PSNR: 36.74 dB, SSIM: 0.9733
#
# Processing 'img676.png'
# PSNR: 40.45 dB, SSIM: 0.9835
#
# Processing 'img677.png'
# PSNR: 44.01 dB, SSIM: 0.9902
#
# Processing 'img678.png'
# PSNR: 46.64 dB, SSIM: 0.9919
#
# Processing 'img679.png'
# PSNR: 41.17 dB, SSIM: 0.9745
#
# Processing 'img680.png'
# PSNR: 40.06 dB, SSIM: 0.9788
#
# Processing 'img681.png'
# PSNR: 38.55 dB, SSIM: 0.9724
#
# Processing 'img682.png'
# PSNR: 37.07 dB, SSIM: 0.9644
#
# Processing 'img683.png'
# PSNR: 36.07 dB, SSIM: 0.9605
#
# Processing 'img684.png'
# PSNR: 51.18 dB, SSIM: 0.9973
#
# Processing 'img685.png'
# PSNR: 46.13 dB, SSIM: 0.9914
#
# Processing 'img686.png'
# PSNR: 43.85 dB, SSIM: 0.9863
#
# Processing 'img687.png'
# PSNR: 40.98 dB, SSIM: 0.9726
#
# Processing 'img688.png'
# PSNR: 46.80 dB, SSIM: 0.9920
#
# Processing 'img689.png'
# PSNR: 46.58 dB, SSIM: 0.9926
#
# Processing 'img690.png'
# PSNR: 41.22 dB, SSIM: 0.9764
#
# Processing 'img691.png'
# PSNR: 43.50 dB, SSIM: 0.9867
#
# Processing 'img692.png'
# PSNR: 41.68 dB, SSIM: 0.9819
#
# Processing 'img693.png'
# PSNR: 39.93 dB, SSIM: 0.9773
#
# Processing 'img694.png'
# PSNR: 39.64 dB, SSIM: 0.9784
#
# Processing 'img695.png'
# PSNR: 38.09 dB, SSIM: 0.9698
#
# Processing 'img696.png'
# PSNR: 38.07 dB, SSIM: 0.9693
#
# Processing 'img697.png'
# PSNR: 37.95 dB, SSIM: 0.9703
#
# Processing 'img698.png'
# PSNR: 37.00 dB, SSIM: 0.9682
#
# Processing 'img699.png'
# PSNR: 46.17 dB, SSIM: 0.9917
#
# Processing 'img7.png'
# PSNR: 35.04 dB, SSIM: 0.9508
#
# Processing 'img700.png'
# PSNR: 43.82 dB, SSIM: 0.9866
#
# Processing 'img701.png'
# PSNR: 41.80 dB, SSIM: 0.9834
#
# Processing 'img702.png'
# PSNR: 46.76 dB, SSIM: 0.9926
#
# Processing 'img703.png'
# PSNR: 39.83 dB, SSIM: 0.9764
#
# Processing 'img704.png'
# PSNR: 38.10 dB, SSIM: 0.9687
#
# Processing 'img705.png'
# PSNR: 36.46 dB, SSIM: 0.9548
#
# Processing 'img706.png'
# PSNR: 46.76 dB, SSIM: 0.9928
#
# Processing 'img707.png'
# PSNR: 46.06 dB, SSIM: 0.9915
#
# Processing 'img708.png'
# PSNR: 37.24 dB, SSIM: 0.9647
#
# Processing 'img709.png'
# PSNR: 36.94 dB, SSIM: 0.9639
#
# Processing 'img710.png'
# PSNR: 35.81 dB, SSIM: 0.9574
#
# Processing 'img711.png'
# PSNR: 35.13 dB, SSIM: 0.9583
#
# Processing 'img712.png'
# PSNR: 41.16 dB, SSIM: 0.9746
#
# Processing 'img713.png'
# PSNR: 46.88 dB, SSIM: 0.9931
#
# Processing 'img714.png'
# PSNR: 44.50 dB, SSIM: 0.9880
#
# Processing 'img715.png'
# PSNR: 43.53 dB, SSIM: 0.9857
#
# Processing 'img716.png'
# PSNR: 41.65 dB, SSIM: 0.9774
#
# Processing 'img717.png'
# PSNR: 38.77 dB, SSIM: 0.9705
#
# Processing 'img718.png'
# PSNR: 38.33 dB, SSIM: 0.9717
#
# Processing 'img719.png'
# PSNR: 37.08 dB, SSIM: 0.9631
#
# Processing 'img720.png'
# PSNR: 36.99 dB, SSIM: 0.9637
#
# Processing 'img721.png'
# PSNR: 35.98 dB, SSIM: 0.9579
#
# Processing 'img722.png'
# PSNR: 35.14 dB, SSIM: 0.9562
#
# Processing 'img723.png'
# PSNR: 34.89 dB, SSIM: 0.9638
#
# Processing 'img724.png'
# PSNR: 44.06 dB, SSIM: 0.9872
#
# Processing 'img725.png'
# PSNR: 42.06 dB, SSIM: 0.9798
#
# Processing 'img726.png'
# PSNR: 46.27 dB, SSIM: 0.9930
#
# Processing 'img727.png'
# PSNR: 44.36 dB, SSIM: 0.9891
#
# Processing 'img728.png'
# PSNR: 42.51 dB, SSIM: 0.9843
#
# Processing 'img729.png'
# PSNR: 41.81 dB, SSIM: 0.9843
#
# Processing 'img730.png'
# PSNR: 37.57 dB, SSIM: 0.9694
#
# Processing 'img731.png'
# PSNR: 37.46 dB, SSIM: 0.9694
#
# Processing 'img732.png'
# PSNR: 37.44 dB, SSIM: 0.9720
#
# Processing 'img733.png'
# PSNR: 46.70 dB, SSIM: 0.9938
#
# Processing 'img734.png'
# PSNR: 32.25 dB, SSIM: 0.9242
#
# Processing 'img735.png'
# PSNR: 41.88 dB, SSIM: 0.9782
#
# Processing 'img736.png'
# PSNR: 36.79 dB, SSIM: 0.9748
#
# Processing 'img737.png'
# PSNR: 42.29 dB, SSIM: 0.9833
#
# Processing 'img738.png'
# PSNR: 40.51 dB, SSIM: 0.9777
#
# Processing 'img739.png'
# PSNR: 38.89 dB, SSIM: 0.9720
#
# Processing 'img740.png'
# PSNR: 37.21 dB, SSIM: 0.9665
#
# Processing 'img741.png'
# PSNR: 36.12 dB, SSIM: 0.9630
#
# Processing 'img742.png'
# PSNR: 44.58 dB, SSIM: 0.9883
#
# Processing 'img743.png'
# PSNR: 41.68 dB, SSIM: 0.9781
#
# Processing 'img744.png'
# PSNR: 41.23 dB, SSIM: 0.9753
#
# Processing 'img745.png'
# PSNR: 33.65 dB, SSIM: 0.9541
#
# Processing 'img746.png'
# PSNR: 44.23 dB, SSIM: 0.9889
#
# Processing 'img747.png'
# PSNR: 42.39 dB, SSIM: 0.9841
#
# Processing 'img748.png'
# PSNR: 40.58 dB, SSIM: 0.9784
#
# Processing 'img749.png'
# PSNR: 39.05 dB, SSIM: 0.9734
#
# Processing 'img750.png'
# PSNR: 37.49 dB, SSIM: 0.9678
#
# Processing 'img751.png'
# PSNR: 37.35 dB, SSIM: 0.9673
#
# Processing 'img752.png'
# PSNR: 47.33 dB, SSIM: 0.9941
#
# Processing 'img753.png'
# PSNR: 46.31 dB, SSIM: 0.9925
#
# Processing 'img754.png'
# PSNR: 44.01 dB, SSIM: 0.9873
#
# Processing 'img755.png'
# PSNR: 41.95 dB, SSIM: 0.9797
#
# Processing 'img756.png'
# PSNR: 34.63 dB, SSIM: 0.9603
#
# Processing 'img757.png'
# PSNR: 41.42 dB, SSIM: 0.9765
#
# Processing 'img758.png'
# PSNR: 44.68 dB, SSIM: 0.9903
#
# Processing 'img759.png'
# PSNR: 44.13 dB, SSIM: 0.9887
#
# Processing 'img760.png'
# PSNR: 40.52 dB, SSIM: 0.9779
#
# Processing 'img761.png'
# PSNR: 37.69 dB, SSIM: 0.9681
#
# Processing 'img762.png'
# PSNR: 36.32 dB, SSIM: 0.9597
#
# Processing 'img763.png'
# PSNR: 44.36 dB, SSIM: 0.9880
#
# Processing 'img764.png'
# PSNR: 42.02 dB, SSIM: 0.9796
#
# Processing 'img765.png'
# PSNR: 41.43 dB, SSIM: 0.9780
#
# Processing 'img766.png'
# PSNR: 39.51 dB, SSIM: 0.9623
#
# Processing 'img767.png'
# PSNR: 33.23 dB, SSIM: 0.9388
#
# Processing 'img768.png'
# PSNR: 44.57 dB, SSIM: 0.9901
#
# Processing 'img769.png'
# PSNR: 44.04 dB, SSIM: 0.9885
#
# Processing 'img770.png'
# PSNR: 42.21 dB, SSIM: 0.9831
#
# Processing 'img771.png'
# PSNR: 40.35 dB, SSIM: 0.9773
#
# Processing 'img772.png'
# PSNR: 37.55 dB, SSIM: 0.9668
#
# Processing 'img773.png'
# PSNR: 36.21 dB, SSIM: 0.9583
#
# Processing 'img774.png'
# PSNR: 35.36 dB, SSIM: 0.9624
#
# Processing 'img775.png'
# PSNR: 47.26 dB, SSIM: 0.9939
#
# Processing 'img776.png'
# PSNR: 46.33 dB, SSIM: 0.9925
#
# Processing 'img777.png'
# PSNR: 44.03 dB, SSIM: 0.9870
#
# Processing 'img778.png'
# PSNR: 36.18 dB, SSIM: 0.9600
#
# Processing 'img779.png'
# PSNR: 43.79 dB, SSIM: 0.9858
#
# Processing 'img780.png'
# PSNR: 41.89 dB, SSIM: 0.9791
#
# Processing 'img781.png'
# PSNR: 41.34 dB, SSIM: 0.9762
#
# Processing 'img782.png'
# PSNR: 39.67 dB, SSIM: 0.9634
#
# Processing 'img783.png'
# PSNR: 44.22 dB, SSIM: 0.9896
#
# Processing 'img784.png'
# PSNR: 42.41 dB, SSIM: 0.9847
#
# Processing 'img785.png'
# PSNR: 40.53 dB, SSIM: 0.9791
#
# Processing 'img786.png'
# PSNR: 39.04 dB, SSIM: 0.9749
#
# Processing 'img787.png'
# PSNR: 37.69 dB, SSIM: 0.9690
#
# Processing 'img788.png'
# PSNR: 36.46 dB, SSIM: 0.9609
#
# Processing 'img789.png'
# PSNR: 36.38 dB, SSIM: 0.9616
#
# Processing 'img790.png'
# PSNR: 41.18 dB, SSIM: 0.9760
#
# Processing 'img791.png'
# PSNR: 47.05 dB, SSIM: 0.9937
#
# Processing 'img792.png'
# PSNR: 43.78 dB, SSIM: 0.9864
#
# Processing 'img793.png'
# PSNR: 41.70 dB, SSIM: 0.9792
#
# Processing 'img794.png'
# PSNR: 39.88 dB, SSIM: 0.9674
#
# Processing 'img795.png'
# PSNR: 44.22 dB, SSIM: 0.9893
#
# Processing 'img796.png'
# PSNR: 42.41 dB, SSIM: 0.9845
#
# Processing 'img797.png'
# PSNR: 40.61 dB, SSIM: 0.9788
#
# Processing 'img798.png'
# PSNR: 39.10 dB, SSIM: 0.9737
#
# Processing 'img799.png'
# PSNR: 37.67 dB, SSIM: 0.9683
#
# Processing 'img8.png'
# PSNR: 34.08 dB, SSIM: 0.9432
#
# Processing 'img800.png'
# PSNR: 37.38 dB, SSIM: 0.9680
#
# Processing 'img801.png'
# PSNR: 39.36 dB, SSIM: 0.9790
#
# Processing 'img802.png'
# PSNR: 36.30 dB, SSIM: 0.9596
#
# Processing 'img803.png'
# PSNR: 36.41 dB, SSIM: 0.9654
#
# Processing 'img804.png'
# PSNR: 46.38 dB, SSIM: 0.9926
#
# Processing 'img805.png'
# PSNR: 44.12 dB, SSIM: 0.9873
#
# Processing 'img806.png'
# PSNR: 41.96 dB, SSIM: 0.9796
#
# Processing 'img807.png'
# PSNR: 41.36 dB, SSIM: 0.9770
#
# Processing 'img808.png'
# PSNR: 41.18 dB, SSIM: 0.9745
#
# Processing 'img809.png'
# PSNR: 36.33 dB, SSIM: 0.9601
#
# Processing 'img810.png'
# PSNR: 36.37 dB, SSIM: 0.9665
#
# Processing 'img811.png'
# PSNR: 35.54 dB, SSIM: 0.9646
#
# Processing 'img812.png'
# PSNR: 42.43 dB, SSIM: 0.9861
#
# Processing 'img813.png'
# PSNR: 47.27 dB, SSIM: 0.9939
#
# Processing 'img814.png'
# PSNR: 46.41 dB, SSIM: 0.9925
#
# Processing 'img815.png'
# PSNR: 44.20 dB, SSIM: 0.9875
#
# Processing 'img816.png'
# PSNR: 41.91 dB, SSIM: 0.9795
#
# Processing 'img817.png'
# PSNR: 42.37 dB, SSIM: 0.9839
#
# Processing 'img818.png'
# PSNR: 40.59 dB, SSIM: 0.9784
#
# Processing 'img819.png'
# PSNR: 39.06 dB, SSIM: 0.9739
#
# Processing 'img820.png'
# PSNR: 37.71 dB, SSIM: 0.9680
#
# Processing 'img821.png'
# PSNR: 37.43 dB, SSIM: 0.9692
#
# Processing 'img822.png'
# PSNR: 36.34 dB, SSIM: 0.9626
#
# Processing 'img823.png'
# PSNR: 46.00 dB, SSIM: 0.9914
#
# Processing 'img824.png'
# PSNR: 44.13 dB, SSIM: 0.9899
#
# Processing 'img825.png'
# PSNR: 40.74 dB, SSIM: 0.9830
#
# Processing 'img826.png'
# PSNR: 38.04 dB, SSIM: 0.9785
#
# Processing 'img827.png'
# PSNR: 36.90 dB, SSIM: 0.9732
#
# Processing 'img828.png'
# PSNR: 46.63 dB, SSIM: 0.9939
#
# Processing 'img829.png'
# PSNR: 44.51 dB, SSIM: 0.9906
#
# Processing 'img830.png'
# PSNR: 41.44 dB, SSIM: 0.9764
#
# Processing 'img831.png'
# PSNR: 46.32 dB, SSIM: 0.9926
#
# Processing 'img832.png'
# PSNR: 44.23 dB, SSIM: 0.9874
#
# Processing 'img833.png'
# PSNR: 42.07 dB, SSIM: 0.9795
#
# Processing 'img834.png'
# PSNR: 43.61 dB, SSIM: 0.9873
#
# Processing 'img835.png'
# PSNR: 41.73 dB, SSIM: 0.9780
#
# Processing 'img836.png'
# PSNR: 39.59 dB, SSIM: 0.9811
#
# Processing 'img837.png'
# PSNR: 44.33 dB, SSIM: 0.9892
#
# Processing 'img838.png'
# PSNR: 42.54 dB, SSIM: 0.9845
#
# Processing 'img839.png'
# PSNR: 40.65 dB, SSIM: 0.9782
#
# Processing 'img840.png'
# PSNR: 39.03 dB, SSIM: 0.9735
#
# Processing 'img841.png'
# PSNR: 36.44 dB, SSIM: 0.9641
#
# Processing 'img842.png'
# PSNR: 46.40 dB, SSIM: 0.9926
#
# Processing 'img843.png'
# PSNR: 41.59 dB, SSIM: 0.9770
#
# Processing 'img844.png'
# PSNR: 41.27 dB, SSIM: 0.9742
#
# Processing 'img845.png'
# PSNR: 39.29 dB, SSIM: 0.9797
#
# Processing 'img846.png'
# PSNR: 42.63 dB, SSIM: 0.9878
#
# Processing 'img847.png'
# PSNR: 40.47 dB, SSIM: 0.9795
#
# Processing 'img848.png'
# PSNR: 38.99 dB, SSIM: 0.9760
#
# Processing 'img849.png'
# PSNR: 36.72 dB, SSIM: 0.9662
#
# Processing 'img850.png'
# PSNR: 46.54 dB, SSIM: 0.9931
#
# Processing 'img851.png'
# PSNR: 44.43 dB, SSIM: 0.9881
#
# Processing 'img852.png'
# PSNR: 43.76 dB, SSIM: 0.9862
#
# Processing 'img853.png'
# PSNR: 41.81 dB, SSIM: 0.9786
#
# Processing 'img854.png'
# PSNR: 41.63 dB, SSIM: 0.9759
#
# Processing 'img855.png'
# PSNR: 41.53 dB, SSIM: 0.9737
#
# Processing 'img856.png'
# PSNR: 36.19 dB, SSIM: 0.9613
#
# Processing 'img857.png'
# PSNR: 44.42 dB, SSIM: 0.9894
#
# Processing 'img858.png'
# PSNR: 43.91 dB, SSIM: 0.9888
#
# Processing 'img859.png'
# PSNR: 42.02 dB, SSIM: 0.9848
#
# Processing 'img860.png'
# PSNR: 40.28 dB, SSIM: 0.9807
#
# Processing 'img861.png'
# PSNR: 38.82 dB, SSIM: 0.9771
#
# Processing 'img862.png'
# PSNR: 43.67 dB, SSIM: 0.9861
#
# Processing 'img863.png'
# PSNR: 41.77 dB, SSIM: 0.9776
#
# Processing 'img864.png'
# PSNR: 42.10 dB, SSIM: 0.9840
#
# Processing 'img865.png'
# PSNR: 40.47 dB, SSIM: 0.9791
#
# Processing 'img866.png'
# PSNR: 38.94 dB, SSIM: 0.9746
#
# Processing 'img867.png'
# PSNR: 35.23 dB, SSIM: 0.9552
#
# Processing 'img868.png'
# PSNR: 36.57 dB, SSIM: 0.9636
#
# Processing 'img869.png'
# PSNR: 44.61 dB, SSIM: 0.9883
#
# Processing 'img870.png'
# PSNR: 43.93 dB, SSIM: 0.9865
#
# Processing 'img871.png'
# PSNR: 38.52 dB, SSIM: 0.9761
#
# Processing 'img872.png'
# PSNR: 41.95 dB, SSIM: 0.9796
#
# Processing 'img873.png'
# PSNR: 41.51 dB, SSIM: 0.9771
#
# Processing 'img874.png'
# PSNR: 36.89 dB, SSIM: 0.9726
#
# Processing 'img875.png'
# PSNR: 42.51 dB, SSIM: 0.9869
#
# Processing 'img876.png'
# PSNR: 42.35 dB, SSIM: 0.9835
#
# Processing 'img877.png'
# PSNR: 42.05 dB, SSIM: 0.9830
#
# Processing 'img878.png'
# PSNR: 39.96 dB, SSIM: 0.9675
#
# Processing 'img879.png'
# PSNR: 40.34 dB, SSIM: 0.9769
#
# Processing 'img880.png'
# PSNR: 38.75 dB, SSIM: 0.9712
#
# Processing 'img881.png'
# PSNR: 37.35 dB, SSIM: 0.9662
#
# Processing 'img882.png'
# PSNR: 43.91 dB, SSIM: 0.9865
#
# Processing 'img883.png'
# PSNR: 41.95 dB, SSIM: 0.9780
#
# Processing 'img884.png'
# PSNR: 37.80 dB, SSIM: 0.9719
#
# Processing 'img885.png'
# PSNR: 35.62 dB, SSIM: 0.9609
#
# Processing 'img886.png'
# PSNR: 37.97 dB, SSIM: 0.9798
#
# Processing 'img887.png'
# PSNR: 40.59 dB, SSIM: 0.9783
#
# Processing 'img888.png'
# PSNR: 36.53 dB, SSIM: 0.9722
#
# Processing 'img889.png'
# PSNR: 36.03 dB, SSIM: 0.9592
#
# Processing 'img890.png'
# PSNR: 39.63 dB, SSIM: 0.9671
#
# Processing 'img891.png'
# PSNR: 44.41 dB, SSIM: 0.9880
#
# Processing 'img892.png'
# PSNR: 43.66 dB, SSIM: 0.9856
#
# Processing 'img893.png'
# PSNR: 41.44 dB, SSIM: 0.9753
#
# Processing 'img894.png'
# PSNR: 41.23 dB, SSIM: 0.9730
#
# Processing 'img895.png'
# PSNR: 44.54 dB, SSIM: 0.9885
#
# Processing 'img896.png'
# PSNR: 43.93 dB, SSIM: 0.9863
#
# Processing 'img897.png'
# PSNR: 41.32 dB, SSIM: 0.9741
#
# Processing 'img898.png'
# PSNR: 41.31 dB, SSIM: 0.9708
#
# Processing 'img899.png'
# PSNR: 35.32 dB, SSIM: 0.9585
#
# Processing 'img9.png'
# PSNR: 33.39 dB, SSIM: 0.9442
#
# Processing 'img900.png'
# PSNR: 41.36 dB, SSIM: 0.9750
#
# Processing 'img901.png'
# PSNR: 39.43 dB, SSIM: 0.9658
#
# Processing 'img902.png'
# PSNR: 41.08 dB, SSIM: 0.9724
#
# Processing 'img903.png'
# PSNR: 41.07 dB, SSIM: 0.9707
#
# Processing 'img904.png'
# PSNR: 35.38 dB, SSIM: 0.9573
#
# Processing 'img905.png'
# PSNR: 35.42 dB, SSIM: 0.9583
#
# Processing 'img906.png'
# PSNR: 36.93 dB, SSIM: 0.9744
#
# Processing 'img907.png'
# PSNR: 34.97 dB, SSIM: 0.9519
#
# Processing 'img908.png'
# PSNR: 43.71 dB, SSIM: 0.9860
#
# Processing 'img909.png'
# PSNR: 41.43 dB, SSIM: 0.9756
#
# Processing 'img910.png'
# PSNR: 41.24 dB, SSIM: 0.9731
#
# Processing 'img911.png'
# PSNR: 41.11 dB, SSIM: 0.9735
#
# Processing 'img912.png'
# PSNR: 42.19 dB, SSIM: 0.9826
#
# Processing 'img913.png'
# PSNR: 36.26 dB, SSIM: 0.9629
#
# Processing 'img914.png'
# PSNR: 36.38 dB, SSIM: 0.9656
#
# Processing 'img915.png'
# PSNR: 42.00 dB, SSIM: 0.9786
#
# Processing 'img916.png'
# PSNR: 35.86 dB, SSIM: 0.9582
#
# Processing 'img917.png'
# PSNR: 34.99 dB, SSIM: 0.9507
#
# Processing 'img918.png'
# PSNR: 35.95 dB, SSIM: 0.9559
#
# Processing 'img919.png'
# PSNR: 36.06 dB, SSIM: 0.9606
#
# Processing 'img920.png'
# PSNR: 44.15 dB, SSIM: 0.9879
#
# Processing 'img921.png'
# PSNR: 36.95 dB, SSIM: 0.9733
#
# Processing 'img922.png'
# PSNR: 41.38 dB, SSIM: 0.9765
#
# Processing 'img923.png'
# PSNR: 40.45 dB, SSIM: 0.9776
#
# Processing 'img924.png'
# PSNR: 34.99 dB, SSIM: 0.9487
#
# Processing 'img925.png'
# PSNR: 43.86 dB, SSIM: 0.9881
#
# Processing 'img926.png'
# PSNR: 42.09 dB, SSIM: 0.9807
#
# Processing 'img927.png'
# PSNR: 41.72 dB, SSIM: 0.9786
#
# Processing 'img928.png'
# PSNR: 41.01 dB, SSIM: 0.9747
#
# Processing 'img929.png'
# PSNR: 36.25 dB, SSIM: 0.9587
#
# Processing 'img930.png'
# PSNR: 37.24 dB, SSIM: 0.9676
#
# Processing 'img931.png'
# PSNR: 36.29 dB, SSIM: 0.9630
#
# Processing 'img932.png'
# PSNR: 43.70 dB, SSIM: 0.9876
#
# Processing 'img933.png'
# PSNR: 35.50 dB, SSIM: 0.9438
#
# Processing 'img934.png'
# PSNR: 38.90 dB, SSIM: 0.9734
#
# Processing 'img935.png'
# PSNR: 34.59 dB, SSIM: 0.9416
#
# Processing 'img936.png'
# PSNR: 44.63 dB, SSIM: 0.9896
#
# Processing 'img937.png'
# PSNR: 33.71 dB, SSIM: 0.9556
#
# Processing 'img938.png'
# PSNR: 33.03 dB, SSIM: 0.9520
#
# Processing 'img939.png'
# PSNR: 36.84 dB, SSIM: 0.9734
#
# Processing 'img940.png'
# PSNR: 33.78 dB, SSIM: 0.9562
#
# Processing 'img941.png'
# PSNR: 33.88 dB, SSIM: 0.9612
#
# Processing 'img942.png'
# PSNR: 38.11 dB, SSIM: 0.9743
#
# Processing 'img943.png'
# PSNR: 36.91 dB, SSIM: 0.9715
#
# Processing 'img944.png'
# PSNR: 33.01 dB, SSIM: 0.9511
#
# Processing 'img945.png'
# PSNR: 37.62 dB, SSIM: 0.9682
#
# Processing 'img946.png'
# PSNR: 36.38 dB, SSIM: 0.9627
#
# Processing 'img947.png'
# PSNR: 35.04 dB, SSIM: 0.9488
#
# Processing 'img948.png'
# PSNR: 35.11 dB, SSIM: 0.9555
#
# Processing 'img949.png'
# PSNR: 39.10 dB, SSIM: 0.9784
#
# Processing 'img96.png'
# PSNR: 37.94 dB, SSIM: 0.9758
#
# Processing 'img97.png'
# PSNR: 34.63 dB, SSIM: 0.9598
#
# Processing 'img98.png'
# PSNR: 34.50 dB, SSIM: 0.9601
#
# Processing 'img99.png'
# PSNR: 35.81 dB, SSIM: 0.9709
#
#
# === Processing Defect Folder ===
# Processing '001.png'
# PSNR: 32.49 dB, SSIM: 0.9387
#
# Processing '002.png'
# PSNR: 41.60 dB, SSIM: 0.9804
#
# Processing '003.png'
# PSNR: 41.66 dB, SSIM: 0.9804
#
# Processing '004.png'
# PSNR: 47.44 dB, SSIM: 0.9942
#
# Processing '005.png'
# PSNR: 41.70 dB, SSIM: 0.9803
#
# Processing '006.png'
# PSNR: 41.35 dB, SSIM: 0.9792
#
# Processing '007.png'
# PSNR: 41.42 dB, SSIM: 0.9797
#
# Processing '008.png'
# PSNR: 41.44 dB, SSIM: 0.9801
#
# Processing '009.png'
# PSNR: 41.78 dB, SSIM: 0.9808
#
# Processing '010.png'
# PSNR: 41.81 dB, SSIM: 0.9820
#
# Processing '011.png'
# PSNR: 41.63 dB, SSIM: 0.9807
#
# Processing '012.png'
# PSNR: 41.47 dB, SSIM: 0.9808
#
# Processing '013.png'
# PSNR: 41.59 dB, SSIM: 0.9804
#
# Processing '014.png'
# PSNR: 41.24 dB, SSIM: 0.9789
#
# Processing '015.png'
# PSNR: 41.40 dB, SSIM: 0.9796
#
# Processing '016.png'
# PSNR: 41.19 dB, SSIM: 0.9788
#
# Processing '017.png'
# PSNR: 41.57 dB, SSIM: 0.9809
#
# Processing '018.png'
# PSNR: 43.95 dB, SSIM: 0.9880
#
# Processing '019.png'
# PSNR: 41.55 dB, SSIM: 0.9805
#
# Processing '020.png'
# PSNR: 41.54 dB, SSIM: 0.9805
#
# Processing '021.png'
# PSNR: 40.51 dB, SSIM: 0.9783
#
# Processing '022.png'
# PSNR: 35.32 dB, SSIM: 0.9652
#
# Processing '023.png'
# PSNR: 35.53 dB, SSIM: 0.9591
#
# Processing '024.png'
# PSNR: 35.30 dB, SSIM: 0.9559
#
# Processing '025.png'
# PSNR: 38.14 dB, SSIM: 0.9780
#
# Processing '026.png'
# PSNR: 43.74 dB, SSIM: 0.9831
#
# Processing '027.png'
# PSNR: 33.77 dB, SSIM: 0.9339
#
# Processing '028.png'
# PSNR: 37.17 dB, SSIM: 0.9764
#
# Processing '029.png'
# PSNR: 43.99 dB, SSIM: 0.9867
#
# Processing '030.png'
# PSNR: 44.33 dB, SSIM: 0.9906
#
# Processing '031.png'
# PSNR: 41.74 dB, SSIM: 0.9783
#
# Processing '032.png'
# PSNR: 41.83 dB, SSIM: 0.9787
#
# Processing '033.png'
# PSNR: 36.98 dB, SSIM: 0.9694
#
# Processing '034.png'
# PSNR: 38.82 dB, SSIM: 0.9753
#
# Processing '035.png'
# PSNR: 40.65 dB, SSIM: 0.9798
#
# Processing '036.png'
# PSNR: 44.26 dB, SSIM: 0.9889
#
# Processing '037.png'
# PSNR: 47.11 dB, SSIM: 0.9940
#
# Processing '038.png'
# PSNR: 44.53 dB, SSIM: 0.9893
#
# Processing '039.png'
# PSNR: 39.10 dB, SSIM: 0.9844
#
# Processing '040.png'
# PSNR: 40.28 dB, SSIM: 0.9823
#
# Processing '041.png'
# PSNR: 37.99 dB, SSIM: 0.9744
#
# Processing '042.png'
# PSNR: 36.83 dB, SSIM: 0.9708
#
# Processing '043.png'
# PSNR: 35.66 dB, SSIM: 0.9653
#
# Processing '044.png'
# PSNR: 35.58 dB, SSIM: 0.9649
#
# Processing '045.png'
# PSNR: 34.56 dB, SSIM: 0.9523
#
# Processing '046.png'
# PSNR: 32.50 dB, SSIM: 0.9330
#
# Processing '047.png'
# PSNR: 39.40 dB, SSIM: 0.9775
#
# Processing '048.png'
# PSNR: 37.12 dB, SSIM: 0.9722
#
# Processing '049.png'
# PSNR: 35.66 dB, SSIM: 0.9652
#
# Processing '050.png'
# PSNR: 39.15 dB, SSIM: 0.9735
#
# Processing '051.png'
# PSNR: 33.44 dB, SSIM: 0.9434
#
# Processing '052.png'
# PSNR: 38.11 dB, SSIM: 0.9758
#
# Processing '053.png'
# PSNR: 34.44 dB, SSIM: 0.9550
#
# Processing '054.png'
# PSNR: 36.04 dB, SSIM: 0.9507
#
# Processing '055.png'
# PSNR: 35.47 dB, SSIM: 0.9622
#
# Processing '056.png'
# PSNR: 39.39 dB, SSIM: 0.9775
#
# Processing '057.png'
# PSNR: 34.91 dB, SSIM: 0.9642
#
# Processing '058.png'
# PSNR: 42.08 dB, SSIM: 0.9856
#
# Processing '059.png'
# PSNR: 43.34 dB, SSIM: 0.9858
#
# Processing '060.png'
# PSNR: 43.45 dB, SSIM: 0.9863
#
# Processing '061.png'
# PSNR: 43.59 dB, SSIM: 0.9867
#
# Processing '062.png'
# PSNR: 43.41 dB, SSIM: 0.9855
#
# Processing '063.png'
# PSNR: 38.07 dB, SSIM: 0.9560
#
# Processing '064.png'
# PSNR: 41.83 dB, SSIM: 0.9789
#
# Processing '065.png'
# PSNR: 39.17 dB, SSIM: 0.9646
#
# Processing '066.png'
# PSNR: 36.35 dB, SSIM: 0.9715
#
# Processing '067.png'
# PSNR: 37.99 dB, SSIM: 0.9758
#
# Processing '068.png'
# PSNR: 40.28 dB, SSIM: 0.9832
#
# Processing '069.png'
# PSNR: 46.62 dB, SSIM: 0.9929
#
# Processing '070.png'
# PSNR: 46.45 dB, SSIM: 0.9927
#
# Processing '071.png'
# PSNR: 46.56 dB, SSIM: 0.9931
#
# Processing '072.png'
# PSNR: 42.27 dB, SSIM: 0.9863
#
# Processing '073.png'
# PSNR: 42.29 dB, SSIM: 0.9864
#
# Processing '074.png'
# PSNR: 38.66 dB, SSIM: 0.9776
#
# Processing '075.png'
# PSNR: 35.43 dB, SSIM: 0.9634
#
# Processing '076.png'
# PSNR: 34.42 dB, SSIM: 0.9570
#
# Processing '077.png'
# PSNR: 39.38 dB, SSIM: 0.9801
#
# Processing '078.png'
# PSNR: 37.60 dB, SSIM: 0.9735
#
# Processing '079.png'
# PSNR: 38.16 dB, SSIM: 0.9757
#
# Processing '080.png'
# PSNR: 37.85 dB, SSIM: 0.9694
#
# Processing '081.png'
# PSNR: 42.28 dB, SSIM: 0.9876
#
# Processing '082.png'
# PSNR: 42.32 dB, SSIM: 0.9873
#
# Processing '083.png'
# PSNR: 42.02 dB, SSIM: 0.9863
#
# Processing '084.png'
# PSNR: 39.31 dB, SSIM: 0.9787
#
# Processing '085.png'
# PSNR: 36.99 dB, SSIM: 0.9536
#
# Processing '086.png'
# PSNR: 37.90 dB, SSIM: 0.9759
#
# Processing '087.png'
# PSNR: 41.96 dB, SSIM: 0.9813
#
# Processing '088.png'
# PSNR: 41.74 dB, SSIM: 0.9835
#
# Processing '089.png'
# PSNR: 41.67 dB, SSIM: 0.9820
#
# Processing '090.png'
# PSNR: 38.98 dB, SSIM: 0.9734
#
# Processing '091.png'
# PSNR: 36.73 dB, SSIM: 0.9705
#
# Processing '092.png'
# PSNR: 35.72 dB, SSIM: 0.9657
#
# Processing '093.png'
# PSNR: 43.58 dB, SSIM: 0.9851
#
# Processing '094.png'
# PSNR: 38.16 dB, SSIM: 0.9685
#
# Processing '095.png'
# PSNR: 36.31 dB, SSIM: 0.9655
#
#
# ===== Summary =====
# Normal Folder - Avg PSNR: 39.75 dB, Avg SSIM: 0.9741
# Defect Folder - Avg PSNR: 39.79 dB, Avg SSIM: 0.9752

# %%
import os
import cv2
import numpy as np

# Folder paths
input_folder =  r'C:\Users\Global\Fabric project\WFDD\Yellow cloth\final_normal'  # Replace with your input folder path
output_folder =  r'C:\Users\Global\Fabric project\WFDD\Yellow cloth\final_normal_3'    # Replace with your output folder path

# Create output folder if it doesn't exist
os.makedirs(output_folder, exist_ok=True)

def grayscale_to_color_normalized(image):
    # Normalize if not already in [0, 1]
    if image.max() > 1.0:
        image = image / 255.0

    # Convert grayscale image to 3-channel normalized image
    color_image = np.stack([image, image, image], axis=-1)
    return color_image

# Process all image files in the folder
for filename in os.listdir(input_folder):
    if filename.lower().endswith(('.png', '.jpg', '.jpeg', '.bmp', '.tif', '.tiff')):
        # Read image in grayscale
        gray_path = os.path.join(input_folder, filename)
        gray_image = cv2.imread(gray_path, cv2.IMREAD_GRAYSCALE)

        if gray_image is None:
            print(f"Could not read image: {filename}")
            continue

        # Convert to normalized color image
        color_image_normalized = grayscale_to_color_normalized(gray_image)

        # Optional: Save the normalized image as a visual reference (rescaled for saving)
        color_image_to_save = (color_image_normalized * 255).astype(np.uint8)
        save_path = os.path.join(output_folder, filename)
        cv2.imwrite(save_path, color_image_to_save)

        print(f"Processed and saved: {filename}")

print("All images converted successfully.")
# Out:
# Processed and saved: img1.png
# Processed and saved: img10.png
# Processed and saved: img100.png
# Processed and saved: img1000.png
# Processed and saved: img1008.png
# Processed and saved: img1009.png
# Processed and saved: img101.png
# Processed and saved: img1010.png
# Processed and saved: img1013.png
# Processed and saved: img1017.png
# Processed and saved: img102.png
# Processed and saved: img1020.png
# Processed and saved: img1026.png
# Processed and saved: img103.png
# Processed and saved: img1033.png
# Processed and saved: img1034.png
# Processed and saved: img1036.png
# Processed and saved: img1037.png
# Processed and saved: img1038.png
# Processed and saved: img104.png
# Processed and saved: img1040.png
# Processed and saved: img1044.png
# Processed and saved: img105.png
# Processed and saved: img106.png
# Processed and saved: img107.png
# Processed and saved: img109.png
# Processed and saved: img11.png
# Processed and saved: img110.png
# Processed and saved: img111.png
# Processed and saved: img114.png
# Processed and saved: img116.png
# Processed and saved: img117.png
# Processed and saved: img118.png
# Processed and saved: img119.png
# Processed and saved: img12.png
# Processed and saved: img120.png
# Processed and saved: img121.png
# Processed and saved: img122.png
# Processed and saved: img123.png
# Processed and saved: img124.png
# Processed and saved: img125.png
# Processed and saved: img126.png
# Processed and saved: img127.png
# Processed and saved: img13.png
# Processed and saved: img131.png
# Processed and saved: img132.png
# Processed and saved: img133.png
# Processed and saved: img134.png
# Processed and saved: img135.png
# Processed and saved: img137.png
# Processed and saved: img14.png
# Processed and saved: img140.png
# Processed and saved: img141.png
# Processed and saved: img142.png
# Processed and saved: img143.png
# Processed and saved: img144.png
# Processed and saved: img145.png
# Processed and saved: img146.png
# Processed and saved: img147.png
# Processed and saved: img148.png
# Processed and saved: img149.png
# Processed and saved: img150.png
# Processed and saved: img152.png
# Processed and saved: img153.png
# Processed and saved: img155.png
# Processed and saved: img156.png
# Processed and saved: img159.png
# Processed and saved: img16.png
# Processed and saved: img162.png
# Processed and saved: img163.png
# Processed and saved: img165.png
# Processed and saved: img166.png
# Processed and saved: img167.png
# Processed and saved: img169.png
# Processed and saved: img17.png
# Processed and saved: img170.png
# Processed and saved: img171.png
# Processed and saved: img172.png
# Processed and saved: img174.png
# Processed and saved: img175.png
# Processed and saved: img176.png
# Processed and saved: img18.png
# Processed and saved: img181.png
# Processed and saved: img182.png
# Processed and saved: img183.png
# Processed and saved: img184.png
# Processed and saved: img185.png
# Processed and saved: img186.png
# Processed and saved: img187.png
# Processed and saved: img188.png
# Processed and saved: img189.png
# Processed and saved: img191.png
# Processed and saved: img192.png
# Processed and saved: img193.png
# Processed and saved: img197.png
# Processed and saved: img198.png
# Processed and saved: img2.png
# Processed and saved: img200.png
# Processed and saved: img201.png
# Processed and saved: img202.png
# Processed and saved: img203.png
# Processed and saved: img207.png
# Processed and saved: img208.png
# Processed and saved: img209.png
# Processed and saved: img21.png
# Processed and saved: img212.png
# Processed and saved: img215.png
# Processed and saved: img216.png
# Processed and saved: img217.png
# Processed and saved: img218.png
# Processed and saved: img22.png
# Processed and saved: img225.png
# Processed and saved: img226.png
# Processed and saved: img227.png
# Processed and saved: img229.png
# Processed and saved: img23.png
# Processed and saved: img231.png
# Processed and saved: img232.png
# Processed and saved: img233.png
# Processed and saved: img234.png
# Processed and saved: img236.png
# Processed and saved: img239.png
# Processed and saved: img240.png
# Processed and saved: img243.png
# Processed and saved: img244.png
# Processed and saved: img245.png
# Processed and saved: img247.png
# Processed and saved: img248.png
# Processed and saved: img249.png
# Processed and saved: img250.png
# Processed and saved: img251.png
# Processed and saved: img252.png
# Processed and saved: img253.png
# Processed and saved: img254.png
# Processed and saved: img255.png
# Processed and saved: img256.png
# Processed and saved: img257.png
# Processed and saved: img258.png
# Processed and saved: img259.png
# Processed and saved: img260.png
# Processed and saved: img261.png
# Processed and saved: img262.png
# Processed and saved: img263.png
# Processed and saved: img264.png
# Processed and saved: img265.png
# Processed and saved: img266.png
# Processed and saved: img267.png
# Processed and saved: img269.png
# Processed and saved: img27.png
# Processed and saved: img270.png
# Processed and saved: img271.png
# Processed and saved: img272.png
# Processed and saved: img273.png
# Processed and saved: img275.png
# Processed and saved: img276.png
# Processed and saved: img278.png
# Processed and saved: img279.png
# Processed and saved: img280.png
# Processed and saved: img283.png
# Processed and saved: img284.png
# Processed and saved: img285.png
# Processed and saved: img286.png
# Processed and saved: img290.png
# Processed and saved: img292.png
# Processed and saved: img293.png
# Processed and saved: img294.png
# Processed and saved: img295.png
# Processed and saved: img296.png
# Processed and saved: img297.png
# Processed and saved: img298.png
# Processed and saved: img300.png
# Processed and saved: img304.png
# Processed and saved: img305.png
# Processed and saved: img306.png
# Processed and saved: img307.png
# Processed and saved: img311.png
# Processed and saved: img313.png
# Processed and saved: img314.png
# Processed and saved: img315.png
# Processed and saved: img318.png
# Processed and saved: img32.png
# Processed and saved: img320.png
# Processed and saved: img321.png
# Processed and saved: img322.png
# Processed and saved: img324.png
# Processed and saved: img325.png
# Processed and saved: img33.png
# Processed and saved: img330.png
# Processed and saved: img332.png
# Processed and saved: img333.png
# Processed and saved: img334.png
# Processed and saved: img336.png
# Processed and saved: img337.png
# Processed and saved: img339.png
# Processed and saved: img34.png
# Processed and saved: img342.png
# Processed and saved: img343.png
# Processed and saved: img344.png
# Processed and saved: img345.png
# Processed and saved: img346.png
# Processed and saved: img347.png
# Processed and saved: img349.png
# Processed and saved: img355.png
# Processed and saved: img36.png
# Processed and saved: img361.png
# Processed and saved: img362.png
# Processed and saved: img363.png
# Processed and saved: img366.png
# Processed and saved: img367.png
# Processed and saved: img371.png
# Processed and saved: img372.png
# Processed and saved: img376.png
# Processed and saved: img377.png
# Processed and saved: img382.png
# Processed and saved: img383.png
# Processed and saved: img384.png
# Processed and saved: img388.png
# Processed and saved: img389.png
# Processed and saved: img390.png
# Processed and saved: img394.png
# Processed and saved: img395.png
# Processed and saved: img396.png
# Processed and saved: img397.png
# Processed and saved: img398.png
# Processed and saved: img399.png
# Processed and saved: img403.png
# Processed and saved: img409.png
# Processed and saved: img410.png
# Processed and saved: img411.png
# Processed and saved: img412.png
# Processed and saved: img413.png
# Processed and saved: img415.png
# Processed and saved: img416.png
# Processed and saved: img417.png
# Processed and saved: img426.png
# Processed and saved: img427.png
# Processed and saved: img428.png
# Processed and saved: img431.png
# Processed and saved: img432.png
# Processed and saved: img433.png
# Processed and saved: img438.png
# Processed and saved: img439.png
# Processed and saved: img440.png
# Processed and saved: img441.png
# Processed and saved: img442.png
# Processed and saved: img443.png
# Processed and saved: img444.png
# Processed and saved: img446.png
# Processed and saved: img448.png
# Processed and saved: img449.png
# Processed and saved: img450.png
# Processed and saved: img451.png
# Processed and saved: img453.png
# Processed and saved: img454.png
# Processed and saved: img455.png
# Processed and saved: img456.png
# Processed and saved: img457.png
# Processed and saved: img458.png
# Processed and saved: img459.png
# Processed and saved: img46.png
# Processed and saved: img460.png
# Processed and saved: img461.png
# Processed and saved: img462.png
# Processed and saved: img464.png
# Processed and saved: img465.png
# Processed and saved: img466.png
# Processed and saved: img468.png
# Processed and saved: img469.png
# Processed and saved: img470.png
# Processed and saved: img471.png
# Processed and saved: img472.png
# Processed and saved: img474.png
# Processed and saved: img476.png
# Processed and saved: img477.png
# Processed and saved: img478.png
# Processed and saved: img482.png
# Processed and saved: img483.png
# Processed and saved: img484.png
# Processed and saved: img485.png
# Processed and saved: img489.png
# Processed and saved: img491.png
# Processed and saved: img493.png
# Processed and saved: img494.png
# Processed and saved: img495.png
# Processed and saved: img496.png
# Processed and saved: img497.png
# Processed and saved: img498.png
# Processed and saved: img499.png
# Processed and saved: img50.png
# Processed and saved: img501.png
# Processed and saved: img504.png
# Processed and saved: img506.png
# Processed and saved: img509.png
# Processed and saved: img512.png
# Processed and saved: img514.png
# Processed and saved: img515.png
# Processed and saved: img519.png
# Processed and saved: img522.png
# Processed and saved: img524.png
# Processed and saved: img525.png
# Processed and saved: img526.png
# Processed and saved: img527.png
# Processed and saved: img528.png
# Processed and saved: img532.png
# Processed and saved: img533.png
# Processed and saved: img535.png
# Processed and saved: img536.png
# Processed and saved: img537.png
# Processed and saved: img539.png
# Processed and saved: img540.png
# Processed and saved: img541.png
# Processed and saved: img542.png
# Processed and saved: img544.png
# Processed and saved: img547.png
# Processed and saved: img548.png
# Processed and saved: img549.png
# Processed and saved: img550.png
# Processed and saved: img551.png
# Processed and saved: img554.png
# Processed and saved: img558.png
# Processed and saved: img559.png
# Processed and saved: img560.png
# Processed and saved: img563.png
# Processed and saved: img564.png
# Processed and saved: img565.png
# Processed and saved: img567.png
# Processed and saved: img569.png
# Processed and saved: img570.png
# Processed and saved: img571.png
# Processed and saved: img576.png
# Processed and saved: img577.png
# Processed and saved: img578.png
# Processed and saved: img579.png
# Processed and saved: img580.png
# Processed and saved: img581.png
# Processed and saved: img585.png
# Processed and saved: img588.png
# Processed and saved: img590.png
# Processed and saved: img594.png
# Processed and saved: img595.png
# Processed and saved: img596.png
# Processed and saved: img597.png
# Processed and saved: img598.png
# Processed and saved: img6.png
# Processed and saved: img600.png
# Processed and saved: img604.png
# Processed and saved: img605.png
# Processed and saved: img606.png
# Processed and saved: img607.png
# Processed and saved: img608.png
# Processed and saved: img610.png
# Processed and saved: img621.png
# Processed and saved: img622.png
# Processed and saved: img624.png
# Processed and saved: img625.png
# Processed and saved: img626.png
# Processed and saved: img627.png
# Processed and saved: img629.png
# Processed and saved: img631.png
# Processed and saved: img632.png
# Processed and saved: img633.png
# Processed and saved: img634.png
# Processed and saved: img635.png
# Processed and saved: img637.png
# Processed and saved: img639.png
# Processed and saved: img640.png
# Processed and saved: img641.png
# Processed and saved: img649.png
# Processed and saved: img650.png
# Processed and saved: img651.png
# Processed and saved: img652.png
# Processed and saved: img657.png
# Processed and saved: img662.png
# Processed and saved: img665.png
# Processed and saved: img666.png
# Processed and saved: img669.png
# Processed and saved: img670.png
# Processed and saved: img673.png
# Processed and saved: img675.png
# Processed and saved: img676.png
# Processed and saved: img677.png
# Processed and saved: img680.png
# Processed and saved: img682.png
# Processed and saved: img683.png
# Processed and saved: img690.png
# Processed and saved: img694.png
# Processed and saved: img695.png
# Processed and saved: img697.png
# Processed and saved: img698.png
# Processed and saved: img701.png
# Processed and saved: img706.png
# Processed and saved: img708.png
# Processed and saved: img710.png
# Processed and saved: img711.png
# Processed and saved: img720.png
# Processed and saved: img721.png
# Processed and saved: img722.png
# Processed and saved: img723.png
# Processed and saved: img726.png
# Processed and saved: img731.png
# Processed and saved: img732.png
# Processed and saved: img734.png
# Processed and saved: img736.png
# Processed and saved: img741.png
# Processed and saved: img745.png
# Processed and saved: img748.png
# Processed and saved: img751.png
# Processed and saved: img756.png
# Processed and saved: img758.png
# Processed and saved: img762.png
# Processed and saved: img767.png
# Processed and saved: img768.png
# Processed and saved: img771.png
# Processed and saved: img772.png
# Processed and saved: img774.png
# Processed and saved: img776.png
# Processed and saved: img783.png
# Processed and saved: img785.png
# Processed and saved: img786.png
# Processed and saved: img788.png
# Processed and saved: img790.png
# Processed and saved: img798.png
# Processed and saved: img8.png
# Processed and saved: img800.png
# Processed and saved: img801.png
# Processed and saved: img802.png
# Processed and saved: img803.png
# Processed and saved: img809.png
# Processed and saved: img810.png
# Processed and saved: img811.png
# Processed and saved: img813.png
# Processed and saved: img814.png
# Processed and saved: img818.png
# Processed and saved: img819.png
# Processed and saved: img820.png
# Processed and saved: img821.png
# Processed and saved: img824.png
# Processed and saved: img825.png
# Processed and saved: img826.png
# Processed and saved: img827.png
# Processed and saved: img834.png
# Processed and saved: img836.png
# Processed and saved: img841.png
# Processed and saved: img842.png
# Processed and saved: img845.png
# Processed and saved: img846.png
# Processed and saved: img847.png
# Processed and saved: img848.png
# Processed and saved: img849.png
# Processed and saved: img852.png
# Processed and saved: img855.png
# Processed and saved: img860.png
# Processed and saved: img861.png
# Processed and saved: img866.png
# Processed and saved: img867.png
# Processed and saved: img869.png
# Processed and saved: img874.png
# Processed and saved: img875.png
# Processed and saved: img882.png
# Processed and saved: img884.png
# Processed and saved: img885.png
# Processed and saved: img886.png
# Processed and saved: img888.png
# Processed and saved: img895.png
# Processed and saved: img899.png
# Processed and saved: img9.png
# Processed and saved: img904.png
# Processed and saved: img905.png
# Processed and saved: img906.png
# Processed and saved: img907.png
# Processed and saved: img913.png
# Processed and saved: img914.png
# Processed and saved: img916.png
# Processed and saved: img917.png
# Processed and saved: img918.png
# Processed and saved: img919.png
# Processed and saved: img921.png
# Processed and saved: img923.png
# Processed and saved: img924.png
# Processed and saved: img929.png
# Processed and saved: img930.png
# Processed and saved: img931.png
# Processed and saved: img932.png
# Processed and saved: img933.png
# Processed and saved: img934.png
# Processed and saved: img935.png
# Processed and saved: img936.png
# Processed and saved: img937.png
# Processed and saved: img938.png
# Processed and saved: img939.png
# Processed and saved: img940.png
# Processed and saved: img941.png
# Processed and saved: img942.png
# Processed and saved: img943.png
# Processed and saved: img944.png
# Processed and saved: img947.png
# Processed and saved: img96.png
# Processed and saved: img97.png
# Processed and saved: img98.png
# Processed and saved: img99.png
# All images converted successfully.

# %%
import os
import cv2
import numpy as np

# Folder paths
input_folder =  r'C:\Users\Global\Fabric project\WFDD\Yellow cloth\final_defect'  # Replace with your input folder path
output_folder =  r'C:\Users\Global\Fabric project\WFDD\Yellow cloth\final_defect_3'    # Replace with your output folder path

# Create output folder if it doesn't exist
os.makedirs(output_folder, exist_ok=True)

def grayscale_to_color_normalized(image):
    # Normalize if not already in [0, 1]
    if image.max() > 1.0:
        image = image / 255.0

    # Convert grayscale image to 3-channel normalized image
    color_image = np.stack([image, image, image], axis=-1)
    return color_image

# Process all image files in the folder
for filename in os.listdir(input_folder):
    if filename.lower().endswith(('.png', '.jpg', '.jpeg', '.bmp', '.tif', '.tiff')):
        # Read image in grayscale
        gray_path = os.path.join(input_folder, filename)
        gray_image = cv2.imread(gray_path, cv2.IMREAD_GRAYSCALE)

        if gray_image is None:
            print(f"Could not read image: {filename}")
            continue

        # Convert to normalized color image
        color_image_normalized = grayscale_to_color_normalized(gray_image)

        # Optional: Save the normalized image as a visual reference (rescaled for saving)
        color_image_to_save = (color_image_normalized * 255).astype(np.uint8)
        save_path = os.path.join(output_folder, filename)
        cv2.imwrite(save_path, color_image_to_save)

        print(f"Processed and saved: {filename}")

print("All images converted successfully.")
# Out:
# Processed and saved: 001.png
# Processed and saved: 002.png
# Processed and saved: 003.png
# Processed and saved: 004.png
# Processed and saved: 005.png
# Processed and saved: 005e8fd1fe92464f8d5320da3e6b7a40.png
# Processed and saved: 006.png
# Processed and saved: 007.png
# Processed and saved: 008.png
# Processed and saved: 009.png
# Processed and saved: 010.png
# Processed and saved: 011.png
# Processed and saved: 012.png
# Processed and saved: 0120f33d47f74449b31c572d11d90506.png
# Processed and saved: 0125acbb64ee412c8f33c841cd5a6b59.png
# Processed and saved: 013.png
# Processed and saved: 014.png
# Processed and saved: 015.png
# Processed and saved: 016.png
# Processed and saved: 017.png
# Processed and saved: 018.png
# Processed and saved: 019.png
# Processed and saved: 01c85d73cd7e4f38b2182f3e472529f0.png
# Processed and saved: 01d22fb47082426f8552bc0a1d06cf60.png
# Processed and saved: 020.png
# Processed and saved: 021.png
# Processed and saved: 022.png
# Processed and saved: 023.png
# Processed and saved: 024.png
# Processed and saved: 025.png
# Processed and saved: 026.png
# Processed and saved: 027.png
# Processed and saved: 028.png
# Processed and saved: 029.png
# Processed and saved: 02da9529a4424093b666add0ab8c0026.png
# Processed and saved: 030.png
# Processed and saved: 031.png
# Processed and saved: 031af616ed7e428aac7dc88f0a1dd79f.png
# Processed and saved: 032.png
# Processed and saved: 033.png
# Processed and saved: 034.png
# Processed and saved: 035.png
# Processed and saved: 036.png
# Processed and saved: 037.png
# Processed and saved: 038.png
# Processed and saved: 039.png
# Processed and saved: 03fc6fd5bbe94bb187d35932b73cae73.png
# Processed and saved: 040.png
# Processed and saved: 041.png
# Processed and saved: 041f4e6b6c5f432bacc47dd744665b12.png
# Processed and saved: 042.png
# Processed and saved: 043.png
# Processed and saved: 044.png
# Processed and saved: 045.png
# Processed and saved: 046.png
# Processed and saved: 047.png
# Processed and saved: 048.png
# Processed and saved: 049.png
# Processed and saved: 050.png
# Processed and saved: 051.png
# Processed and saved: 051960f2ba7347ea9e5f2f6ebc73194a.png
# Processed and saved: 052.png
# Processed and saved: 053.png
# Processed and saved: 054.png
# Processed and saved: 055.png
# Processed and saved: 055d923444d74976915fc0c0cda93a66.png
# Processed and saved: 056.png
# Processed and saved: 057.png
# Processed and saved: 058.png
# Processed and saved: 059.png
# Processed and saved: 0595f8ac44db40169d39e0c8621bf673.png
# Processed and saved: 060.png
# Processed and saved: 061.png
# Processed and saved: 062.png
# Processed and saved: 063.png
# Processed and saved: 064.png
# Processed and saved: 065.png
# Processed and saved: 066.png
# Processed and saved: 067.png
# Processed and saved: 068.png
# Processed and saved: 069.png
# Processed and saved: 070.png
# Processed and saved: 071.png
# Processed and saved: 072.png
# Processed and saved: 073.png
# Processed and saved: 074.png
# Processed and saved: 074d391c2d66436fa5719ac4e28cdffd.png
# Processed and saved: 075.png
# Processed and saved: 076.png
# Processed and saved: 077.png
# Processed and saved: 078.png
# Processed and saved: 079.png
# Processed and saved: 07cf0767893b418299ee8bc1f75c6e46.png
# Processed and saved: 07d58c5a31e440a99a80a7da75b3d35b.png
# Processed and saved: 080.png
# Processed and saved: 080f46e0b2fe479db4de78e1f6e042c6.png
# Processed and saved: 081.png
# Processed and saved: 082.png
# Processed and saved: 0827dce2c8774d37b6b7c069df4b7653.png
# Processed and saved: 083.png
# Processed and saved: 084.png
# Processed and saved: 0842766256814155b81824401680de9a.png
# Processed and saved: 085.png
# Processed and saved: 086.png
# Processed and saved: 087.png
# Processed and saved: 088.png
# Processed and saved: 089.png
# Processed and saved: 090.png
# Processed and saved: 091.png
# Processed and saved: 092.png
# Processed and saved: 09276e1279054377be2000402aee2c7e.png
# Processed and saved: 093.png
# Processed and saved: 094.png
# Processed and saved: 0941f542d44c45c98b37b19449e8228b.png
# Processed and saved: 095.png
# Processed and saved: 0adfe906d1184312b5bc4e534f08fb47.png
# Processed and saved: 0b1cac1721e848e194ead4c87e80f248.png
# Processed and saved: 0bc1cb9485f84eac802acd9cc5fd1505.png
# Processed and saved: 0be94bb1521e4092bdc8e59639420f62.png
# Processed and saved: 0bfb2488d46b496a85b73a4797d744f3.png
# Processed and saved: 0c375c935cd0424792067cc26287d9c3.png
# Processed and saved: 0c5f839152ad40068e6f223dc779ac6a.png
# Processed and saved: 0c934a627ca94689acd93950c9bfa0df.png
# Processed and saved: 0c99b100186941528bd9618ac71bc121.png
# Processed and saved: 0cb5fb271cd740eb871dc2f1cae0e29c.png
# Processed and saved: 0d3e23909e1947cd88dac92852641d24.png
# Processed and saved: 0d8e63c44f1e4c97b3a8e86eeb6444b1.png
# Processed and saved: 0f11d9a3cd1548fabc430207f710e1ec.png
# Processed and saved: 0f52134be3184408a30d8bfc6a38ddc7.png
# Processed and saved: 0f90529f333e4c6babbad93734677604.png
# Processed and saved: 110c05bb71d543978bf730906d75672f.png
# Processed and saved: 1199a8ed279148f8bcc9863de72bd1e1.png
# Processed and saved: 1200beb901f64b14a06021a78957d648.png
# Processed and saved: 1237c6eda15448feb6cf59f22dde7505.png
# Processed and saved: 136714f9c1e041a6b93c7fe928ca2f95.png
# Processed and saved: 1371c45bd72a47c6bb56ded4510d803c.png
# Processed and saved: 14e56baeef774a1389ad9caa233d757a.png
# Processed and saved: 14f51ff0cf9345bf9f684f2ff928606a.png
# Processed and saved: 15799cb678d74623b2103769a01e40e3.png
# Processed and saved: 15f34c240be84765ab4f9104467a99d2.png
# Processed and saved: 1726b41e3775400697732144f59870a3.png
# Processed and saved: 17518652cad04602a48d801c08feb1ec.png
# Processed and saved: 1753577fd67842e9b3ce6ed91c3d07bc.png
# Processed and saved: 177c3296e2ca4e18b8bd9a98a817d0b4.png
# Processed and saved: 192ced0f5e5141d583db3dd957406305.png
# Processed and saved: 19e65043a82f4c86aba4b3e1bad46406.png
# Processed and saved: 1a8c98325af4473294cc3f8dfee262b7.png
# Processed and saved: 1af9217105a946618e0c203fac9169db.png
# Processed and saved: 1b4a956a09ce4d93ac1efccba12ad639.png
# Processed and saved: 1b6c4161c3794fecbe79a1d6e3bfee09.png
# Processed and saved: 1c086f504b67469fa0ff7a90494f1909.png
# Processed and saved: 1c3b1b44c20243a38a27ce7f1987eba8.png
# Processed and saved: 1d6a8377ceaa455290f648edbedcb306.png
# Processed and saved: 1e11cf1126164cf688891e8183eafee5.png
# Processed and saved: 1e67ea6eac244663b206a0d20dbdc75d.png
# Processed and saved: 1f241fc34a1045e9adbc7940d13f6f6c.png
# Processed and saved: 1f3c0ebb850e445ea3032d96724fe863.png
# Processed and saved: 1fbd28d59c524bf48dc4437fb143bb63.png
# Processed and saved: 20e763598e5344b1a2f329b78e03f0c4.png
# Processed and saved: 214feb0207fb4ed49f86a8eaa95cd500.png
# Processed and saved: 233ac898ae5f4567ab50eb412e1ba94c.png
# Processed and saved: 23a159b7a33c41c0b0b20886a257a7ea.png
# Processed and saved: 24793180ec134039aebf7e4cb3402e21.png
# Processed and saved: 24a5a4b8387e41bba0d3d2b271161cd7.png
# Processed and saved: 25fc7abd46564348891e6483df6418c7.png
# Processed and saved: 2670f9ec2cd341e1890ae0eb42eba00d.png
# Processed and saved: 26b0856190e74ccaace6eea8fc3e74e3.png
# Processed and saved: 27cf8026331d4a8aa187aa37b25b8ccd.png
# Processed and saved: 28f03608dbd94873962484176a362435.png
# Processed and saved: 29509b68d3c44bffbd4fb09339098af7.png
# Processed and saved: 2a5e08d3974349149361a0d3e918aa6b.png
# Processed and saved: 2ab251f891214070ad49a7b92e574268.png
# Processed and saved: 2cbf4562d5b34d489675e3d0e4081f66.png
# Processed and saved: 2f06cf1790a446898f9fdbd6ce333d7b.png
# Processed and saved: 2f1b9fd77491439cbdabe3f3eeb6c34c.png
# Processed and saved: 30355106b7454a848c4589d7f4d4e378.png
# Processed and saved: 3137b173de9841508e00dd197d7ce4fb.png
# Processed and saved: 31e7f4b5576c4e5bac96bf19ea275aa2.png
# Processed and saved: 32ccd7944d8b48ab9171bd01d67c0a8c.png
# Processed and saved: 32d1d956528b4a71a0f88d0923b47658.png
# Processed and saved: 33c4e0ffa414435381a81ce82ae42b22.png
# Processed and saved: 34597be4dd5e4b23a5b7361ed53e1b68.png
# Processed and saved: 34fdea15e72444668c9220535853e765.png
# Processed and saved: 374023c3e2994bfcb870a57bb7ef257e.png
# Processed and saved: 38b84f277de645b084d40e5d311866f1.png
# Processed and saved: 3aa47f3fc19d4b58820ee46a2f1def6e.png
# Processed and saved: 3b15a7cfbeba42ad90cb16b4b7c2f328.png
# Processed and saved: 3b691aa4adfa4520a645e7224028f413.png
# Processed and saved: 3bbbb665594d4b4ebd5b74ed3ab3ef21.png
# Processed and saved: 3c6b8acc16fc47ac9bb86abac41f9ad8.png
# Processed and saved: 3c957f7221424a14a563bfb296805750.png
# Processed and saved: 3d38feb9d17e4441ae74fd53bc08502c.png
# Processed and saved: 3d79ddbb35014a58ad9bd1171965dcef.png
# Processed and saved: 3d8df5a5660545189c7d23aec64a7f1a.png
# Processed and saved: 3d9466c2f37e4d8d86db695349ff9912.png
# Processed and saved: 3e1f4b28101149d294878d9e2be9e55b.png
# Processed and saved: 3fbcdc8b257c4945812ba50e1ef2037d.png
# Processed and saved: 3ff5fb1483eb4668a1c1c8ad954c5a59.png
# Processed and saved: 4009a3ac43574eca8cc97109492951a9.png
# Processed and saved: 40d5d0a1d2074dc980a33f5bd29d2859.png
# Processed and saved: 42e70dede79e42d898694c765acb91bf.png
# Processed and saved: 434b5e2802844cb8b8374ef9ac206fa5.png
# Processed and saved: 44d00feb66fd4b3eb5bcf2147e838ecf.png
# Processed and saved: 4584998764af481e9edb5c9c9e5630a3.png
# Processed and saved: 458da9628f104d93bcf57b01b40a6117.png
# Processed and saved: 45946afe019d4efe962b423618480468.png
# Processed and saved: 467e36aed1cb4a51a94459e8d174ba0c.png
# Processed and saved: 47b8c28768734c92a6598a0336eb12ec.png
# Processed and saved: 47be1d96e6f146a69c39a687e9c51a92.png
# Processed and saved: 481aa104f56c43a399ed7f9a3e5f9eed.png
# Processed and saved: 48a5523be0d34b3eb9dcc8279a7c4018.png
# Processed and saved: 48aee432d21a4ad9a40bff784ef39f79.png
# Processed and saved: 49ce99c8768f43ba8320089f3504f200.png
# Processed and saved: 49d79c533524403e921c9c9449807770.png
# Processed and saved: 4a6879ff32634fe3a97f9903170571aa.png
# Processed and saved: 4afbdad000314e28abb46d0771d60735.png
# Processed and saved: 4b1fd08590924312a044c749ed7b670a.png
# Processed and saved: 4b90cb43e00f46e8bfb487b10341d4aa.png
# Processed and saved: 4c4880489de44e17b918883c6e916a5e.png
# Processed and saved: 4e12489aa51d41d1b241ec7305463ac0.png
# Processed and saved: 4f3d11cb554b493fb0e526c470d25c05.png
# Processed and saved: 4f8d8bfe572e4583982520b48c2b7442.png
# Processed and saved: 505f1eb08b4a4e83a2e3c9bd39f6c319.png
# Processed and saved: 51e97b3048ce409c9f803416a3770d7a.png
# Processed and saved: 52436fb5f6944d54bcbd2f7308405c10.png
# Processed and saved: 525bacd7798141238e33144ee492c29d.png
# Processed and saved: 537bb392574f4b029b1eb55b95b45c7e.png
# Processed and saved: 543aa8beccfc461291f952588316d0d2.png
# Processed and saved: 5469b226daa54ec29774cad371a4cdef.png
# Processed and saved: 568d19b49be149c8827f7658dfc5490f.png
# Processed and saved: 56ce73136c824fc49bcad342b1bad187.png
# Processed and saved: 579560af93fb4ac2a0bb2f5b098f8220.png
# Processed and saved: 57dc5f85b751497f9c951af3f4a9241b.png
# Processed and saved: 58e7c48bf65343fa96e429cdc376ef6b.png
# Processed and saved: 591fa841ed464ead8e44945e8d2777c9.png
# Processed and saved: 5973ed54fb3341d394ec81fbbc92dab6.png
# Processed and saved: 59eba369b7bc49d8a8fce99771d384c0.png
# Processed and saved: 5a63416e55094fddaf43f2a6b741c9cb.png
# Processed and saved: 5c36f93f5d214d24b3235427cf9699c3.png
# Processed and saved: 5cba69f9687b4ca19c3e6296c7e47305.png
# Processed and saved: 5ccac832c6354513b7e7a02f2c2ef007.png
# Processed and saved: 5cf546bac13142c592461f1b3b7c0465.png
# Processed and saved: 5d8f3bf754254df5b60cf255484c8a96.png
# Processed and saved: 5e840977435848c0b79dd9d477d8f210.png
# Processed and saved: 6029135bc4f244c08279482e15715519.png
# Processed and saved: 60be678a31be4b14b83d909da3de771a.png
# Processed and saved: 617d527d1483415faf9a39c1805b653d.png
# Processed and saved: 61fbb208ae3e450fa621449824ee9c4f.png
# Processed and saved: 62172ef383af4c8cbc440a307a931558.png
# Processed and saved: 623b0984c71949daab74d941bba02757.png
# Processed and saved: 641cc0520fc3483abdbf66e034cbf092.png
# Processed and saved: 64584bdedcbd45c4b6cb9225df15bcf8.png
# Processed and saved: 646e5a3769bd4cd4a05ddf43c21c371e.png
# Processed and saved: 6524c9ed018b447d9a03ccb8a8126cbb.png
# Processed and saved: 656c6ffa651149dab8a87f0c4a925e3a.png
# Processed and saved: 65d6b2d709114b1ca1484d75d2b074db.png
# Processed and saved: 65e1c5a750834fd58f971f3a9bc66bd3.png
# Processed and saved: 661468ce842d40fbbe827a941b304e08.png
# Processed and saved: 661a3aee18654a6082b98caade434860.png
# Processed and saved: 6643a51212084654918a0aa47882a55e.png
# Processed and saved: 669a2c7cf00b4ee8b9f9f701b6341304.png
# Processed and saved: 66e8554965984e67be73e8b3d833458a.png
# Processed and saved: 6791042f298e43cb98b6ed3941754d08.png
# Processed and saved: 67cddf2dd6654a368faf9fbeb3842b41.png
# Processed and saved: 6800aa6ae5974d7791283f196cb857e9.png
# Processed and saved: 6816217558a142b19729f212432c04df.png
# Processed and saved: 6839b3e14f964e1997285b8003cf2c6c.png
# Processed and saved: 6920997b0bda48e29f96bce9e4f628bf.png
# Processed and saved: 69509ed71a0043ae90fe442e84fe3388.png
# Processed and saved: 6973762cf77042a48382dfa75c059e05.png
# Processed and saved: 698aeeb0d58645119abb1fe6896bdab6.png
# Processed and saved: 69bd61fcce464e9ca60bafbd20d288bf.png
# Processed and saved: 69d192b795b445b280f32378b9f108f4.png
# Processed and saved: 6cb30bf94806446398c79dcb290efec7.png
# Processed and saved: 6d24003fdff747e2964015b334ed3c3c.png
# Processed and saved: 70d311405dc245f0acccb30a7c10be4c.png
# Processed and saved: 70f92fa974e34e87b3239c756706a661.png
# Processed and saved: 712e15c69a104ab3bb37e2709ff4d6fe.png
# Processed and saved: 7226948ce401464a802e51a88509cc63.png
# Processed and saved: 729785e363104c70933a412f269d804b.png
# Processed and saved: 74c1e5590af64f2882c1665427070ee6.png
# Processed and saved: 76ac100dd5c54732b0109570644dccc3.png
# Processed and saved: 776db76dccf34927be04b0ae2bba4c75.png
# Processed and saved: 7ab4e09f44ec421da7fe3269d1aab3f3.png
# Processed and saved: 7b978b911a3c4e81b3841a714f7f7368.png
# Processed and saved: 7bfce1e7c99a4434b4f53e9f9948f2a8.png
# Processed and saved: 7ca0167f73224eb4b04c7898375b72b9.png
# Processed and saved: 7dc64c322323434088a360565b7b7d4a.png
# Processed and saved: 7f231954d7da4a7686a2cc88b78892ea.png
# Processed and saved: 7f248a85b4844e6ea643c70ac9c5ab0b.png
# Processed and saved: 7f61cc812f9f4ebda4078eb04910d6db.png
# Processed and saved: 7f9db4ab68e84e859eaceefca10a6348.png
# Processed and saved: 7feea2b200c241539f7f2b56f9d814fe.png
# Processed and saved: 80993046432749a49c7cc189e19bd973.png
# Processed and saved: 820dfc9d3a824d868c1d3e5c9877d40a.png
# Processed and saved: 82a5f7d96ba54076882d28d1eaf78898.png
# Processed and saved: 82d317cb6bce4bb889ed51ccd5b263f4.png
# Processed and saved: 82fdfab52a4c45fc9b06e1525f8bf3c7.png
# Processed and saved: 8300d4f656b94ed8abcd36c9158d3a76.png
# Processed and saved: 8337aa531a3e4f37b2b09c11a2e1e71d.png
# Processed and saved: 834460dc7d894d76ac9bae938721ec74.png
# Processed and saved: 83d1d871f4c8466d898c16436449c612.png
# Processed and saved: 83da3cf523b24675bd6c0ac5b776d3b6.png
# Processed and saved: 8461699c543c4c3cbe0b56d1c3b7616f.png
# Processed and saved: 849e1470cb794604be06c99eb03a63ce.png
# Processed and saved: 84c1b60dbcf447208461f8cedddda001.png
# Processed and saved: 84d8fdc17da6471086e36874573524f9.png
# Processed and saved: 84e68dbd88b64a33a781499a9f20fe28.png
# Processed and saved: 8627265370c44212ad686f0eba48da39.png
# Processed and saved: 8700e04b36b5407c876cd15d38988c69.png
# Processed and saved: 882f827131af4659a0937150dbfcd51f.png
# Processed and saved: 88acc32c80be407d93a72fccbda15d10.png
# Processed and saved: 88bfa614a8c34e5087c2c35727034917.png
# Processed and saved: 896b85cf4f3a4b74ae651fc2934f827e.png
# Processed and saved: 899121e21b6f43e0863df02d16379535.png
# Processed and saved: 89e1e7690ab149bca5a3da6f8f7d2aa0.png
# Processed and saved: 8b0ed41008744703acfcc328cd1566ab.png
# Processed and saved: 8b2d319815864379b22979cbb671c376.png
# Processed and saved: 8c49b4da7fdd48f4af23ae200cde31aa.png
# Processed and saved: 8c6062162d8746babe9083e5b589806b.png
# Processed and saved: 8d0ed5b640ab4f329933ba6c96188e77.png
# Processed and saved: 8da2ed861624439cbc26e4337c6a0cc7.png
# Processed and saved: 8f84fb13fd8d4e8aa9ea607d88a11415.png
# Processed and saved: 902bb0a685494f8d849f5be2fe82c32b.png
# Processed and saved: 904ecd52eebe4aa0a58b0904ffd93705.png
# Processed and saved: 91028f1b61b14878826b5bffcb28ec88.png
# Processed and saved: 919d818349c4450e8ab26a1c9a3531fb.png
# Processed and saved: 91eeb41baa6e4b6db66a6de01d2a70ee.png
# Processed and saved: 92605e064d464f3bb5f3a796bf9a59d0.png
# Processed and saved: 926b1e0efd504ed4ac9cbbdfd7c3f35f.png
# Processed and saved: 92b5c9324769406ca10b047e3b30ac97.png
# Processed and saved: 932bf2e05c3e40f9b79c85ac4fc992e0.png
# Processed and saved: 93b7db898b514670b8f834caf79e3fbe.png
# Processed and saved: 93d8182731914970893a2e1b635fa6bd.png
# Processed and saved: 93d9c71e8926411e800acfd4c6b7ee28.png
# Processed and saved: 946b7d35066e486e875cd3852185b01a.png
# Processed and saved: 94ae3922d3b0460597e5902aaefe83b4.png
# Processed and saved: 95dce134ea44424ba051954293faf8d1.png
# Processed and saved: 9734cbb97c66416a96620769519e3a52.png
# Processed and saved: 98326279771342b6bc0ca305441ac750.png
# Processed and saved: 98e0533a4b3541eeb4ea937fcde895ba.png
# Processed and saved: 996c3b548e5f4f9ea3e09cdc84bb309b.png
# Processed and saved: 9a886b1ee7e944bfa6455e3a3d13c467.png
# Processed and saved: 9a89ca19e9734fb5b37b470d50061efb.png
# Processed and saved: 9aece68502274410a00e53fd290ea34d.png
# Processed and saved: 9c9d27eb4268479eb37e213fdf50436b.png
# Processed and saved: 9cdb925a165b409f8700d54ce0890db1.png
# Processed and saved: 9ce46974624a498f8a454c300992ac0a.png
# Processed and saved: 9d25a82b5b2d44958a4b42abf38ce2e4.png
# Processed and saved: 9e966f8726fb4ab58bae6fac035837d0.png
# Processed and saved: 9f8f8582aaca45abbeec4ae5bc5b6f1f.png
# Processed and saved: 9feaa9f769e94cb8a9622d68fb72e2be.png
# Processed and saved: a08fda8935064c5aa3f4241352f8a16c.png
# Processed and saved: a0afada11ce843dcbe66b2393e5046bd.png
# Processed and saved: a14b27e702534ac9bbea0aab64918de3.png
# Processed and saved: a150630769de4dfa95f2244961e67e40.png
# Processed and saved: a15c96e9c4a040a5843a8369e8e3b769.png
# Processed and saved: a169a234fef044748046b625fe6e5509.png
# Processed and saved: a1df1be3065044aba93ffcc2b8a0b3b2.png
# Processed and saved: a1ecc09fdf054eb994dc5f7fc859cc08.png
# Processed and saved: a21e7e9847084731b0d81823126eaba8.png
# Processed and saved: a3840503acd444d8af76eea3f37f9f8c.png
# Processed and saved: a43114c388f04f268e2bb5e9067df25f.png
# Processed and saved: a5937af474284c97b281af512ad825b4.png
# Processed and saved: a6d0d44d0e7949288e2ed09bbeba06a1.png
# Processed and saved: a6d3975e60074e8dab265da0b4b0783c.png
# Processed and saved: a794126d17f34bfab2354980650248a6.png
# Processed and saved: a8e0a09bfd2546eb88ff3ab6801e29a1.png
# Processed and saved: a8e4d05e1fe1446180bb9c23ac455706.png
# Processed and saved: a95c73bab5654734844dafcb0126b3bf.png
# Processed and saved: aa5f397952f94fd09b28e3e3e469ba79.png
# Processed and saved: aaec9e2a1659481cb7c51c447ab17504.png
# Processed and saved: abe7cbc4fa444d23a132a982004fdd73.png
# Processed and saved: aed45db534c04af1b161e387371a240a.png
# Processed and saved: af87eb24c87c457bace816faab1e810d.png
# Processed and saved: af9c1251cb8149a996160680954a4aa1.png
# Processed and saved: b064d28aec634f9f84f2a666cfa029db.png
# Processed and saved: b096b553fd94408d95212333560b491b.png
# Processed and saved: b21aa49c59fd44139a8a80176a71effd.png
# Processed and saved: b2c905eaa7184bcb8205f64c2711d3d0.png
# Processed and saved: b4cfc45a57e8486399726a8606506b8e.png
# Processed and saved: b5379815a88447ec951adbd302d79d4c.png
# Processed and saved: b55642e6805142e383802bdf3b6a7a8d.png
# Processed and saved: b622e1e24a8f4b65b25f8745ed072153.png
# Processed and saved: b78875a09dce451b9f745bb6495d21f3.png
# Processed and saved: b7b4d423122d41bda890303ebbb0d9c3.png
# Processed and saved: b81a7afc5d0a4cef9376e9a100f3c650.png
# Processed and saved: b8478faa58a14267baf4e65a7cf30122.png
# Processed and saved: b89a9cb815234febacb9428f75a0d67c.png
# Processed and saved: b9279d5e8b524be8b569beeace48a061.png
# Processed and saved: b978646a79774a01b2ebb9cd984b4183.png
# Processed and saved: b9d909a4d0554dec880ea6354d128bb5.png
# Processed and saved: ba6f80126e3844878f7d30133c6e99a1.png
# Processed and saved: baad93f4be654c48b8d32ac6724149a9.png
# Processed and saved: baccc5c628184d6b8eb5cf757006fb43.png
# Processed and saved: bae8e8f015264c0a867f92e213a71b3b.png
# Processed and saved: baee889039294335ac5f12efeb56a6cb.png
# Processed and saved: bb318ddc1da94fbebb65f8eb366cf446.png
# Processed and saved: bb519c7ae4d24ff69c382eafd52b1311.png
# Processed and saved: be3f999895484b3dafda59ffc2a8b7a9.png
# Processed and saved: be459ffd44324e04b4be5eaf0ea4a164.png
# Processed and saved: bfa7b54440c04e68a9c5aa4e0bfe59b4.png
# Processed and saved: c0131fbea4a04f9e9d51b43ce1f61902.png
# Processed and saved: c0944e383a5e469d8eb4fd79cb72c020.png
# Processed and saved: c0a47de4f8b343428a22383aec251114.png
# Processed and saved: c1f4495e264f4f07b1e388cf6f675224.png
# Processed and saved: c200cb7811df4217b9c42f7df1c9a414.png
# Processed and saved: c22b269bbebd4c1481ff89b84f1267c8.png
# Processed and saved: c2a83c6cb0904c6391f3fb20cd52f9a3.png
# Processed and saved: c38c0bd49cd840bc814878ddcc3f0c97.png
# Processed and saved: c3dd93fa8e8040e9a0b944e89ec2ede2.png
# Processed and saved: c4457918f4ef45d1b142c11b6606428a.png
# Processed and saved: c5aa820465714a5584bdf9eaea5d2d8b.png
# Processed and saved: c64d8fda4db7464f91bd3af0902b4889.png
# Processed and saved: c69ac2f197cc409f9948d13db35b95ab.png
# Processed and saved: c6ac9f27be744922bad3f8b96b3330c9.png
# Processed and saved: c6cf9fe036fc40f7890e267cc639cbd4.png
# Processed and saved: c6ec9cc95fd34b31896429a77bc83872.png
# Processed and saved: c7ef2bf72fcf4e84bffda12d4e4e2347.png
# Processed and saved: c7f3ab98362d4c458567617c853a65c8.png
# Processed and saved: c888ea0e789a4fc99daa747233a8aa63.png
# Processed and saved: c9145437b2ec44dbbf2fdfb7f3048baa.png
# Processed and saved: c9ba549863ad4a8392073ffd6e33a2a1.png
# Processed and saved: cb249b655d9946dd88cf07e0f749d67a.png
# Processed and saved: cb59384fdd3d4f438453cb9ce1f6bdab.png
# Processed and saved: cb98d9fd8f6347b29b71d173040a90b7.png
# Processed and saved: cc2af2ba1ff741918e71288a5478a078.png
# Processed and saved: cc2d8c09c2f441b09c61216f7d316de6.png
# Processed and saved: d02901c7871b4ae6aa2d68b52b9f5e70.png
# Processed and saved: d185c7ebc9154a0eaf5361f71995f141.png
# Processed and saved: d23c16a8f4544599aa31a83f48d07ed3.png
# Processed and saved: d2813a1c17444069b6a5839c9bc3db23.png
# Processed and saved: d2f72ca269984d3183c50437f313202f.png
# Processed and saved: d41e236163724004a01b721ee5b0ce75.png
# Processed and saved: d58716dcd84c4af1baa7d9ff03db6cf6.png
# Processed and saved: d5d8f5e0b2ab44c98ffee157a6968cfd.png
# Processed and saved: d69429de99e2429bbb7e8cba3b9d170c.png
# Processed and saved: d84d359dcfc54143b10ff0b23c70311c.png
# Processed and saved: d867ba9a092647279680290070ae18cb.png
# Processed and saved: d904b21fa4494ec98ab0c0353266386a.png
# Processed and saved: d9397b2f973740e085ff5d7faf719d2e.png
# Processed and saved: d9bdca6dee2b40b58fc85cd6302b6bc4.png
# Processed and saved: dad01ae2e72d4a6485e323c52a7fd0d1.png
# Processed and saved: dad4066dbc954ad690d18c3182b72d70.png
# Processed and saved: db872ba5487f40eaac4a9a89321a0b99.png
# Processed and saved: dc675b3c01a54ff08b366910bddfbd93.png
# Processed and saved: dc78b7f108424e368117713268745b79.png
# Processed and saved: dcdeb0652bf14db6ae78b53d2bc44197.png
# Processed and saved: dd149b7ac703482ea26b1b810e40497f.png
# Processed and saved: dd64bb892e1241c7ad35e4047da53914.png
# Processed and saved: deabb9b6ff4c4aec93cf683e6b7da3b2.png
# Processed and saved: e0acd2712ad1451fa660824a7134bd3e.png
# Processed and saved: e0fd18f5ce014e3bb7e23bb8323f5d36.png
# Processed and saved: e1e26c567ea74189804e67f782400664.png
# Processed and saved: e20e0928da3047b0bd7148d14b3aae2e.png
# Processed and saved: e39217383a844e35a9c9bb2dc3250d2c.png
# Processed and saved: e3d2a4f7e3e1468fb1f2f4dbec8b9691.png
# Processed and saved: e4033beef79a4d6794dffcc569ee0482.png
# Processed and saved: e48cbbda3d6840c4a5adedbb3079afaf.png
# Processed and saved: e49b0598deae4e42a8c9ad2aaac49f89.png
# Processed and saved: e56ccf5d31df4708adb7c083f2edaeea.png
# Processed and saved: e5ea30a642d9428ca4344abdcee19bef.png
# Processed and saved: e7c325a78bae4bc9a8e48938a1f3f1ce.png
# Processed and saved: e84d56ccd1b440bdb9a4558d88c139a8.png
# Processed and saved: e8dbe773f2064768adf56f49cd00b025.png
# Processed and saved: e9069adbe3bb424d92e63bc37d25ad13.png
# Processed and saved: e915c473b8604bee8c3c57bbee495369.png
# Processed and saved: e95e955a4dde4570b12649ceb76a3256.png
# Processed and saved: ebd8cce49ff448f383b8ee7a6cfbbe22.png
# Processed and saved: ec8f5949ca5e4ddc896402cd620dc00d.png
# Processed and saved: ed10f1f305264076898efad4031dd186.png
# Processed and saved: edfd007982804a27a5b189b503498e96.png
# Processed and saved: ee61c48ad3b44d22919037174043ebee.png
# Processed and saved: f07fcf86a23343dc85a62a73b4940ffe.png
# Processed and saved: f088533d8f984e8391f2b41974e2e80b.png
# Processed and saved: f0aef7a2968e450f8e10c46b1ddeaf4b.png
# Processed and saved: f0f005755d934e849fe0a7ad3b55757a.png
# Processed and saved: f352ec5e203949a3bfdb80bf9e70a192.png
# Processed and saved: f39c8a1794ee495298e9415c3760ce1e.png
# Processed and saved: f481dfdb793b4f84bcb43d6997b4d49f.png
# Processed and saved: f48601a1ebaa4515baa02295bd91ed83.png
# Processed and saved: f4e6b615f88f4f98bac42eaa2f3e38b3.png
# Processed and saved: f4fc85b1cbe140ca96f6700f384f1434.png
# Processed and saved: f4fe0905323f4da1ab1f3c28ede7a8c4.png
# Processed and saved: f5048bb824c04d87a10a1b307d185526.png
# Processed and saved: f52551c21dd6449da3367106fc0ff261.png
# Processed and saved: f61839aa52b84356a3ab009422c9d28f.png
# Processed and saved: f68296a0a0d54eb785ca11335341b3fe.png
# Processed and saved: f82b1ab3027e4222bd370556d7917801.png
# Processed and saved: f9a964fb54fa45f7a3cfa4d206ac28fd.png
# Processed and saved: fa3a4d8797954e6a86a6d43b7f6ba590.png
# Processed and saved: faf713485fa64911a7aec28cc2d2482e.png
# Processed and saved: faf7d842ff2246f885d88d67722f2204.png
# Processed and saved: fc733759b16b453499b2c21dc08c460f.png
# Processed and saved: fc86d79450a343228693ad4031bbeebe.png
# Processed and saved: fcc844ef16d24441ad185464a1e2095d.png
# Processed and saved: fd4b782e9a6b4ea2acc5c4b3599c069c.png
# Processed and saved: fd7dc188b4d94e6c96641a7b572025b5.png
# Processed and saved: fe608ab01785478b9735aa4918554ea6.png
# Processed and saved: ff8e595b242e4cd5bf89bbff6a20cc56.png
# All images converted successfully.
