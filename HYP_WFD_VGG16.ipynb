# %% [markdown]
# # Downloading data

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import tensorflow as tf
from tensorflow.keras import layers, models, regularizers
from tensorflow.keras.applications.efficientnet import preprocess_input

# ==== Paths ====
train_dir = '/content/drive/MyDrive/VGG/train'
val_dir   = '/content/drive/MyDrive/VGG/valid'
test_dir  = '/content/drive/MyDrive/VGG/test'

# ==== Parameters ====
img_size    = (256, 256)
batch_size  = 16
seed        = 123
num_classes = 1   # binary classification

# %%
def prepare_ds(path):
    ds = tf.keras.utils.image_dataset_from_directory(
        path, seed=seed,
        image_size=img_size, batch_size=batch_size,
        label_mode='int'
    )
    ds = ds.map(lambda x, y: (preprocess_input(tf.cast(x, tf.float32)), y))
    return ds.prefetch(tf.data.AUTOTUNE)

train_ds = prepare_ds(train_dir)
val_ds   = prepare_ds(val_dir)
test_ds  = prepare_ds(test_dir)
# Out:
# Found 3200 files belonging to 2 classes.
# Found 398 files belonging to 2 classes.
# Found 402 files belonging to 2 classes.

# %%
def build_model(backbone_class):
    backbone = backbone_class(
        input_shape=img_size + (3,),
        include_top=False,
        weights='imagenet'
    )
    backbone.trainable = False

    inputs = layers.Input(shape=img_size + (3,))
    x = backbone(inputs, training=False)
    x = layers.GlobalAveragePooling2D(name='gap')(x)
    x = layers.Dropout(0.3, name='dropout1')(x)
    x = layers.Dense(
        128, activation='relu',
        kernel_regularizer=regularizers.l2(1e-4),
        name='dense128'
    )(x)
    x = layers.Dropout(0.3, name='dropout2')(x)
    outputs = layers.Dense(1, activation='sigmoid', name='output')(x)

    model = models.Model(inputs, outputs)
    model.compile(
        optimizer=tf.keras.optimizers.AdamW(learning_rate=2.5e-4, weight_decay=1e-4),
        loss='binary_crossentropy',
        metrics=[tf.keras.metrics.AUC(name='auc'), 'accuracy']
    )
    return model

# %%
from tensorflow.keras.applications import VGG16
model = build_model(VGG16)
model.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58889256/58889256 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_1 (InputLayer)      │ (None, 256, 256, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ vgg16 (Functional)              │ (None, 8, 8, 512)      │    14,714,688 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ gap (GlobalAveragePooling2D)    │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout1 (Dropout)              │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense128 (Dense)                │ (None, 128)            │        65,664 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout2 (Dropout)              │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ output (Dense)                  │ (None, 1)              │           129 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 14,780,481 (56.38 MB)
#  Trainable params: 65,793 (257.00 KB)
#  Non-trainable params: 14,714,688 (56.13 MB)

# %%
from tensorflow.keras.callbacks import (
    ModelCheckpoint, EarlyStopping,
    ReduceLROnPlateau, CSVLogger
)

callbacks = [
    ModelCheckpoint('best_model.h5', monitor='val_auc', save_best_only=True, verbose=1),
    EarlyStopping(monitor='val_auc', patience=10, restore_best_weights=True, verbose=1),
    ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=5, min_lr=1e-6, verbose=1),
    CSVLogger('training_log.csv', append=False)
]

history = model.fit(
    train_ds, validation_data=val_ds,
    epochs=50, callbacks=callbacks
)
# Out:
# Epoch 1/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.6244 - auc: 0.6379 - loss: 1.5616
# Epoch 1: val_auc improved from inf to 0.86866, saving model to best_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 500s 2s/step - accuracy: 0.6245 - auc: 0.6381 - loss: 1.5601 - val_accuracy: 0.7638 - val_auc: 0.8687 - val_loss: 0.4954 - learning_rate: 2.5000e-04
# Epoch 2/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 131ms/step - accuracy: 0.6940 - auc: 0.7686 - loss: 0.8066
# Epoch 2: val_auc did not improve from 0.86866
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 30s 147ms/step - accuracy: 0.6941 - auc: 0.7686 - loss: 0.8064 - val_accuracy: 0.8191 - val_auc: 0.9307 - val_loss: 0.4167 - learning_rate: 2.5000e-04
# Epoch 3/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step - accuracy: 0.7520 - auc: 0.8335 - loss: 0.5923
# Epoch 3: val_auc did not improve from 0.86866
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 32s 159ms/step - accuracy: 0.7520 - auc: 0.8335 - loss: 0.5922 - val_accuracy: 0.8417 - val_auc: 0.9406 - val_loss: 0.3748 - learning_rate: 2.5000e-04
# Epoch 4/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 131ms/step - accuracy: 0.7625 - auc: 0.8507 - loss: 0.5343
# Epoch 4: val_auc did not improve from 0.86866
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 38s 146ms/step - accuracy: 0.7626 - auc: 0.8507 - loss: 0.5343 - val_accuracy: 0.8970 - val_auc: 0.9574 - val_loss: 0.3288 - learning_rate: 2.5000e-04
# Epoch 5/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step - accuracy: 0.
# Epoch 43/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 127ms/step - accuracy: 0.9197 - auc: 0.9743 - loss: 0.2210
# Epoch 43: val_auc did not improve from 0.86866
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 40s 147ms/step - accuracy: 0.9197 - auc: 0.9743 - loss: 0.2211 - val_accuracy: 0.9472 - val_auc: 0.9922 - val_loss: 0.1686 - learning_rate: 1.2500e-04
# Epoch 44/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step - accuracy: 0.9182 - auc: 0.9732 - loss: 0.2241
# Epoch 44: val_auc did not improve from 0.86866
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 30s 150ms/step - accuracy: 0.9182 - auc: 0.9732 - loss: 0.2241 - val_accuracy: 0.9447 - val_auc: 0.9918 - val_loss: 0.1766 - learning_rate: 1.2500e-04
# Epoch 45/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 128ms/step - accuracy: 0.9302 - auc: 0.9773 - loss: 0.2076
# Epoch 45: val_auc did not improve from 0.86866
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 40s 143ms/step - accuracy: 0.9302 - auc: 0.9773 - loss: 0.2077 - val_accuracy: 0.9548 - val_auc: 0.9922 - val_loss: 0.1657 - learning_rate: 1.2500e-04
# Epoch 46/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 128ms/step - accuracy: 0.9189 - auc: 0.9758 - loss: 0.2164
# Epoch 46: val_auc did not improve from 0.86866
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 31s 154ms/step - accuracy: 0.9189 - auc: 0.9758 - loss: 0.2165 - val_accuracy: 0.9497 - val_auc: 0.9928 - val_loss: 0.1659 - learning_rate: 1.2500e-04
# Epoch 47/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 128ms/step - accuracy: 0.9248 - auc: 0.9772 - loss: 0.2109
# Epoch 47: val_auc did not improve from 0.86866
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 29s 142ms/step - accuracy: 0.9248 - auc: 0.9772 - loss: 0.2109 - val_accuracy: 0.9397 - val_auc: 0.9911 - val_loss: 0.1704 - learning_rate: 1.2500e-04
# Epoch 48/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 128ms/step - accuracy: 0.9182 - auc: 0.9730 - loss: 0.2279
# Epoch 48: val_auc did not improve from 0.86866
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 43s 154ms/step - accuracy: 0.9182 - auc: 0.9730 - loss: 0.2279 - val_accuracy: 0.9422 - val_auc: 0.9923 - val_loss: 0.1680 - learning_rate: 1.2500e-04
# Epoch 49/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 125ms/step - accuracy: 0.9235 - auc: 0.9773 - loss: 0.2099
# Epoch 49: val_auc did not improve from 0.86866
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 30s 151ms/step - accuracy: 0.9235 - auc: 0.9773 - loss: 0.2099 - val_accuracy: 0.9573 - val_auc: 0.9930 - val_loss: 0.1529 - learning_rate: 1.2500e-04
# Epoch 50/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 128ms/step - accuracy: 0.9234 - auc: 0.9804 - loss: 0.2003
# Epoch 50: val_auc did not improve from 0.86866
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 40s 144ms/step - accuracy: 0.9233 - auc: 0.9804 - loss: 0.2004 - val_accuracy: 0.9548 - val_auc: 0.9939 - val_loss: 0.1571 - learning_rate: 1.2500e-04
# Restoring model weights from the end of the best epoch: 50.

# %%
import numpy as np
from sklearn.metrics import roc_curve, accuracy_score, roc_auc_score, f1_score
import tensorflow as tf
# Evaluate on test set using the best saved model
model.load_weights('best_model.h5')

# 1) Predict probabilities
y_true, y_prob = [], []
for x_batch, y_batch in test_ds:
    y_true.extend(y_batch.numpy())
    y_prob.extend(model.predict(x_batch).flatten())
y_true = np.array(y_true)
y_prob = np.array(y_prob)

# 2) Compute ROC curve and Youden’s J threshold
fpr, tpr, thresholds = roc_curve(y_true, y_prob)
j_idx = np.argmax(tpr - fpr)
best_threshold = thresholds[j_idx]
print(f'Optimal threshold (Youden J): {best_threshold:.3f}')

# 3) Compute binary predictions and metrics
y_pred = (y_prob >= best_threshold).astype(int)
test_acc = accuracy_score(y_true, y_pred)
test_auc = roc_auc_score(y_true, y_prob)
test_f1  = f1_score(y_true, y_pred)

print(f'Test AUC : {test_auc:.4f}')
print(f'Test Acc : {test_acc:.4f}')
print(f'Test F1  : {test_f1:.4f}')
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 380ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 320ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 343ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 257ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 354ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 251ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 233ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 245ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 263ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 222ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 215ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 201ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 211ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 173ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 191ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 162ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 129ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 129ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 131ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 127ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# Optimal threshold (Youden J): 0.464
# Test AUC : 0.8971
# Test Acc : 0.8134
# Test F1  : 0.8092
